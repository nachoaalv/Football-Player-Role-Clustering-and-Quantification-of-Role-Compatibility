# %% [markdown]
# Start data analysis with ligue 1 2015/16 season

# %%
import json
import pandas as pd

# Define your path (with UTF-8 encoding)
file_path = r'C:\Users\nacho\open-data\data\matches\7\27.json'

# Load La Liga 2015/16 matches
with open(file_path, 'r', encoding='utf-8') as f:
    matches = json.load(f)

# Extract match IDs
match_ids = [match['match_id'] for match in matches]

print(f"Found {len(match_ids)} La Liga 2015/16 matches.")
# Out:
# Found 377 La Liga 2015/16 matches.

# %%
'''
Checks every game for each team is in the dataset
'''
home_teams = [match['home_team']['home_team_name'] for match in matches]
away_teams = [match['away_team']['away_team_name'] for match in matches]

all_teams = home_teams + away_teams

games_per_team = pd.Series(all_teams).value_counts()

print(games_per_team)
# Out:
# Rennes                 38
# Lorient                38
# Guingamp               38
# Nantes                 38
# Montpellier            38
# OGC Nice               38
# Lille                  38
# Marseille              38
# Caen                   38
# Stade de Reims         38
# Angers                 38
# AS Monaco              38
# Toulouse               38
# Lyon                   38
# Troyes                 37
# Saint-Étienne          37
# Gazélec Ajaccio        37
# Paris Saint-Germain    37
# Bastia                 37
# Bordeaux               37
# Name: count, dtype: int64

# %%
import os
from tqdm import tqdm 

'''
to extract all match events from each match
'''

# Base folder where event files are stored
events_folder = r'C:\Users\nacho\open-data\data\events'

# List to hold all events
all_events = {}

for match_id in tqdm(match_ids):
    event_file = os.path.join(events_folder, f"{match_id}.json")
    with open(event_file, 'r', encoding='utf-8') as f:
        match_events = json.load(f)
        all_events[match_id] = match_events  # Store events under the match_id key

print(f"Loaded events for {len(all_events)} matches.")
total_events = sum(len(ev) for ev in all_events.values())
print(f"Loaded a total of {total_events} events from {len(all_events)} matches.")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 377/377 [05:34<00:00,  1.13it/s]
# Loaded events for 377 matches.
# Loaded a total of 1358596 events from 377 matches.

# %% [markdown]
# Extracting the line up of one game to check accuracy and make sure it works

# %%
first_match = matches[12]
match_id = first_match['match_id']

print(f"Match ID: {match_id}")
print(f"Home team: {first_match['home_team']['home_team_name']}")
print(f"Away team: {first_match['away_team']['away_team_name']}")
print(f"Date: {first_match['match_date']}")
# Out:
# Match ID: 3901184
# Home team: Marseille
# Away team: Rennes
# Date: 2016-03-18

# %%
events_for_match = all_events[match_id]

# Find the Starting XI event(s)
starting_xi_events = [e for e in events_for_match if e['type']['id'] == 35]

for event in starting_xi_events:
    print(f"Team: {event['team']['name']}, Formation: {event['tactics']['formation']}")
    lineup = event['tactics']['lineup']
    for player_info in lineup:
        player_name = player_info['player']['name']
        position_name = player_info['position']['name']
        jersey_number = player_info.get('jersey_number', 'N/A')
        print(f"  #{jersey_number} {player_name} - {position_name}")
    print()
# Out:
# Team: Marseille, Formation: 4231
#   #30 Steve Mandanda - Goalkeeper
#   #26 Brice Dja Djédjé - Right Back
#   #3 Nicolas Alexis Julio N'Koulou Ndoubena - Right Center Back
#   #6 Rolando Jorge Pires da Fonseca - Left Center Back
#   #2 Javier Manquillo Gaitán - Left Back
#   #18 Mauricio Aníbal Isla Isla - Right Defensive Midfield
#   #10 Lassana Diarra - Left Defensive Midfield
#   #24 Florian Thauvin - Right Wing
#   #13 Rémy Cabella - Center Attacking Midfield
#   #14 Georges-Kévin Nkoudou Mbida - Left Wing
#   #22 Michy Batshuayi Tunga - Center Forward
#
# Team: Rennes, Formation: 442
#   #1 Benoît Guy Robert Costil - Goalkeeper
#   #29 Romain Danzé - Right Back
#   #14 Fallou Diagne - Right Center Back
#   #22 Sylvain Armand - Left Center Back
#   #24 Ludovic Baal - Left Back
#   #6 Gélson da Conceição Tavares Fernandes - Right Defensive Midfield
#   #21 Benjamin André - Left Defensive Midfield
#   #10 Kamil Grosicki - Right Midfield
#   #28 Yoann Gourcuff - Left Midfield
#   #23 Ousmane Dembélé - Right Center Forward
#   #13 Giovanni-Guy Yann Sio - Left Center Forward

# %% [markdown]
# need to narrow down to what postions i should go,
#
# examples: treat right back and left back as one?
# treat left back and left wing back as one?
# treat defensive midfield, center midfield and attacking midfield as one?
#
# Inititally only these positions:
#
# fullback (LB, RB, LWB, RWB)
#
# centreback
#
# Midfield (CDM CM CAM)
#
# RM LM?
#
# Wingers (LW RW)
#
# Striker (ST CF

# %%
unique_positions = set()

for match_id, events in all_events.items():
    for event in events:
        if event['type']['name'] == 'Starting XI':
            lineup = event['tactics']['lineup']
            for player in lineup:
                position_name = player['position']['name']
                unique_positions.add(position_name)

print(f"Unique positions in the season: {len(unique_positions)}")
print("Position names:", unique_positions)
# Out:
# Unique positions in the season: 23
# Position names: {'Left Wing', 'Left Midfield', 'Left Wing Back', 'Right Center Forward', 'Right Attacking Midfield', 'Left Attacking Midfield', 'Right Center Midfield', 'Left Defensive Midfield', 'Right Midfield', 'Right Wing Back', 'Left Center Forward', 'Center Back', 'Goalkeeper', 'Right Defensive Midfield', 'Right Wing', 'Left Back', 'Right Back', 'Center Attacking Midfield', 'Center Defensive Midfield', 'Center Forward', 'Right Center Back', 'Left Center Midfield', 'Left Center Back'}

# %%
'''GET MINUTES PLAYED BY EACH PLAYER'''


from collections import defaultdict

player_seconds = defaultdict(float)
player_id_to_name = {}

for match_id, events in all_events.items():
    players_on_pitch = {}  # player_id -> start_time_in_seconds
    off_periods = defaultdict(list)  # player_id -> list of {'off': time, 'on': time}
    added_time_players = defaultdict(int)
    
    for event in events:
        event_time = event['minute'] * 60 + event['second']
        
        if event['type']['id'] == 35:
            for player in event['tactics']['lineup']:
                pid = player['player']['id']
                name = player['player']['name']
                players_on_pitch[pid] = 0
                player_id_to_name[pid] = name
        
        elif event['type']['id'] == 34:
            added_time = event_time - 2700  # 45 mins in secs
            if added_time > 0:
                for pid in players_on_pitch:
                    added_time_players[pid] = added_time
        
        elif event['type']['id'] == 19:
            player_out = event['player']['id']
            player_in = event['substitution']['replacement']['id']
            time_sub = event_time
            
            if player_out in players_on_pitch:
                start_time = players_on_pitch[player_out]
                added = added_time_players.get(player_out, 0)
                player_seconds[player_out] += time_sub - start_time + added
                del players_on_pitch[player_out]
            
            players_on_pitch[player_in] = time_sub
            name = event['substitution']['replacement']['name']
            player_id_to_name[player_in] = name
        
        elif event['type']['id'] == 27:
            pid = event['player']['id']
            off_periods[pid].append({'off': event_time})
        
        elif event['type']['id'] == 26:
            pid = event['player']['id']
            if off_periods[pid] and 'off' in off_periods[pid][-1] and 'on' not in off_periods[pid][-1]:
                off_periods[pid][-1]['on'] = event_time

    # End of match: finalize playing time for players still on pitch
    if events:
        last_event = events[-1]
        match_end_time = last_event['minute'] * 60 + last_event['second']
        for pid, start_time in players_on_pitch.items():
            play_time = match_end_time - start_time + added_time_players.get(pid, 0)
            
            for period in off_periods.get(pid, []):
                if 'on' in period and 'off' in period:
                    play_time -= (period['on'] - period['off'])
                elif 'off' in period:
                    play_time -= (match_end_time - period['off'])
            
            player_seconds[pid] += play_time
'''
# Print results
for pid, seconds in player_seconds.items():
    name = player_id_to_name.get(pid, "Unknown")
    minutes = round(seconds / 60, 2)
    print(pid, name, minutes)
print(len(player_seconds))
'''
# Out:
# '\n# Print results\nfor pid, seconds in player_seconds.items():\n    name = player_id_to_name.get(pid, "Unknown")\n    minutes = round(seconds / 60, 2)\n    print(pid, name, minutes)\nprint(len(player_seconds))\n'

# %%
player_data = []

for pid, seconds in player_seconds.items():
    name = player_id_to_name.get(pid, "Unknown")
    minutes = round(seconds / 60, 2)
    player_data.append({
        'player_id': pid,
        'name': name,
        'minutes': minutes
    })

# %%
'''ADD THEIR MAIN POSITION'''

from collections import defaultdict, Counter

player_position_counts = defaultdict(Counter)


for match_id, events in all_events.items():
    for event in events:
        if event['type']['id'] == 35:  # Lineup
            for player in event['tactics']['lineup']:
                pid = player['player']['id']
                pos = player.get('position', {}).get('name')
                if pos:
                    player_position_counts[pid][pos] += 1

        elif event['type']['id'] == 19:  # Sub
            replacement = event['substitution']['replacement']
            pid = replacement['id']
            pos = replacement.get('position', {}).get('name')
            if pos:
                player_position_counts[pid][pos] += 1

for player in player_data:
    pid = player['player_id']
    position_counter = player_position_counts.get(pid, {})
    most_played = position_counter.most_common(1)[0][0] if position_counter else "Unknown"
    player['most_played_position'] = most_played

# %%
# Mapping function
def map_general_position(pos):
    pos = pos.lower()
    
    if pos == "goalkeeper":
        return "goalkeeper"
    
    elif pos in ["right back", "left back", "right wing back", "left wing back"]:
        return "full back"
    
    elif pos in ["center back", "right center back", "left center back"]:
        return "center back"
    
    elif "midfield" in pos:
        return "midfielder"
    
    elif pos in ["right wing", "left wing"]:
        return "winger"
    
    elif pos in ["striker", "center forward", "secondary striker", "right center forward", "left center forward"]:
        return "striker"
    
    return "other"  # fallback for unexpected cases

# %%
for player in player_data:
    specific_pos = player.get('most_played_position', 'Unknown')
    player['position'] = map_general_position(specific_pos)

# %%
other_count = sum(1 for player in player_data if player.get('position') == 'other')
print(f"Number of players with position 'other': {other_count}")
# Out:
# Number of players with position 'other': 49

# %% [raw]
# PASSING DATA

# %%
from collections import defaultdict

# Initialize stats containers per player
pass_stats = defaultdict(lambda: {
    'total_passes': 0,
    'completed_passes': 0,
    'progressive_passes': 0,
    'completed_progressive_passes': 0,
    'long_passes': 0,
    'completed_long_passes': 0,
    'crosses': 0,
    'completed_crosses': 0,
    'key_passes': 0,
    'assists': 0,
    'passes_received' : 0
})

def is_progressive_pass(start_x, end_x, pitch_length=100):
    # Determine progressive pass by x-coordinate movement closer to opponent goal
    if start_x < pitch_length / 2 and end_x < pitch_length / 2:
        return (end_x - start_x) >= 30
    elif (start_x < pitch_length / 2 and end_x >= pitch_length / 2) or (start_x >= pitch_length / 2 and end_x < pitch_length / 2):
        return (end_x - start_x) >= 15
    else:  # both in opponent half
        return (end_x - start_x) >= 10

def is_long_pass(length_yards, height_id):
    # Ground pass longer than 45m (~49.2 yards)
    # High pass longer than 25m (~27.3 yards)
    if height_id == 1:  # Ground Pass
        return length_yards >= 49.2
    elif height_id == 3:  # High Pass
        return length_yards >= 27.3
    return False

# Collect pass data
for match_id, events in all_events.items():
    for event in events:
        if event['type']['id'] == 30:  # Pass event
            pid = event['player']['id']
            # Completed pass if no outcome or outcome id is None
            completed = event.get('pass', {}).get('outcome', {}).get('id') is None
            length = event.get('pass', {}).get('length', 0)  # in yards
            height_id = event.get('pass', {}).get('height', {}).get('id', 1)  # default to ground pass if missing

            start_x = event.get('location', [0, 0])[0]
            end_x = event.get('pass', {}).get('end_location', [0, 0])[0]

            cross = event.get('pass', {}).get('cross', False)

            # Update total and completed passes
            pass_stats[pid]['total_passes'] += 1
            if completed:
                pass_stats[pid]['completed_passes'] += 1

            # Progressive passes
            if is_progressive_pass(start_x, end_x):
                pass_stats[pid]['progressive_passes'] += 1
                if completed:
                    pass_stats[pid]['completed_progressive_passes'] += 1

            # Long passes
            if is_long_pass(length, height_id):
                pass_stats[pid]['long_passes'] += 1
                if completed:
                    pass_stats[pid]['completed_long_passes'] += 1

            # Crosses
            if cross:
                pass_stats[pid]['crosses'] += 1
                if completed:
                    pass_stats[pid]['completed_crosses'] += 1

            # Key passes (assisted shot)
            if event.get('pass', {}).get('shot_assist', False):
                pass_stats[pid]['key_passes'] += 1

            # Assists (goal assists)
            if event.get('pass', {}).get('goal_assist', False):
                pass_stats[pid]['assists'] += 1
                
        elif event['type']['id'] == 42: #Ball receipt
            pid = event['player']['id']
            pass_stats[pid]['passes_received'] +=1

# %%
# Add passing stats per 90 minutes to player_data
for player in player_data:
    pid = player['player_id']
    minutes = player.get('minutes', 0)
    stats = pass_stats.get(pid, {})

    if minutes > 0:
        player['passes_per_90'] = stats.get('total_passes', 0) / (minutes / 90)
        player['pass_accuracy'] = (stats.get('completed_passes', 0) / max(stats.get('total_passes', 1), 1)) * 100

        player['progressive_passes_per_90'] = stats.get('progressive_passes', 0) / (minutes / 90)
        player['progressive_pass_accuracy'] = (stats.get('completed_progressive_passes', 0) / max(stats.get('progressive_passes', 1), 1)) * 100

        player['long_passes_per_90'] = stats.get('long_passes', 0) / (minutes / 90)
        player['long_pass_accuracy'] = (stats.get('completed_long_passes', 0) / max(stats.get('long_passes', 1), 1)) * 100

        player['crosses_per_90'] = stats.get('crosses', 0) / (minutes / 90)
        player['cross_accuracy'] = (stats.get('completed_crosses', 0) / max(stats.get('crosses', 1), 1)) * 100

        player['key_passes_per_90'] = stats.get('key_passes', 0) / (minutes / 90)
        player['assists_per_90'] = stats.get('assists', 0) / (minutes / 90)
        
        player['passes_received_per_90'] = stats.get('passes_received', 0) / (minutes/90)
    else:
        player['passes_per_90'] = 0
        player['pass_accuracy'] = 0
        player['progressive_passes_per_90'] = 0
        player['progressive_pass_accuracy'] = 0
        player['long_passes_per_90'] = 0
        player['long_pass_accuracy'] = 0
        player['crosses_per_90'] = 0
        player['cross_accuracy'] = 0
        player['key_passes_per_90'] = 0
        player['assists_per_90'] = 0
        player['passes_received_per_90'] = 0

# %% [raw]
# SHOT DATA

# %%
# Initialize data containers
player_shots = defaultdict(lambda: {
    'total_shots': 0,
    'shots_on_target': 0,
    'goals': 0,
    'xg': 0.0,
    'first_time_shots': 0,
    'headers': 0,
    'shots_outside_box': 0
})

# Pitch box boundaries (StatsBomb pitch is 120x80)
# The penalty box on the attacking side is approximately x >= 84 for shots inside the box
penalty_box_x = 84

for match_id, events in all_events.items():
    for event in events:
        if event['type']['id'] == 16:  # Shot event
            pid = event['player']['id']
            location = event.get('location', [0, 0])
            x, y = location
            
            # Count total shots
            player_shots[pid]['total_shots'] += 1
            
            # Check shot outcome
            outcome_id = event.get('shot', {}).get('outcome', {}).get('id')
            # On target if goal (97), saved (100), or saved to post (116)
            if outcome_id in [97, 100, 116]:
                player_shots[pid]['shots_on_target'] += 1
            
            # Count goals
            if outcome_id == 97:
                player_shots[pid]['goals'] += 1
            
            # Accumulate xG
            xg = event.get('shot', {}).get('statsbomb_xg', 0)
            player_shots[pid]['xg'] += xg
            
            # First time shots
            if event.get('shot', {}).get('first_time', False):
                player_shots[pid]['first_time_shots'] += 1
            
            # Headers
            body_part_id = event.get('shot', {}).get('body_part', {}).get('id')
            if body_part_id == 37:  # 37 corresponds to 'Head'
                player_shots[pid]['headers'] += 1
            
            # Shots from outside the box (x < penalty_box_x)
            if x < penalty_box_x:
                player_shots[pid]['shots_outside_box'] += 1

# %%
# Now calculate per 90 stats and accuracy and add to player_data
for player in player_data:
    pid = player['player_id']
    seconds_played = player.get('minutes', 0) * 60
    minutes_played = player.get('minutes', 0)
    if seconds_played == 0:
        # Avoid division by zero if no minutes played
        player.update({
            'shots_per_90': 0,
            'shots_on_target_per_90': 0,
            'shot_accuracy': 0,
            'goals_per_90': 0,
            'xg_per_90': 0,
            'first_time_shots_per_90': 0,
            'headers_per_90': 0,
            'shots_outside_box_per_90': 0
        })
        continue
    
    stats = player_shots.get(pid, {
        'total_shots': 0,
        'shots_on_target': 0,
        'goals': 0,
        'xg': 0.0,
        'first_time_shots': 0,
        'headers': 0,
        'shots_outside_box': 0
    })
    
    shots = stats['total_shots']
    shots_on_target = stats['shots_on_target']
    goals = stats['goals']
    xg = stats['xg']
    first_time = stats['first_time_shots']
    headers = stats['headers']
    shots_outside = stats['shots_outside_box']
    
    # Calculate accuracy (on target / total shots)
    accuracy = shots_on_target / shots if shots > 0 else 0
    
    player['shots_per_90'] = shots / minutes_played * 90
    player['shots_on_target_per_90'] = shots_on_target / minutes_played * 90
    player['shot_accuracy'] = round(accuracy, 3)
    player['goals_per_90'] = goals / minutes_played * 90
    player['xg_per_90'] = xg / minutes_played * 90
    player['first_time_shots_per_90'] = first_time / minutes_played * 90
    player['headers_per_90'] = headers / minutes_played * 90
    player['shots_outside_box_per_90'] = shots_outside / minutes_played * 90

# %%
print(player_data)
# Out:
# [{'player_id': 7498, 'name': 'Mickaël Tacalfred', 'minutes': 1798.03, 'most_played_position': 'Right Center Back', 'position': 'center back', 'passes_per_90': 29.882704960428914, 'pass_accuracy': 82.24455611390285, 'progressive_passes_per_90': 10.861887732685217, 'progressive_pass_accuracy': 61.75115207373272, 'long_passes_per_90': 5.756299950501382, 'long_pass_accuracy': 47.82608695652174, 'crosses_per_90': 0.15016434653481867, 'cross_accuracy': 33.33333333333333, 'key_passes_per_90': 0.10010956435654578, 'assists_per_90': 0.0, 'passes_received_per_90': 21.723775465370434, 'shots_per_90': 0.20021912871309153, 'shots_on_target_per_90': 0.05005478217827288, 'shot_accuracy': 0.25, 'goals_per_90': 0.0, 'xg_per_90': 0.010027853713786757, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.10010956435654576, 'shots_outside_box_per_90': 0.05005478217827288}, {'player_id': 7635, 'name': 'Gaëtan Charbonnier', 'minutes': 1748.55, 'most_played_position': 'Center Attacking Midfield', 'position': 'midfielder', 'passes_per_90': 29.59595093077121, 'pass_accuracy': 70.78260869565217, 'progressive_passes_per_90': 7.566269194475422, 'progressive_pass_accuracy': 52.38095238095239, 'long_passes_per_90': 2.1103199794115124, 'long_pass_accuracy': 36.58536585365854, 'crosses_per_90': 0.6691258471304795, 'cross_accuracy': 30.76923076923077, 'key_passes_per_90': 0.9264819421806639, 'assists_per_90': 0.05147121901003689, 'passes_received_per_90': 45.96379857596294, 'shots_per_90': 1.1323668182208115, 'shots_on_target_per_90': 0.46324097109033197, 'shot_accuracy': 0.409, 'goals_per_90': 0.20588487604014757, 'xg_per_90': 0.09168577953847476, 'first_time_shots_per_90': 0.3602985330702582, 'headers_per_90': 0.051471219010036894, 'shots_outside_box_per_90': 0.0}, {'player_id': 5477, 'name': 'Ousmane Dembélé', 'minutes': 2884.35, 'most_played_position': 'Right Wing', 'position': 'winger', 'passes_per_90': 22.40366113682459, 'pass_accuracy': 67.40947075208913, 'progressive_passes_per_90': 5.11727078891258, 'progressive_pass_accuracy': 46.34146341463415, 'long_passes_per_90': 2.8394612304332, 'long_pass_accuracy': 34.065934065934066, 'crosses_per_90': 1.6849550158614592, 'cross_accuracy': 20.37037037037037, 'key_passes_per_90': 1.1233033439076396, 'assists_per_90': 0.1560143533205055, 'passes_received_per_90': 36.28893858234958, 'shots_per_90': 1.7473607571896614, 'shots_on_target_per_90': 0.8424775079307297, 'shot_accuracy': 0.482, 'goals_per_90': 0.3744344479692132, 'xg_per_90': 0.2103175589723855, 'first_time_shots_per_90': 0.5616516719538198, 'headers_per_90': 0.062405741328202195, 'shots_outside_box_per_90': 0.0}, {'player_id': 5667, 'name': 'Kamil Grosicki', 'minutes': 2808.65, 'most_played_position': 'Right Wing', 'position': 'winger', 'passes_per_90': 20.89259964751749, 'pass_accuracy': 63.80368098159509, 'progressive_passes_per_90': 4.293877841667705, 'progressive_pass_accuracy': 47.01492537313433, 'long_passes_per_90': 2.8198600751250598, 'long_pass_accuracy': 31.818181818181817, 'crosses_per_90': 2.0187634628736224, 'cross_accuracy': 20.634920634920633, 'key_passes_per_90': 0.7370088832713225, 'assists_per_90': 0.0961315934701725, 'passes_received_per_90': 28.903565770031864, 'shots_per_90': 1.6662809534829899, 'shots_on_target_per_90': 0.76905274776138, 'shot_accuracy': 0.462, 'goals_per_90': 0.2883947804105175, 'xg_per_90': 0.1412030708251295, 'first_time_shots_per_90': 0.51270183184092, 'headers_per_90': 0.0320438644900575, 'shots_outside_box_per_90': 0.0320438644900575}, {'player_id': 7369, 'name': 'Aly Ndom', 'minutes': 609.45, 'most_played_position': 'Left Center Midfield', 'position': 'midfielder', 'passes_per_90': 26.433669702190496, 'pass_accuracy': 79.88826815642457, 'progressive_passes_per_90': 6.4976618262367705, 'progressive_pass_accuracy': 56.81818181818182, 'long_passes_per_90': 1.9197637213881367, 'long_pass_accuracy': 30.76923076923077, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.7383706620723602, 'assists_ ...

# %%
fields_to_check = [
    'minutes',
    'most_played_position',
    # Passing stats
    'passes_per_90',
    'pass_accuracy',
    'progressive_passes_per_90',
    'progressive_pass_accuracy',
    'long_passes_per_90',
    'long_pass_accuracy',
    'key_passes_per_90',
    'assists_per_90',
    'crosses_per_90',
    'cross_accuracy',
    # Shot stats
    'shots_per_90',
    'shots_on_target_per_90',
    'shot_accuracy',
    'goals_per_90',
    'xg_per_90',
    'first_time_shots_per_90',
    'headers_per_90',
    'shots_outside_box_per_90' 
]


missing_values = []

for player in player_data:
    for field in fields_to_check:
        if field not in player or player[field] is None:
            missing_values.append((player.get('player_id'), player.get('name'), field))

if missing_values:
    print(f"Missing values found for {len(missing_values)} fields:")
    for pid, name, field in missing_values:
        print(f"Player ID {pid} ({name}): Missing {field}")
else:
    print("No missing values found in checked fields.")
# Out:
# No missing values found in checked fields.

# %% [raw]
# Dribbling Data

# %%
# Dribble-related stats
dribble_stats = defaultdict(lambda: {
    'dribbles': 0,
    'successful_dribbles': 0,
    'progressive_runs': 0,
    'fouls_won': 0,
    'carry_distances' : []
})

def is_progressive_run(start_x, end_x, pitch_length=120):
    if start_x < pitch_length / 2 and end_x < pitch_length / 2:
        return (end_x - start_x) >= 30
    elif (start_x < pitch_length / 2 and end_x >= pitch_length / 2) or (start_x >= pitch_length / 2 and end_x < pitch_length / 2):
        return (end_x - start_x) >= 15
    else:
        return (end_x - start_x) >= 10

# Extract dribbling data
for match_id, events in all_events.items():
    for event in events:
        player = event.get('player')
        if not player:
            continue
        pid = player['id']
        etype = event['type']['id']

        if etype == 14:  # Dribble
            dribble_stats[pid]['dribbles'] += 1
            if event.get('dribble', {}).get('outcome', {}).get('id') == 8:
                dribble_stats[pid]['successful_dribbles'] += 1

        elif etype == 43:  # Carry
            start_x = event.get('location', [0, 0])[0]
            end_x = event.get('carry', {}).get('end_location', [0, 0])[0]
            if is_progressive_run(start_x, end_x):
                dribble_stats[pid]['progressive_runs'] += 1

        elif etype == 21:  # Foul Won
            dribble_stats[pid]['fouls_won'] += 1

# %%
for player in player_data:
    pid = player['player_id']
    minutes = player.get('minutes', 0)
    stats = dribble_stats.get(pid, {})

    if minutes > 0:
        factor = minutes / 90
        player['dribbles_per_90'] = stats.get('dribbles', 0) / factor
        player['successful_dribbles_per_90'] = stats.get('successful_dribbles', 0) / factor
        player['dribble_success_rate'] = (stats.get('successful_dribbles', 0) / max(stats.get('dribbles', 1), 1)) * 100
        player['progressive_runs_per_90'] = stats.get('progressive_runs', 0) / factor
        player['fouls_won_per_90'] = stats.get('fouls_won', 0) / factor
    else:
        player['dribbles_per_90'] = 0
        player['successful_dribbles_per_90'] = 0
        player['dribble_success_rate'] = 0
        player['progressive_runs_per_90'] = 0
        player['fouls_won_per_90'] = 0

# %% [raw]
# Defensive data

# %%
defensive_stats = defaultdict(lambda: {
    'pressures': 0,
    'blocks': 0,
    'interceptions': 0,
    'dribbled_past': 0,
    'clearances': 0,
    'ball_recoveries': 0,
    'fouls_made': 0,
    'yellow_cards': 0,
    'red_cards': 0,
    'duels': 0,
    'duels_won': 0
})

for match_id, events in all_events.items():
    for event in events:
        if 'player' not in event:
            continue

        pid = event['player']['id']
        etype = event['type']['id']

        if etype == 17:  # Pressure
            defensive_stats[pid]['pressures'] += 1
        elif etype == 2:  # Ball Recovery
            defensive_stats[pid]['ball_recoveries'] += 1
        elif etype == 4:  # Duel
            defensive_stats[pid]['duels'] += 1
            if event.get('duel', {}).get('outcome', {}).get('name') == 'Won':
                defensive_stats[pid]['duels_won'] += 1
        elif etype == 10:  # Interception
            defensive_stats[pid]['interceptions'] += 1
        elif etype == 22:  # Foul Committed (plus cards)
            defensive_stats[pid]['fouls_made'] += 1
            card = event.get('foul_committed', {}).get('card', {}).get('id')
            if card == 5:
                defensive_stats[pid]['yellow_cards'] += 1
            elif card == 6:
                defensive_stats[pid]['yellow_cards'] += 1
                defensive_stats[pid]['red_cards'] += 1
            elif card == 7:
                defensive_stats[pid]['red_cards'] += 1
        elif etype == 24:  # Bad Behaviour
            card = event.get('bad_behaviour', {}).get('card', {}).get('id')
            if card == 65:
                defensive_stats[pid]['yellow_cards'] += 1
            elif card == 66:
                defensive_stats[pid]['yellow_cards'] += 1
                defensive_stats[pid]['red_cards'] += 1
            elif card == 67:
                defensive_stats[pid]['red_cards'] += 1
        elif etype == 9:  # Clearance
            defensive_stats[pid]['clearances'] += 1
        elif etype == 6:  # Block
            defensive_stats[pid]['blocks'] += 1
        elif etype == 39:  # Dribbled Past
            defensive_stats[pid]['dribbled_past'] += 1

# %%
for player in player_data:
    pid = player['player_id']
    minutes = player.get('minutes', 0)
    stats = defensive_stats.get(pid, {})

    if minutes > 0:
        factor = minutes / 90
        player['pressures_per_90'] = stats.get('pressures', 0) / factor
        player['blocks_per_90'] = stats.get('blocks', 0) / factor
        player['interceptions_per_90'] = stats.get('interceptions', 0) / factor
        player['dribbled_past_per_90'] = stats.get('dribbled_past', 0) / factor
        player['clearances_per_90'] = stats.get('clearances', 0) / factor
        player['ball_recoveries_per_90'] = stats.get('ball_recoveries', 0) / factor
        player['fouls_made_per_90'] = stats.get('fouls_made', 0) / factor
        player['yellow_cards_per_90'] = stats.get('yellow_cards', 0) / factor
        player['red_cards_per_90'] = stats.get('red_cards', 0) / factor
        player['duels_per_90'] = stats.get('duels', 0) / factor
        player['duels_won_per_90'] = stats.get('duels_won', 0) / factor
        player['duel_success_rate'] = (stats.get('duels_won', 0) / max(stats.get('duels', 1), 1)) * 100
    else:
        player['pressures_per_90'] = 0
        player['blocks_per_90'] = 0
        player['interceptions_per_90'] = 0
        player['dribbled_past_per_90'] = 0
        player['clearances_per_90'] = 0
        player['ball_recoveries_per_90'] = 0
        player['fouls_made_per_90'] = 0
        player['yellow_cards_per_90'] = 0
        player['red_cards_per_90'] = 0
        player['duels_per_90'] = 0
        player['duels_won_per_90'] = 0
        player['duel_success_rate'] = 0

# %% [raw]
# Goalkeeper

# %%
import math

goalkeeping_stats = defaultdict(lambda: {
    'shots_faced': 0,
    'saves': 0,
    'close_range_saves': 0,
    'goals_conceded': 0,
    'smothers': 0,
    'collections': 0,
    'punches': 0,
    'sweeper_claims': 0,
    'sweeper_clears': 0,
    'successful_sweepers': 0,
    'successful_collections': 0,
    'successful_punches': 0,
    'successful_smothers': 0,
})

save_types = {29, 31, 33, 114, 110, 109}  # includes post saves, not 134 (off target)
goal_types = {26, 28}
shot_faced_types = save_types | goal_types | {32}  # include non-save faced shots
smother_type = 34
collection_types = {25, 49}  # includes "Collected" + "Collected Twice"
punch_types = {30, 117}
sweeper_type = 27

# Outcome categories
successful_outcomes = {15, 17, 47, 48, 49, 51, 53, 56, 59, 4, 16, 117}
fail_outcomes = {13, 14, 50, 52, 55, 58}

# Process events
for match_id, events in all_events.items():
    for event in events:
        if event['type']['id'] != 23:  # Not a goalkeeper event
            continue

        player = event.get('player')
        if not player:
            continue
        pid = player['id']
        gk_type = event['goalkeeper']['type']['id']
        outcome_id = event['goalkeeper'].get('outcome', {}).get('id')
        loc = event.get('location', [None, None])
        x = loc[0] if loc else None

        # Shots faced
        if gk_type in shot_faced_types:
            goalkeeping_stats[pid]['shots_faced'] += 1

        # Saves (including post saves, excluding off target saves)
        #if gk_type in save_types:
        #    goalkeeping_stats[pid]['saves'] += 1
          #  if x is not None and x <= 12:  # <12m assuming pitch 100 = 120m
           #     goalkeeping_stats[pid]['close_range_saves'] += 1
                
        # Goals conceded
        if gk_type in goal_types:
            goalkeeping_stats[pid]['goals_conceded'] += 1
            
        if gk_type in save_types:
            goalkeeping_stats[pid]['saves'] += 1

        # Smothers
        if gk_type == smother_type:
            goalkeeping_stats[pid]['smothers'] += 1
            if outcome_id in successful_outcomes:
                goalkeeping_stats[pid]['successful_smothers'] += 1

        # Collections
        if gk_type in collection_types:
            goalkeeping_stats[pid]['collections'] += 1
            if outcome_id in successful_outcomes:
                goalkeeping_stats[pid]['successful_collections'] += 1

        # Punches
        if gk_type in punch_types:
            goalkeeping_stats[pid]['punches'] += 1
            if outcome_id in successful_outcomes:
                goalkeeping_stats[pid]['successful_punches'] += 1

        # Sweeper actions
        if gk_type == sweeper_type:
            if outcome_id == 47:  # Claim
                goalkeeping_stats[pid]['sweeper_claims'] += 1
                if outcome_id in successful_outcomes:
                    goalkeeping_stats[pid]['successful_sweepers'] += 1
            elif outcome_id == 48:  # Clear
                goalkeeping_stats[pid]['sweeper_clears'] += 1
                if outcome_id in successful_outcomes:
                    goalkeeping_stats[pid]['successful_sweepers'] += 1

# %%
for player in player_data:
    pid = player['player_id']
    minutes = player.get('minutes', 0)

    if pid in goalkeeping_stats and minutes > 0:
        stats = goalkeeping_stats[pid]
        factor = minutes / 90

        player.update({

            # Per 90s
            'shots_faced_per_90': stats['shots_faced'] / factor,
            'saves_per_90': stats['saves'] / factor,
            'goals_conceded_per_90': stats['goals_conceded'] / factor,
            'smothers_per_90': stats['smothers'] / factor,
            'collections_per_90': stats['collections'] / factor,
            'punches_per_90': stats['punches'] / factor,
            'sweeper_claims_per_90': stats['sweeper_claims'] / factor,
            'sweeper_clears_per_90': stats['sweeper_clears'] / factor,

            # Success rates
            'save_percentage': (stats['saves'] / stats['shots_faced']) * 100 if stats['shots_faced'] else 0,
            'smother_success_rate': (stats['successful_smothers'] / stats['smothers']) * 100 if stats['smothers'] else 0,
            'collection_success_rate': (stats['successful_collections'] / stats['collections']) * 100 if stats['collections'] else 0,
            'punch_success_rate': (stats['successful_punches'] / stats['punches']) * 100 if stats['punches'] else 0,
            'sweeper_success_rate': (
                stats['successful_sweepers'] /
                (stats['sweeper_claims'] + stats['sweeper_clears'])
            ) * 100 if (stats['sweeper_claims'] + stats['sweeper_clears']) else 0
        })

# %%
for player in player_data:
    position = player.get('position', '').lower()
    if 'goalkeeper' in position or position == 'gk':
        print(player)
# Out:
# {'player_id': 3354, 'name': 'Benoît Guy Robert Costil', 'minutes': 4411.87, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 18.583956462905753, 'pass_accuracy': 60.1536772777168, 'progressive_passes_per_90': 12.198908852708717, 'progressive_pass_accuracy': 40.635451505016725, 'long_passes_per_90': 11.852117129471178, 'long_pass_accuracy': 40.103270223752155, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 6.058655400091118, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.040799026263239856, 'fouls_won_per_90': 0.06119853939485978, 'pressures_per_90': 0.040799026263239856, 'blocks_per_90': 0.020399513131619928, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.040799026263239856, 'ball_recoveries_per_90': 2.81513281216355, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.813013529410432, 'saves_per_90': 1.8767552081090333, 'goals_conceded_per_90': 0.8975785777912768, 'smothers_per_90': 0.0, 'collections_per_90': 0.7751814990015572, 'punches_per_90': 0.3875907495007786, 'sweeper_claims_per_90': 0.4487892888956384, 'sweeper_clears_per_90': 0.08159805252647971, 'save_percentage': 24.02088772845953, 'smother_success_rate': 0, 'collection_success_rate': 94.73684210526315, 'punch_success_rate': 68.42105263157895, 'sweeper_success_rate': 100.0}
# {'player_id': 7641, 'name': 'Johann Carrasso', 'minutes': 1423.77, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 17.13057586548389, 'pass_accuracy': 48.33948339483395, 'progressive_passes_per_90': 11.947154385890979, 'progressive_pass_accuracy': 28.57142857142857, 'long_passes_per_90': 12.326429128300218, 'long_pass_accuracy': 29.230769230769234, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 7.206220105775512, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.1264249141364125, 'pressures_per_90': 0.1264249141364125, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.06321245706820625, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.2124359973872183, 'fouls_made_per_90': 0.1264249141364125, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.1264249141364125, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.890157820434481, 'saves_per_90': 2.086011083250806, 'goals_conceded_per_90': 1.327461598432331, 'smothers_per_90': 0.06321245706820625, 'collections_per_90': 0.3160622853410312, 'punches_per_90': 0.3160622853410312, 'sweeper_claims_per_90': 0.4424871994774437, 'sweeper_clears_per_90': 0.3792747424092375, 'save_percentage': 30.275229357798167, 'smother_success_rate': 0.0, 'collection_success_rate': 100.0, 'punch_success_rate': 80.0, 'sweeper_success_rate': 100.0}
# {'player_id': 3008, 'name': 'Benjamin Lecomte', 'minutes': 5255.63, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 21.30286949423761, 'pass_accuracy': 56.91318327974276, 'progressive_passes_per_90': 14.042084393307748, 'progressive_pass_accuracy': 36.829268292682926, 'long_passes_per_90': 13.73384351638148, 'long_pass_accuracy': 35.16209476309227, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.051373479487711274, 'assists_per_90': 0.0, 'passes_received_per_90': 6.318937976988487, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.017124493162570423, 'fouls_won_per_90': 0.1541204384631338, 'pressures_per_90': 0.11987145213799297, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.10274695897542255, 'clearances_per_90': 0.017124493162570423, 'ball_recoveries_per_90': 3.270778194050951, 'fouls_made_per_90': 0.017124493162570423, 'yellow_cards_per_90': 0.017124493162570423, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 8.391001649659508, 'saves_per_90': 2.089188165833592, 'goals_conceded_per_90': 0.9075981376162324, 'smothers_per_90': 0.0, 'collections_per_90': 1.0788430692419366, 'punches_per_90': 0.47948580855197187, 'sweeper_claims_per_90': 0.7706021923156691, 'sweeper_clears_per_90': 0.2739918906011268, 'save_percentage': 24.897959183673468, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 85.71428571428571, 'sweeper_success_rate': 100.0}
# {'player_id': 3543, 'name': 'Steve Mandanda', 'minutes': 5120.1, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 24.310072068904905, 'pass_accuracy': 68.40202458423717, 'progressive_passes_per_90': 11.759535946563544, 'progressive_pass_accuracy': 37.369207772795214, 'long_passes_per_90': 12.111091580242574, 'long_pass_accuracy': 37.88098693759071, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 11.95289154508701, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.08788890841975742, 'pressures_per_90': 0.1054666901037089, 'blocks_per_90': 0.017577781683951486, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.3046229565828793, 'fouls_made_per_90': 0.05273334505185445, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.05273334505185445, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.013534891896643, 'saves_per_90': 1.6874670416593425, 'goals_conceded_per_90': 0.650377922306205, 'smothers_per_90': 0.017577781683951486, 'collections_per_90': 0.580066795570399, 'punches_per_90': 0.2285111618913693, 'sweeper_claims_per_90': 0.5097556688345931, 'sweeper_clears_per_90': 0.1230444717876604, 'save_percentage': 24.06015037593985, 'smother_success_rate': 0.0, 'collection_success_rate': 96.96969696969697, 'punch_success_rate': 84.61538461538461, 'sweeper_success_rate': 100.0}
# {'player_id': 401508, 'name': 'Clément Maury', 'minutes': 4693.33, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 24.372886628470617, 'pass_accuracy': 59.24468922108576, 'progressive_passes_per_90': 16.683250485263127, 'progressive_pass_accuracy': 42.183908045977006, 'long_passes_per_90': 16.91336428505986, 'long_pass_accuracy': 42.17687074829932, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.019176149983061067, 'assists_per_90': 0.019176149983061067, 'passes_received_per_90': 9.223728141852373, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.03835229996612213, 'successful_dribbles_per_90': 0.019176149983061067, 'dribble_success_rate': 50.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.07670459993224427, 'pressures_per_90': 0.26846609976285496, 'blocks_per_90': 0.019176149983061067, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.09588074991530533, 'clearances_per_90': 0.019176149983061067, 'ball_recoveries_per_90': 4.717332895833023, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.037647043783411, 'saves_per_90': 1.8025580984077403, 'goals_conceded_per_90': 0.9779836491361144, 'smothers_per_90': 0.09588074991530533, 'collections_per_90': 0.6328129494410152, 'punches_per_90': 0.49857989955958776, 'sweeper_claims_per_90': 0.7862221493055037, 'sweeper_clears_per_90': 0.3643468496781603, 'save_percentage': 25.61307901907357, 'smother_success_rate': 60.0, 'collection_success_rate': 96.96969696969697, 'punch_success_rate': 65.38461538461539, 'sweeper_success_rate': 100.0}
# {'player_id': 4259, 'name': 'Stéphane Ruffier', 'minutes': 5269.43, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 20.32477896091228, 'pass_accuracy': 59.66386554621849, 'progressive_passes_per_90': 11.716637283349431, 'progressive_pass_accuracy': 31.924198250728864, 'long_passes_per_90': 11.528761175307386, 'long_pass_accuracy': 30.37037037037037, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.01707964618564057, 'assists_per_90': 0.0, 'passes_received_per_90': 7.9078761839515845, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.051238938556921715, 'pressures_per_90': 0.03415929237128114, 'blocks_per_90': 0.03415929237128114, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.01707964618564057, 'clearances_per_90': 0.01707964618564057, 'ball_recoveries_per_90': 2.9889380824871, 'fouls_made_per_90': 0.03415929237128114, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.01707964618564057, 'duels_per_90': 0.03415929237128114, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.361327506011086, 'saves_per_90': 1.8787610804204629, 'goals_conceded_per_90': 0.59778761649742, 'smothers_per_90': 0.01707964618564057, 'collections_per_90': 0.49530973938357653, 'punches_per_90': 0.358672569898452, 'sweeper_claims_per_90': 0.5123893855692171, 'sweeper_clears_per_90': 0.20495575422768686, 'save_percentage': 25.52204176334107, 'smother_success_rate': 100.0, 'collection_success_rate': 100.0, 'punch_success_rate': 80.95238095238095, 'sweeper_success_rate': 100.0}
# {'player_id': 25377, 'name': 'Rémy Riou', 'minutes': 4435.87, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 21.3847565415578, 'pass_accuracy': 62.808349146110054, 'progressive_passes_per_90': 13.289388552865615, 'progressive_pass_accuracy': 42.74809160305343, 'long_passes_per_90': 13.228521124379208, 'long_pass_accuracy': 42.63803680981595, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.040578285657604934, 'assists_per_90': 0.0, 'passes_received_per_90': 8.298259416980208, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.040578285657604934, 'fouls_won_per_90': 0.10144571414401234, 'pressures_per_90': 0.1217348569728148, 'blocks_per_90': 0.040578285657604934, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.020289142828802467, 'clearances_per_90': 0.040578285657604934, 'ball_recoveries_per_90': 3.6317565663556413, 'fouls_made_per_90': 0.020289142828802467, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.2084777056135545, 'saves_per_90': 1.3999508551873703, 'goals_conceded_per_90': 0.6289634276928765, 'smothers_per_90': 0.040578285657604934, 'collections_per_90': 0.872433141638506, 'punches_per_90': 0.2840479996032345, 'sweeper_claims_per_90': 0.8521439988097036, 'sweeper_clears_per_90': 0.14202399980161726, 'save_percentage': 22.54901960784314, 'smother_success_rate': 100.0, 'collection_success_rate': 95.34883720930233, 'punch_success_rate': 71.42857142857143, 'sweeper_success_rate': 100.0}
# {'player_id': 36553, 'name': 'Matthieu Dreyer', 'minutes': 1986.73, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 20.204053897610645, 'pass_accuracy': 65.69506726457399, 'progressive_passes_per_90': 10.690934349408323, 'progressive_pass_accuracy': 36.440677966101696, 'long_passes_per_90': 10.328529795191093, 'long_pass_accuracy': 34.21052631578947, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.04530056927715392, 'assists_per_90': 0.0, 'passes_received_per_90': 4.892461481932623, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.09060113855430783, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.04530056927715392, 'ball_recoveries_per_90': 3.3975426957865436, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 10.64563378013117, 'saves_per_90': 2.6727335873520808, 'goals_conceded_per_90': 1.4496182168689253, 'smothers_per_90': 0.04530056927715392, 'collections_per_90': 0.49830626204869305, 'punches_per_90': 0.7248091084344627, 'sweeper_claims_per_90': 0.3171039849400774, 'sweeper_clears_per_90': 0.4077051234943852, 'save_percentage': 25.106382978723403, 'smother_success_rate': 100.0, 'collection_success_rate': 90.9090909090909, 'punch_success_rate': 81.25, 'sweeper_success_rate': 100.0}
# {'player_id': 4432, 'name': 'Yohann Pelé', 'minutes': 294.07, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 21.423470602237565, 'pass_accuracy': 85.71428571428571, 'progressive_passes_per_90': 4.590743700479478, 'progressive_pass_accuracy': 40.0, 'long_passes_per_90': 4.590743700479478, 'long_pass_accuracy': 40.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 11.017784881150748, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.060495800319652, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.427041180671269, 'saves_per_90': 1.8362974801917913, 'goals_conceded_per_90': 0.6120991600639304, 'smothers_per_90': 0.0, 'collections_per_90': 0.3060495800319652, 'punches_per_90': 0.3060495800319652, 'sweeper_claims_per_90': 0.6120991600639304, 'sweeper_clears_per_90': 0.3060495800319652, 'save_percentage': 28.57142857142857, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 0.0, 'sweeper_success_rate': 100.0}
# {'player_id': 7282, 'name': 'Jean-Louis Leca', 'minutes': 4616.88, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 22.164318760721525, 'pass_accuracy': 49.252418645558485, 'progressive_passes_per_90': 16.35520091490357, 'progressive_pass_accuracy': 33.373063170441, 'long_passes_per_90': 16.647606175599105, 'long_pass_accuracy': 33.723653395784545, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 7.23215678120289, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.1559494723709518, 'pressures_per_90': 0.09746842023184488, 'blocks_per_90': 0.019493684046368975, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.03898736809273795, 'clearances_per_90': 0.019493684046368975, 'ball_recoveries_per_90': 3.4893694443000465, 'fouls_made_per_90': 0.019493684046368975, 'yellow_cards_per_90': 0.019493684046368975, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.6083588917190825, 'saves_per_90': 1.6764568279877319, 'goals_conceded_per_90': 0.6237978894838072, 'smothers_per_90': 0.019493684046368975, 'collections_per_90': 1.1111399906430317, 'punches_per_90': 0.5263294692519623, 'sweeper_claims_per_90': 0.7017726256692831, 'sweeper_clears_per_90': 0.17544315641732078, 'save_percentage': 25.368731563421832, 'smother_success_rate': 100.0, 'collection_success_rate': 98.24561403508771, 'punch_success_rate': 88.88888888888889, 'sweeper_success_rate': 100.0}
# {'player_id': 40533, 'name': 'Cédric Carrasso', 'minutes': 2678.73, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.52044438969213, 'pass_accuracy': 60.24096385542169, 'progressive_passes_per_90': 12.666450146151348, 'progressive_pass_accuracy': 40.84880636604775, 'long_passes_per_90': 12.767244179144596, 'long_pass_accuracy': 40.526315789473685, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 7.492356452498012, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.03359801099774894, 'fouls_won_per_90': 0.03359801099774894, 'pressures_per_90': 0.0, 'blocks_per_90': 0.06719602199549787, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.3262030887771443, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.652406177554289, 'saves_per_90': 1.9486846378694382, 'goals_conceded_per_90': 0.9071462969392212, 'smothers_per_90': 0.03359801099774894, 'collections_per_90': 0.3023820989797404, 'punches_per_90': 0.33598010997748934, 'sweeper_claims_per_90': 0.3023820989797404, 'sweeper_clears_per_90': 0.16799005498874467, 'save_percentage': 29.292929292929294, 'smother_success_rate': 0.0, 'collection_success_rate': 88.88888888888889, 'punch_success_rate': 70.0, 'sweeper_success_rate': 100.0}
# {'player_id': 4509, 'name': 'Jérôme Prior', 'minutes': 1615.85, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 21.109632701055176, 'pass_accuracy': 54.61741424802111, 'progressive_passes_per_90': 16.430980598446638, 'progressive_pass_accuracy': 42.3728813559322, 'long_passes_per_90': 16.542377077080175, 'long_pass_accuracy': 42.08754208754209, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 8.187641179564936, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.05569823931676827, 'fouls_won_per_90': 0.05569823931676827, 'pressures_per_90': 0.1670947179503048, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.05569823931676827, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.119101401739023, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 5.959711606894205, 'saves_per_90': 1.838041897453353, 'goals_conceded_per_90': 0.3898876752173779, 'smothers_per_90': 0.05569823931676827, 'collections_per_90': 0.7240771111179876, 'punches_per_90': 0.8911718290682923, 'sweeper_claims_per_90': 0.5012841538509144, 'sweeper_clears_per_90': 0.0, 'save_percentage': 30.8411214953271, 'smother_success_rate': 0.0, 'collection_success_rate': 100.0, 'punch_success_rate': 93.75, 'sweeper_success_rate': 100.0}
# {'player_id': 2947, 'name': 'Anthony Lopes', 'minutes': 5278.6, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 18.15822377145455, 'pass_accuracy': 71.36150234741784, 'progressive_passes_per_90': 7.672488917516008, 'progressive_pass_accuracy': 34.44444444444444, 'long_passes_per_90': 7.672488917516008, 'long_pass_accuracy': 33.55555555555556, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 7.007539877997954, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.017049975372257796, 'successful_dribbles_per_90': 0.017049975372257796, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.13639980297806237, 'pressures_per_90': 0.06819990148903118, 'blocks_per_90': 0.03409995074451559, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.017049975372257796, 'clearances_per_90': 0.06819990148903118, 'ball_recoveries_per_90': 2.830295911794794, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.120941158640548, 'saves_per_90': 1.7902474140870686, 'goals_conceded_per_90': 0.6990489902625696, 'smothers_per_90': 0.03409995074451559, 'collections_per_90': 0.6137991134012806, 'punches_per_90': 0.3068995567006403, 'sweeper_claims_per_90': 0.750198916379343, 'sweeper_clears_per_90': 0.2557496305838669, 'save_percentage': 29.247910863509752, 'smother_success_rate': 0.0, 'collection_success_rate': 97.22222222222221, 'punch_success_rate': 66.66666666666666, 'sweeper_success_rate': 100.0}
# {'player_id': 3444, 'name': 'Danijel Subašić', 'minutes': 5131.87, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 17.02888031068597, 'pass_accuracy': 59.11431513903192, 'progressive_passes_per_90': 11.153828916165063, 'progressive_pass_accuracy': 39.46540880503145, 'long_passes_per_90': 11.118753982466432, 'long_pass_accuracy': 38.958990536277604, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.017537466849316136, 'assists_per_90': 0.0, 'passes_received_per_90': 5.31385245534279, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.05261240054794841, 'successful_dribbles_per_90': 0.05261240054794841, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.03507493369863227, 'pressures_per_90': 0.08768733424658069, 'blocks_per_90': 0.03507493369863227, 'interceptions_per_90': 0.017537466849316136, 'dribbled_past_per_90': 0.017537466849316136, 'clearances_per_90': 0.017537466849316136, 'ball_recoveries_per_90': 2.6306200273974207, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 8.154922084932004, 'saves_per_90': 2.139570955616569, 'goals_conceded_per_90': 0.8593358756164907, 'smothers_per_90': 0.017537466849316136, 'collections_per_90': 0.6664237402740132, 'punches_per_90': 0.29813693643837436, 'sweeper_claims_per_90': 0.35074933698632277, 'sweeper_clears_per_90': 0.08768733424658069, 'save_percentage': 26.236559139784948, 'smother_success_rate': 0.0, 'collection_success_rate': 94.73684210526315, 'punch_success_rate': 70.58823529411765, 'sweeper_success_rate': 100.0}
# {'player_id': 3322, 'name': 'Jonas Lössl', 'minutes': 5280.17, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.005069912521755, 'pass_accuracy': 54.88789237668161, 'progressive_passes_per_90': 13.482520449152204, 'progressive_pass_accuracy': 38.05309734513274, 'long_passes_per_90': 13.226846862885097, 'long_pass_accuracy': 37.11340206185567, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 5.028247196586474, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.017044905751140586, 'successful_dribbles_per_90': 0.017044905751140586, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.03408981150228117, 'fouls_won_per_90': 0.10226943450684353, 'pressures_per_90': 0.03408981150228117, 'blocks_per_90': 0.017044905751140586, 'interceptions_per_90': 0.017044905751140586, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.562385301988383, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 8.232689477800903, 'saves_per_90': 1.9601641613811676, 'goals_conceded_per_90': 0.86929019330817, 'smothers_per_90': 0.017044905751140586, 'collections_per_90': 0.9886045335661541, 'punches_per_90': 0.28976339776939, 'sweeper_claims_per_90': 0.7158860415479047, 'sweeper_clears_per_90': 0.17044905751140588, 'save_percentage': 23.809523809523807, 'smother_success_rate': 0.0, 'collection_success_rate': 98.27586206896551, 'punch_success_rate': 82.35294117647058, 'sweeper_success_rate': 100.0}
# {'player_id': 4440, 'name': 'Kevin Trapp', 'minutes': 4705.7, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 16.77327496440487, 'pass_accuracy': 84.60661345496008, 'progressive_passes_per_90': 4.915315468474404, 'progressive_pass_accuracy': 49.416342412451364, 'long_passes_per_90': 5.030069915209214, 'long_pass_accuracy': 50.19011406844106, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 7.459039037762714, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.057377223367405486, 'pressures_per_90': 0.07650296448987398, 'blocks_per_90': 0.019125741122468495, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.019125741122468495, 'ball_recoveries_per_90': 1.9508255944917867, 'fouls_made_per_90': 0.019125741122468495, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 5.986356971332639, 'saves_per_90': 1.5683107720424168, 'goals_conceded_per_90': 0.34426334020443294, 'smothers_per_90': 0.019125741122468495, 'collections_per_90': 0.6311494570414604, 'punches_per_90': 0.09562870561234248, 'sweeper_claims_per_90': 0.2868861168370274, 'sweeper_clears_per_90': 0.07650296448987398, 'save_percentage': 26.198083067092654, 'smother_success_rate': 100.0, 'collection_success_rate': 90.9090909090909, 'punch_success_rate': 100.0, 'sweeper_success_rate': 100.0}
# {'player_id': 3432, 'name': 'Alexandre Letellier', 'minutes': 2405.43, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 17.62262880233472, 'pass_accuracy': 60.29723991507431, 'progressive_passes_per_90': 12.19740337486437, 'progressive_pass_accuracy': 43.86503067484663, 'long_passes_per_90': 12.122572679313055, 'long_pass_accuracy': 43.51851851851852, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.07483069555131516, 'assists_per_90': 0.0, 'passes_received_per_90': 4.863995210835485, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.14966139110263033, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.6190743442960307, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.295992816253228, 'saves_per_90': 1.945598084334194, 'goals_conceded_per_90': 0.8605529988401244, 'smothers_per_90': 0.0, 'collections_per_90': 0.972799042167097, 'punches_per_90': 0.33673812998091823, 'sweeper_claims_per_90': 0.5238148688592061, 'sweeper_clears_per_90': 0.07483069555131516, 'save_percentage': 26.666666666666668, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 66.66666666666666, 'sweeper_success_rate': 100.0}
# {'player_id': 40645, 'name': 'Laurent Pionnier', 'minutes': 3551.07, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 17.284931020790918, 'pass_accuracy': 56.158357771260995, 'progressive_passes_per_90': 11.861213662360923, 'progressive_pass_accuracy': 36.965811965811966, 'long_passes_per_90': 11.835869188723398, 'long_pass_accuracy': 36.402569593147746, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.05068894727504668, 'assists_per_90': 0.0, 'passes_received_per_90': 5.296994990242378, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.02534447363752334, 'successful_dribbles_per_90': 0.02534447363752334, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.10137789455009336, 'pressures_per_90': 0.07603342091257001, 'blocks_per_90': 0.02534447363752334, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.05068894727504668, 'clearances_per_90': 0.02534447363752334, 'ball_recoveries_per_90': 3.218748151965464, 'fouls_made_per_90': 0.02534447363752334, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.02534447363752334, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.640252093031115, 'saves_per_90': 1.5460128918889235, 'goals_conceded_per_90': 0.7349897354881768, 'smothers_per_90': 0.02534447363752334, 'collections_per_90': 0.6589563145756068, 'punches_per_90': 0.7856786827632235, 'sweeper_claims_per_90': 0.6589563145756068, 'sweeper_clears_per_90': 0.4055115782003734, 'save_percentage': 23.282442748091604, 'smother_success_rate': 0.0, 'collection_success_rate': 96.15384615384616, 'punch_success_rate': 77.41935483870968, 'sweeper_success_rate': 100.0}
# {'player_id': 2981, 'name': 'Alban Lafont', 'minutes': 3350.15, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 18.482754503529694, 'pass_accuracy': 48.69186046511628, 'progressive_passes_per_90': 12.572571377401013, 'progressive_pass_accuracy': 27.564102564102566, 'long_passes_per_90': 12.814351596197186, 'long_pass_accuracy': 27.67295597484277, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 5.560945032311986, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.29550915630643404, 'pressures_per_90': 0.02686446875513037, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.02686446875513037, 'clearances_per_90': 0.02686446875513037, 'ball_recoveries_per_90': 3.65356775069773, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.984761876333896, 'saves_per_90': 1.370087906511649, 'goals_conceded_per_90': 0.72534065638852, 'smothers_per_90': 0.02686446875513037, 'collections_per_90': 0.5104249063474771, 'punches_per_90': 0.4835604375923466, 'sweeper_claims_per_90': 0.37610256257182517, 'sweeper_clears_per_90': 0.18805128128591259, 'save_percentage': 19.615384615384617, 'smother_success_rate': 100.0, 'collection_success_rate': 89.47368421052632, 'punch_success_rate': 66.66666666666666, 'sweeper_success_rate': 100.0}
# {'player_id': 40484, 'name': 'Vincent Enyeama', 'minutes': 5011.97, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.644969941958948, 'pass_accuracy': 59.41499085923218, 'progressive_passes_per_90': 12.498079597443718, 'progressive_pass_accuracy': 37.212643678160916, 'long_passes_per_90': 12.372380521032646, 'long_pass_accuracy': 36.284470246734394, 'crosses_per_90': 0.017957010915867412, 'cross_accuracy': 100.0, 'key_passes_per_90': 0.017957010915867412, 'assists_per_90': 0.0, 'passes_received_per_90': 6.9673202353565555, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.07182804366346965, 'pressures_per_90': 0.1616130982428067, 'blocks_per_90': 0.053871032747602236, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.035914021831734824, 'clearances_per_90': 0.035914021831734824, 'ball_recoveries_per_90': 3.1963479430243993, 'fouls_made_per_90': 0.017957010915867412, 'yellow_cards_per_90': 0.017957010915867412, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.374738875132931, 'saves_per_90': 1.6879590260915367, 'goals_conceded_per_90': 0.4309682619808179, 'smothers_per_90': 0.07182804366346965, 'collections_per_90': 0.8619365239616358, 'punches_per_90': 0.520753316560155, 'sweeper_claims_per_90': 0.5027963056442876, 'sweeper_clears_per_90': 0.08978505457933705, 'save_percentage': 26.478873239436616, 'smother_success_rate': 50.0, 'collection_success_rate': 97.91666666666666, 'punch_success_rate': 72.41379310344827, 'sweeper_success_rate': 100.0}
# {'player_id': 2963, 'name': 'Rémy Vercoutre', 'minutes': 5384.27, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 17.41740291627277, 'pass_accuracy': 55.5662188099808, 'progressive_passes_per_90': 14.559076717920904, 'progressive_pass_accuracy': 47.876004592422504, 'long_passes_per_90': 14.391923139069918, 'long_pass_accuracy': 47.386759581881535, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 4.279131618585248, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.016715357885098626, 'successful_dribbles_per_90': 0.016715357885098626, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.016715357885098626, 'fouls_won_per_90': 0.08357678942549314, 'pressures_per_90': 0.050146073655295886, 'blocks_per_90': 0.016715357885098626, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.016715357885098626, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.008764419317753, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 8.006656426962243, 'saves_per_90': 2.0559890198671313, 'goals_conceded_per_90': 0.8357678942549314, 'smothers_per_90': 0.050146073655295886, 'collections_per_90': 0.4513146628976629, 'punches_per_90': 0.46803002078276157, 'sweeper_claims_per_90': 0.3677378734721698, 'sweeper_clears_per_90': 0.20058429462118355, 'save_percentage': 25.678496868475992, 'smother_success_rate': 100.0, 'collection_success_rate': 100.0, 'punch_success_rate': 92.85714285714286, 'sweeper_success_rate': 100.0}
# {'player_id': 7269, 'name': 'Nicolas Douchez', 'minutes': 139.63, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 21.2705006087517, 'pass_accuracy': 90.9090909090909, 'progressive_passes_per_90': 2.578242498030509, 'progressive_pass_accuracy': 50.0, 'long_passes_per_90': 2.578242498030509, 'long_pass_accuracy': 50.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 7.734727494091528, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.578242498030509, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 9.66840936761441, 'saves_per_90': 1.933681873522882, 'goals_conceded_per_90': 0.0, 'smothers_per_90': 0.0, 'collections_per_90': 1.933681873522882, 'punches_per_90': 0.0, 'sweeper_claims_per_90': 0.6445606245076273, 'sweeper_clears_per_90': 0.0, 'save_percentage': 20.0, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 0, 'sweeper_success_rate': 100.0}
# {'player_id': 4377, 'name': 'Maxime Dupé', 'minutes': 987.03, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 21.154372207531686, 'pass_accuracy': 60.775862068965516, 'progressive_passes_per_90': 12.58320415792833, 'progressive_pass_accuracy': 34.78260869565217, 'long_passes_per_90': 12.400838880277195, 'long_pass_accuracy': 33.088235294117645, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 7.0210631895687055, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.27354791647670285, 'pressures_per_90': 0.09118263882556761, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.920853469499407, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 9.027081243731192, 'saves_per_90': 3.009027081243731, 'goals_conceded_per_90': 1.0030090270812437, 'smothers_per_90': 0.0, 'collections_per_90': 1.0941916659068114, 'punches_per_90': 0.45591319412783804, 'sweeper_claims_per_90': 0.45591319412783804, 'sweeper_clears_per_90': 0.18236527765113522, 'save_percentage': 33.33333333333333, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 60.0, 'sweeper_success_rate': 100.0}
# {'player_id': 4257, 'name': 'Yoan Cardinale', 'minutes': 3604.67, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 17.87680980505844, 'pass_accuracy': 68.57541899441341, 'progressive_passes_per_90': 8.189376558741854, 'progressive_pass_accuracy': 33.53658536585366, 'long_passes_per_90': 8.03957088998438, 'long_pass_accuracy': 31.67701863354037, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 6.716287482626703, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.024967611459578824, 'successful_dribbles_per_90': 0.024967611459578824, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.024967611459578824, 'fouls_won_per_90': 0.1997408916766306, 'pressures_per_90': 0.12483805729789411, 'blocks_per_90': 0.024967611459578824, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.0210809866090376, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.024967611459578824, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.265574934737438, 'saves_per_90': 1.8226356365492542, 'goals_conceded_per_90': 0.6491578979490494, 'smothers_per_90': 0.024967611459578824, 'collections_per_90': 0.49935222919157646, 'punches_per_90': 0.49935222919157646, 'sweeper_claims_per_90': 0.3994817833532612, 'sweeper_clears_per_90': 0.12483805729789411, 'save_percentage': 25.085910652920962, 'smother_success_rate': 100.0, 'collection_success_rate': 100.0, 'punch_success_rate': 55.00000000000001, 'sweeper_success_rate': 100.0}
# {'player_id': 3980, 'name': 'Johny Placide', 'minutes': 2614.38, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 18.761618433433547, 'pass_accuracy': 55.04587155963303, 'progressive_passes_per_90': 12.840520505817821, 'progressive_pass_accuracy': 35.924932975871315, 'long_passes_per_90': 12.771670529915314, 'long_pass_accuracy': 36.118598382749326, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.03442498795125421, 'assists_per_90': 0.0, 'passes_received_per_90': 6.12764785532325, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.17212493975627108, 'pressures_per_90': 0.03442498795125421, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.03442498795125421, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.545773758979184, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.470222385422164, 'saves_per_90': 1.5835494457576937, 'goals_conceded_per_90': 0.7229247469763385, 'smothers_per_90': 0.03442498795125421, 'collections_per_90': 0.8606246987813554, 'punches_per_90': 0.481949831317559, 'sweeper_claims_per_90': 0.5852247951713216, 'sweeper_clears_per_90': 0.2409749156587795, 'save_percentage': 21.19815668202765, 'smother_success_rate': 100.0, 'collection_success_rate': 92.0, 'punch_success_rate': 85.71428571428571, 'sweeper_success_rate': 100.0}
# {'player_id': 401454, 'name': 'Kossi Agassa', 'minutes': 1382.4, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 21.875, 'pass_accuracy': 64.88095238095238, 'progressive_passes_per_90': 13.932291666666666, 'progressive_pass_accuracy': 46.728971962616825, 'long_passes_per_90': 13.411458333333332, 'long_pass_accuracy': 44.1747572815534, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 6.380208333333333, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.13020833333333331, 'pressures_per_90': 0.19531249999999997, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.13020833333333331, 'clearances_per_90': 0.06510416666666666, 'ball_recoveries_per_90': 3.255208333333333, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 8.333333333333332, 'saves_per_90': 2.1484375, 'goals_conceded_per_90': 0.8463541666666666, 'smothers_per_90': 0.0, 'collections_per_90': 1.3020833333333333, 'punches_per_90': 0.39062499999999994, 'sweeper_claims_per_90': 0.8463541666666666, 'sweeper_clears_per_90': 0.26041666666666663, 'save_percentage': 25.78125, 'smother_success_rate': 0, 'collection_success_rate': 95.0, 'punch_success_rate': 66.66666666666666, 'sweeper_success_rate': 100.0}
# ...
# {'player_id': 4803, 'name': 'Mathieu Gorgelin', 'minutes': 141.57, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.70756516211062, 'pass_accuracy': 48.38709677419355, 'progressive_passes_per_90': 11.44310235219326, 'progressive_pass_accuracy': 16.666666666666664, 'long_passes_per_90': 11.44310235219326, 'long_pass_accuracy': 16.666666666666664, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 3.178639542275906, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.6357279084551812, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.8143674507310874, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 5.72155117609663, 'saves_per_90': 1.9071837253655437, 'goals_conceded_per_90': 0.0, 'smothers_per_90': 0.0, 'collections_per_90': 1.2714558169103625, 'punches_per_90': 1.2714558169103625, 'sweeper_claims_per_90': 0.6357279084551812, 'sweeper_clears_per_90': 0.0, 'save_percentage': 33.33333333333333, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 50.0, 'sweeper_success_rate': 100.0}
# {'player_id': 41385, 'name': 'Ali Nadhoim Ahamada', 'minutes': 850.63, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 12.908079893725827, 'pass_accuracy': 50.0, 'progressive_passes_per_90': 8.252706817300119, 'progressive_pass_accuracy': 23.076923076923077, 'long_passes_per_90': 8.570118617965509, 'long_pass_accuracy': 24.691358024691358, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 3.5973337408744106, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.385725873764151, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.665647813973173, 'saves_per_90': 1.7986668704372053, 'goals_conceded_per_90': 1.5870590033269458, 'smothers_per_90': 0.0, 'collections_per_90': 0.5290196677756487, 'punches_per_90': 0.4232157342205189, 'sweeper_claims_per_90': 0.3174118006653892, 'sweeper_clears_per_90': 0.0, 'save_percentage': 26.984126984126984, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 75.0, 'sweeper_success_rate': 100.0}
# {'player_id': 22130, 'name': 'Mauro Daniel Goicoechea Furia', 'minutes': 1209.22, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 18.309323365475265, 'pass_accuracy': 47.96747967479675, 'progressive_passes_per_90': 12.801640727080267, 'progressive_pass_accuracy': 27.325581395348834, 'long_passes_per_90': 13.099353302128645, 'long_pass_accuracy': 27.84090909090909, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 5.433254494632903, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.14885628752418914, 'pressures_per_90': 0.07442814376209457, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.753841319197499, 'fouls_made_per_90': 0.07442814376209457, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.07442814376209457, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.145101801161079, 'saves_per_90': 1.414134731479797, 'goals_conceded_per_90': 0.8931377251451349, 'smothers_per_90': 0.22328443128628372, 'collections_per_90': 0.2977125750483783, 'punches_per_90': 0.5954251500967566, 'sweeper_claims_per_90': 0.6698532938588512, 'sweeper_clears_per_90': 0.07442814376209457, 'save_percentage': 19.791666666666664, 'smother_success_rate': 66.66666666666666, 'collection_success_rate': 100.0, 'punch_success_rate': 100.0, 'sweeper_success_rate': 100.0}
# {'player_id': 28357, 'name': 'Thomas Vincensini', 'minutes': 228.2, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 18.536371603856267, 'pass_accuracy': 38.297872340425535, 'progressive_passes_per_90': 16.564417177914113, 'progressive_pass_accuracy': 30.952380952380953, 'long_passes_per_90': 15.77563540753725, 'long_pass_accuracy': 27.500000000000004, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 1.577563540753725, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.39439088518843124, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.9439088518843124, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.493426818580193, 'saves_per_90': 2.3663453111305874, 'goals_conceded_per_90': 0.39439088518843124, 'smothers_per_90': 0.0, 'collections_per_90': 0.0, 'punches_per_90': 0.39439088518843124, 'sweeper_claims_per_90': 0.7887817703768625, 'sweeper_clears_per_90': 0.0, 'save_percentage': 31.57894736842105, 'smother_success_rate': 0, 'collection_success_rate': 0, 'punch_success_rate': 0.0, 'sweeper_success_rate': 100.0}
# {'player_id': 24469, 'name': 'Jesper Hansen', 'minutes': 518.48, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.788612868384508, 'pass_accuracy': 41.228070175438596, 'progressive_passes_per_90': 14.233914519364294, 'progressive_pass_accuracy': 18.29268292682927, 'long_passes_per_90': 14.060330195957413, 'long_pass_accuracy': 17.28395061728395, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 5.033945378799568, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.430180527696343, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 10.067890757599136, 'saves_per_90': 2.0830118808825797, 'goals_conceded_per_90': 1.0415059404412899, 'smothers_per_90': 0.17358432340688165, 'collections_per_90': 0.17358432340688165, 'punches_per_90': 0.8679216170344082, 'sweeper_claims_per_90': 0.6943372936275266, 'sweeper_clears_per_90': 0.0, 'save_percentage': 20.689655172413794, 'smother_success_rate': 100.0, 'collection_success_rate': 100.0, 'punch_success_rate': 80.0, 'sweeper_success_rate': 100.0}
# {'player_id': 24021, 'name': 'Paul Nardi', 'minutes': 282.77, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 14.004314460515616, 'pass_accuracy': 81.81818181818183, 'progressive_passes_per_90': 4.455918237436786, 'progressive_pass_accuracy': 57.14285714285714, 'long_passes_per_90': 4.137638363334159, 'long_pass_accuracy': 53.84615384615385, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 6.365597482052553, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.5913993705131382, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 5.0924779856420415, 'saves_per_90': 0.9548396223078829, 'goals_conceded_per_90': 0.0, 'smothers_per_90': 0.0, 'collections_per_90': 0.0, 'punches_per_90': 0.0, 'sweeper_claims_per_90': 0.0, 'sweeper_clears_per_90': 0.0, 'save_percentage': 18.75, 'smother_success_rate': 0, 'collection_success_rate': 0, 'punch_success_rate': 0, 'sweeper_success_rate': 0}
# {'player_id': 3761, 'name': 'Mike Maignan', 'minutes': 505.9, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 16.366870923107335, 'pass_accuracy': 70.65217391304348, 'progressive_passes_per_90': 6.760229294326943, 'progressive_pass_accuracy': 31.57894736842105, 'long_passes_per_90': 6.760229294326943, 'long_pass_accuracy': 31.57894736842105, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 6.760229294326943, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.3558015418066812, 'successful_dribbles_per_90': 0.3558015418066812, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.558015418066812, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 5.6928246689068995, 'saves_per_90': 1.779007709033406, 'goals_conceded_per_90': 0.5337023127100218, 'smothers_per_90': 0.0, 'collections_per_90': 0.1779007709033406, 'punches_per_90': 0.1779007709033406, 'sweeper_claims_per_90': 0.5337023127100218, 'sweeper_clears_per_90': 0.3558015418066812, 'save_percentage': 31.25, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 100.0, 'sweeper_success_rate': 100.0}
# {'player_id': 401467, 'name': 'Florent Chaigneau', 'minutes': 277.3, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.79805265055896, 'pass_accuracy': 49.18032786885246, 'progressive_passes_per_90': 12.982329606923908, 'progressive_pass_accuracy': 22.5, 'long_passes_per_90': 12.65777136675081, 'long_pass_accuracy': 20.51282051282051, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 4.543815362423368, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 4.543815362423368, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 8.113956004327443, 'saves_per_90': 2.921024161557879, 'goals_conceded_per_90': 1.6227912008654886, 'smothers_per_90': 0.0, 'collections_per_90': 0.9736747205192932, 'punches_per_90': 0.6491164803461954, 'sweeper_claims_per_90': 0.6491164803461954, 'sweeper_clears_per_90': 0.6491164803461954, 'save_percentage': 36.0, 'smother_success_rate': 0, 'collection_success_rate': 66.66666666666666, 'punch_success_rate': 100.0, 'sweeper_success_rate': 100.0}
# {'player_id': 2967, 'name': 'Mamadou Samassa', 'minutes': 144.83, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.263964648208244, 'pass_accuracy': 51.61290322580645, 'progressive_passes_per_90': 15.53545536145826, 'progressive_pass_accuracy': 44.0, 'long_passes_per_90': 16.156873575916592, 'long_pass_accuracy': 42.30769230769231, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 3.7285092867499823, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.7285092867499823, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.835600359041635, 'saves_per_90': 1.242836428916661, 'goals_conceded_per_90': 0.6214182144583305, 'smothers_per_90': 0.0, 'collections_per_90': 1.8642546433749911, 'punches_per_90': 0.6214182144583305, 'sweeper_claims_per_90': 0.0, 'sweeper_clears_per_90': 0.0, 'save_percentage': 18.181818181818183, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 100.0, 'sweeper_success_rate': 0}

# %% [raw]
# Involvement data

# %%
# Define event type IDs that count as touches
# (You should adjust this list based on your event types)
touch_event_types = {
    42, # Reception
    2, # Recovery
    3, # Dispossessed
    4, # Duel
    6, # Block
    9, # Clearance
    10,  # Interception
    14,  # Dribble 
    16, # Shot
    21, # Foul Won
    23, #Goalkeeper
    30, # Pass
    33, #50-50
    37, #Error
    38, # Miscontrol
    43, # Carry
    
    # Add other event IDs that mean ball touch here
}

other_stats = defaultdict(lambda: {
    'x_total': 0.0,
    'y_total': 0.0,
    'touches': 0
})

for match_id, events in all_events.items():
    for event in events:
        player = event.get('player')
        location = event.get('location')
        etype = event.get('type', {}).get('id')

        # Skip if no player, location, or type
        if not player or not location or len(location) < 2 or etype not in touch_event_types:
            continue

        pid = player['id']
        x, y = location[0], location[1]

        other_stats[pid]['x_total'] += x
        other_stats[pid]['y_total'] += y
        other_stats[pid]['touches'] += 1

# %%
# Add to player data
for player in player_data:
    pid = player['player_id']
    minutes = player.get('minutes', 0)
    stats = other_stats.get(pid, {})

    if minutes > 0 and stats.get('touches', 0) > 0:
        factor = minutes / 90
        player['touches_per_90'] = stats['touches'] / factor
        player['average_position_x'] = stats['x_total'] / stats['touches']
        player['average_position_y'] = stats['y_total'] / stats['touches']
    else:
        player['touches_per_90'] = 0
        player['average_position_x'] = None
        player['average_position_y'] = None

# %%
print(player_data)
# Out:
# [{'player_id': 7498, 'name': 'Mickaël Tacalfred', 'minutes': 1798.03, 'most_played_position': 'Right Center Back', 'position': 'center back', 'passes_per_90': 29.882704960428914, 'pass_accuracy': 82.24455611390285, 'progressive_passes_per_90': 10.861887732685217, 'progressive_pass_accuracy': 61.75115207373272, 'long_passes_per_90': 5.756299950501382, 'long_pass_accuracy': 47.82608695652174, 'crosses_per_90': 0.15016434653481867, 'cross_accuracy': 33.33333333333333, 'key_passes_per_90': 0.10010956435654578, 'assists_per_90': 0.0, 'passes_received_per_90': 21.723775465370434, 'shots_per_90': 0.20021912871309153, 'shots_on_target_per_90': 0.05005478217827288, 'shot_accuracy': 0.25, 'goals_per_90': 0.0, 'xg_per_90': 0.010027853713786757, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.10010956435654576, 'shots_outside_box_per_90': 0.05005478217827288, 'dribbles_per_90': 0.2502739108913644, 'successful_dribbles_per_90': 0.15016434653481867, 'dribble_success_rate': 60.0, 'progressive_runs_per_90': 0.9009860792089119, 'fouls_won_per_90': 0.4004382574261831, 'pressures_per_90': 7.257943415849568, 'blocks_per_90': 1.1512599901002765, 'interceptions_per_90': 1.1012052079220036, 'dribbled_past_per_90': 0.3503834752479102, 'clearances_per_90': 2.60284867327019, 'ball_recoveries_per_90': 2.702958237626736, 'fouls_made_per_90': 0.9510408613871848, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.10010956435654578, 'duels_per_90': 2.8531225841615546, 'duels_won_per_90': 0.20021912871309155, 'duel_success_rate': 7.017543859649122, 'touches_per_90': 83.79170536642881, 'average_position_x': 43.13183990442054, 'average_position_y': 58.11021505376343}, {'player_id': 7635, 'name': 'Gaëtan Charbonnier', 'minutes': 1748.55, 'most_played_position': 'Center Attacking Midfield', 'position': 'midfielder', 'passes_per_90': 29.59595093077121, 'pass_accuracy': 70.78260869565217, 'progressive_passes_per_90': 7.566269194475422, 'progressive_pass_accuracy': 52.38095238095239, 'long_passes_per_90': 2.1103199794115124, 'long_pass_accuracy': 36.58536585365854, 'crosses_per_90': 0.6691258471304795, 'cross_accuracy': 30.76923076923077, 'key_passes_per_90': 0.9264819421806639, 'assists_per_90': 0.05147121901003689, 'passes_received_per_90': 45.96379857596294, 'shots_per_90': 1.1323668182208115, 'shots_on_target_per_90': 0.46324097109033197, 'shot_accuracy': 0.409, 'goals_per_90': 0.20588487604014757, 'xg_per_90': 0.09168577953847476, 'first_time_shots_per_90': 0.3602985330702582, 'headers_per_90': 0.051471219010036894, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 2.4191472934717337, 'successful_dribbles_per_90': 1.0808955992107745, 'dribble_success_rate': 44.680851063829785, 'progressive_runs_per_90': 1.4411941322810327, 'fouls_won_per_90': 1.1323668182208115, 'pressures_per_90': 16.831088616282063, 'blocks_per_90': 1.4411941322810327, 'interceptions_per_90': 0.6176546281204426, 'dribbled_past_per_90': 0.5661834091104058, 'clearances_per_90': 0.36029853307025816, 'ball_recoveries_per_90': 4.477996053873209, 'fouls_made_per_90': 1.1838380372308484, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.15441365703011065, 'duels_per_90': 4.683880929913356, 'duels_won_per_90': 0.3088273140602213, 'duel_success_rate': 6.593406593406594, 'touches_per_90': 124.14858025220896, 'average_position_x': 72.68237976782761, 'average_position_y': 41.91077943615248}, {'player_id': 5477, 'name': 'Ousmane Dembélé', 'minutes': 2884.35, 'most_played_position': 'Right Wing', 'position': 'winger', 'passes_per_90': 22.40366113682459, 'pass_accuracy': 67.40947075208913, 'progressive_passes_per_90': 5.11727078891258, 'progressive_pass_accuracy': 46.34146341463415, 'long_passes_per_90': 2.8394612304332, 'long_pass_accuracy': 34.065934065934066, 'crosses_per_90': 1.6849550158614592, 'cross_accuracy': 20.37037037037037, 'key_passes_per_90': 1.1233033439076396, 'assists_per_90': 0.1560143533205055, 'passes_received_per_90': 36.28893858234958, 'shots_per_90': 1.7473607571896614, 'shots_o ...

# %%
import math

def check_nan_or_errors(player_data):
    problematic = []
    for player in player_data:
        for key, value in player.items():
            if value is None:
                problematic.append((player.get('player_id', 'unknown'), key, 'None'))
            elif isinstance(value, float) and math.isnan(value):
                problematic.append((player.get('player_id', 'unknown'), key, 'NaN'))
            # You can add more error checks here if needed

    if problematic:
        print("Found NaN or None in the following player stats:")
        for pid, col, val in problematic:
            print(f"Player {pid} - Column: {col} - Value: {val}")
    else:
        print("No NaN or None values found in player stats.")

check_nan_or_errors(player_data)
# Out:
# Found NaN or None in the following player stats:
# Player 7236 - Column: average_position_x - Value: None
# Player 7236 - Column: average_position_y - Value: None
# Player 4908 - Column: average_position_x - Value: None
# Player 4908 - Column: average_position_y - Value: None

# %%
for player in player_data:
    if player.get('player_id') == 206604:
        print(player)
        break

# %%
unknown_positions = sum(1 for player in player_data if player.get('most_played_position') == 'Unknown')
print(f"Number of players with 'Unknown' position: {unknown_positions}")
# Out:
# Number of players with 'Unknown' position: 49

# %%
for player in player_data:
    if player.get('most_played_position') == 'Unknown':
        print(player)
# Out:
# {'player_id': 4839, 'name': 'Issam Ben Khémis', 'minutes': 71.27, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 12.628034236003929, 'pass_accuracy': 60.0, 'progressive_passes_per_90': 5.0512136944015715, 'progressive_pass_accuracy': 50.0, 'long_passes_per_90': 2.5256068472007858, 'long_pass_accuracy': 50.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 1.2628034236003929, 'assists_per_90': 0.0, 'passes_received_per_90': 10.102427388803143, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 10.102427388803143, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 1.2628034236003929, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.7884102708011786, 'fouls_made_per_90': 2.5256068472007858, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 36.62129928441139, 'average_position_x': 56.13793103448276, 'average_position_y': 26.889655172413796}
# {'player_id': 170152, 'name': "Mahamadou Bamba N''Diaye", 'minutes': 69.75, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 2.5806451612903225, 'pass_accuracy': 100.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 1.2903225806451613, 'long_pass_accuracy': 100.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 5.161290322580645, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 1.2903225806451613, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 2.5806451612903225, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 2.5806451612903225, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 15.483870967741934, 'average_position_x': 33.13333333333333, 'average_position_y': 45.98333333333333}
# {'player_id': 40509, 'name': 'Kermit Romeo Erasmus', 'minutes': 140.47, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 14.095536413469068, 'pass_accuracy': 86.36363636363636, 'progressive_passes_per_90': 1.9221186018366911, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.6407062006122304, 'cross_accuracy': 100.0, 'key_passes_per_90': 1.9221186018366911, 'assists_per_90': 0.0, 'passes_received_per_90': 20.502598419591372, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.6407062006122304, 'fouls_won_per_90': 0.0, 'pressures_per_90': 5.125649604897843, 'blocks_per_90': 1.2814124012244608, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.6407062006122304, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.2814124012244608, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 49.33437744714174, 'average_position_x': 79.70649350649356, 'average_position_y': 46.60779220779221}
# {'player_id': 40526, 'name': 'François Pantxi Sirieix', 'minutes': 334.92, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 14.779648871372268, 'pass_accuracy': 65.45454545454545, 'progressive_passes_per_90': 5.6431386599785025, 'progressive_pass_accuracy': 47.61904761904761, 'long_passes_per_90': 2.149767108563239, 'long_pass_accuracy': 50.0, 'crosses_per_90': 0.5374417771408098, 'cross_accuracy': 100.0, 'key_passes_per_90': 0.2687208885704049, 'assists_per_90': 0.5374417771408098, 'passes_received_per_90': 14.242207094231459, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.2687208885704049, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 1.0748835542816195, 'fouls_won_per_90': 0.8061626657112146, 'pressures_per_90': 7.524184879971337, 'blocks_per_90': 0.2687208885704049, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.2687208885704049, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.8061626657112146, 'fouls_made_per_90': 0.2687208885704049, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.0748835542816195, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 43.26406305983518, 'average_position_x': 70.50000000000004, 'average_position_y': 28.81552795031058}
# {'player_id': 21792, 'name': 'Robin Maulun', 'minutes': 104.03, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 35.470537344996636, 'pass_accuracy': 85.36585365853658, 'progressive_passes_per_90': 8.651350571950399, 'progressive_pass_accuracy': 70.0, 'long_passes_per_90': 2.5954051715851194, 'long_pass_accuracy': 33.33333333333333, 'crosses_per_90': 0.8651350571950398, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.8651350571950398, 'assists_per_90': 0.0, 'passes_received_per_90': 34.605402287801596, 'shots_per_90': 0.8651350571950398, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.022429729404979334, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.8651350571950398, 'successful_dribbles_per_90': 0.8651350571950398, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 13.842160915120637, 'blocks_per_90': 1.7302701143900796, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 1.7302701143900796, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 5.190810343170239, 'fouls_made_per_90': 0.8651350571950398, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 4.3256752859751995, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 113.33269249255022, 'average_position_x': 63.472519083969466, 'average_position_y': 41.35419847328244}
# {'player_id': 4776, 'name': 'Enock Kwateng', 'minutes': 129.82, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 5.546140810352797, 'pass_accuracy': 87.5, 'progressive_passes_per_90': 1.3865352025881992, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 3.466338006470498, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.6932676012940996, 'pressures_per_90': 3.466338006470498, 'blocks_per_90': 0.6932676012940996, 'interceptions_per_90': 0.6932676012940996, 'dribbled_past_per_90': 0.6932676012940996, 'clearances_per_90': 1.3865352025881992, 'ball_recoveries_per_90': 1.3865352025881992, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 2.0798028038822984, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 19.411492836234785, 'average_position_x': 43.57499999999999, 'average_position_y': 72.48571428571428}
# {'player_id': 19395, 'name': 'Marvin Gakpa', 'minutes': 199.2, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 17.16867469879518, 'pass_accuracy': 81.57894736842105, 'progressive_passes_per_90': 5.873493975903615, 'progressive_pass_accuracy': 61.53846153846154, 'long_passes_per_90': 1.8072289156626506, 'long_pass_accuracy': 50.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.45180722891566266, 'assists_per_90': 0.0, 'passes_received_per_90': 16.265060240963855, 'shots_per_90': 0.45180722891566266, 'shots_on_target_per_90': 0.45180722891566266, 'shot_accuracy': 1.0, 'goals_per_90': 0.0, 'xg_per_90': 0.005440043674698795, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.355421686746988, 'successful_dribbles_per_90': 1.355421686746988, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 2.710843373493976, 'fouls_won_per_90': 0.9036144578313253, 'pressures_per_90': 8.132530120481928, 'blocks_per_90': 0.9036144578313253, 'interceptions_per_90': 0.45180722891566266, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.355421686746988, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.355421686746988, 'duels_won_per_90': 0.45180722891566266, 'duel_success_rate': 33.33333333333333, 'touches_per_90': 58.734939759036145, 'average_position_x': 67.28461538461535, 'average_position_y': 45.453846153846136}
# {'player_id': 28968, 'name': 'Sébastien Wüthrich', 'minutes': 52.47, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 5.145797598627787, 'pass_accuracy': 100.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 6.86106346483705, 'shots_per_90': 1.7152658662092624, 'shots_on_target_per_90': 1.7152658662092624, 'shot_accuracy': 1.0, 'goals_per_90': 0.0, 'xg_per_90': 0.052866891938250435, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 1.7152658662092626, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 1.7152658662092626, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 20.58319039451115, 'average_position_x': 85.67500000000003, 'average_position_y': 8.816666666666666}
# {'player_id': 30315, 'name': 'Moryké Fofana', 'minutes': 429.77, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 12.774274612001769, 'pass_accuracy': 85.24590163934425, 'progressive_passes_per_90': 1.884729041115015, 'progressive_pass_accuracy': 66.66666666666666, 'long_passes_per_90': 0.41882867580333666, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.41882867580333666, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.20941433790166833, 'assists_per_90': 0.0, 'passes_received_per_90': 18.428461735346815, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 2.303557716918352, 'successful_dribbles_per_90': 1.0470716895083416, 'dribble_success_rate': 45.45454545454545, 'progressive_runs_per_90': 3.141215068525025, 'fouls_won_per_90': 0.8376573516066733, 'pressures_per_90': 4.607115433836704, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.20941433790166833, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.25648602741001, 'fouls_made_per_90': 0.41882867580333666, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.8376573516066733, 'duels_won_per_90': 0.20941433790166833, 'duel_success_rate': 25.0, 'touches_per_90': 52.56299881331875, 'average_position_x': 73.8430278884462, 'average_position_y': 47.333864541832696}
# {'player_id': 106664, 'name': 'Sibiri Alain Traoré', 'minutes': 183.48, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 14.224983649444082, 'pass_accuracy': 65.51724137931035, 'progressive_passes_per_90': 3.9241334205362985, 'progressive_pass_accuracy': 50.0, 'long_passes_per_90': 2.452583387835187, 'long_pass_accuracy': 80.0, 'crosses_per_90': 0.9810333551340746, 'cross_accuracy': 50.0, 'key_passes_per_90': 0.9810333551340746, 'assists_per_90': 0.0, 'passes_received_per_90': 12.262916939175934, 'shots_per_90': 0.4905166775670373, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.013419310006540223, 'first_time_shots_per_90': 0.4905166775670373, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.4905166775670373, 'fouls_won_per_90': 1.471550032701112, 'pressures_per_90': 3.9241334205362985, 'blocks_per_90': 0.9810333551340746, 'interceptions_per_90': 0.4905166775670373, 'dribbled_past_per_90': 0.4905166775670373, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.452583387835187, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.4905166775670373, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 44.14650098103336, 'average_position_x': 69.20999999999998, 'average_position_y': 37.58333333333335}
# {'player_id': 2976, 'name': 'Samuel Grandsir', 'minutes': 63.48, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 5.671077504725899, 'pass_accuracy': 100.0, 'progressive_passes_per_90': 1.4177693761814747, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 2.8355387523629494, 'long_pass_accuracy': 100.0, 'crosses_per_90': 1.4177693761814747, 'cross_accuracy': 100.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 7.088846880907373, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 1.4177693761814747, 'fouls_won_per_90': 0.0, 'pressures_per_90': 4.253308128544424, 'blocks_per_90': 1.4177693761814747, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 18.43100189035917, 'average_position_x': 72.7076923076923, 'average_position_y': 27.5}
# {'player_id': 175093, 'name': "Hicham M''Laab", 'minutes': 129.93, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 9.004848764719464, 'pass_accuracy': 76.92307692307693, 'progressive_passes_per_90': 2.0780420226275687, 'progressive_pass_accuracy': 66.66666666666666, 'long_passes_per_90': 2.0780420226275687, 'long_pass_accuracy': 33.33333333333333, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 13.853613484183791, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.385361348418379, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.6926806742091896, 'fouls_won_per_90': 2.0780420226275687, 'pressures_per_90': 2.0780420226275687, 'blocks_per_90': 1.385361348418379, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.6926806742091896, 'clearances_per_90': 0.6926806742091896, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.6926806742091896, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 40.175479104133, 'average_position_x': 78.56896551724134, 'average_position_y': 55.55344827586206}
# {'player_id': 7264, 'name': 'Thimotee Taufflieb', 'minutes': 52.45, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 13.727359389895136, 'pass_accuracy': 100.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 20.591039084842706, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 1.715919923736892, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 3.431839847473784, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 49.76167778836987, 'average_position_x': 63.43793103448277, 'average_position_y': 60.682758620689654}
# {'player_id': 4902, 'name': 'Kevin Rimane', 'minutes': 53.72, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 13.402829486224869, 'pass_accuracy': 100.0, 'progressive_passes_per_90': 3.3507073715562172, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 1.6753536857781086, 'long_pass_accuracy': 100.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 11.72747580044676, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 31.831720029784066, 'average_position_x': 30.826315789473682, 'average_position_y': 64.63157894736844}
# {'player_id': 7236, 'name': 'Yakou Meïté', 'minutes': 50.35, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 0.0, 'pass_accuracy': 0.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 0.0, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 0, 'average_position_x': None, 'average_position_y': None}
# {'player_id': 2970, 'name': 'Christian Kouakou Yao', 'minutes': 439.03, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 7.379905701204929, 'pass_accuracy': 66.66666666666666, 'progressive_passes_per_90': 1.2299842835341548, 'progressive_pass_accuracy': 16.666666666666664, 'long_passes_per_90': 0.4099947611780516, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.4099947611780516, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 12.7098375965196, 'shots_per_90': 1.024986902945129, 'shots_on_target_per_90': 0.6149921417670774, 'shot_accuracy': 0.6, 'goals_per_90': 0.20499738058902583, 'xg_per_90': 0.06793364694895565, 'first_time_shots_per_90': 0.8199895223561033, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.4099947611780516, 'successful_dribbles_per_90': 0.2049973805890258, 'dribble_success_rate': 50.0, 'progressive_runs_per_90': 0.2049973805890258, 'fouls_won_per_90': 0.4099947611780516, 'pressures_per_90': 6.149921417670774, 'blocks_per_90': 0.2049973805890258, 'interceptions_per_90': 0.2049973805890258, 'dribbled_past_per_90': 0.4099947611780516, 'clearances_per_90': 0.2049973805890258, 'ball_recoveries_per_90': 1.2299842835341548, 'fouls_made_per_90': 1.2299842835341548, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.2049973805890258, 'duels_per_90': 0.8199895223561032, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 34.84955470013439, 'average_position_x': 77.71823529411763, 'average_position_y': 55.15176470588237}
# {'player_id': 7198, 'name': 'Franck Honorat', 'minutes': 429.08, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 11.326559149808894, 'pass_accuracy': 53.70370370370371, 'progressive_passes_per_90': 1.4682576675678196, 'progressive_pass_accuracy': 42.857142857142854, 'long_passes_per_90': 0.8390043814673255, 'long_pass_accuracy': 25.0, 'crosses_per_90': 0.41950219073366274, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.41950219073366274, 'assists_per_90': 0.0, 'passes_received_per_90': 18.877598583014823, 'shots_per_90': 0.41950219073366274, 'shots_on_target_per_90': 0.41950219073366274, 'shot_accuracy': 1.0, 'goals_per_90': 0.0, 'xg_per_90': 0.018013332199123707, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.20975109536683137, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.4682576675678196, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 2.097510953668314, 'fouls_won_per_90': 0.20975109536683137, 'pressures_per_90': 9.22904819614058, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.41950219073366274, 'clearances_per_90': 0.41950219073366274, 'ball_recoveries_per_90': 0.8390043814673255, 'fouls_made_per_90': 1.2585065722009883, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.20975109536683137, 'duels_per_90': 1.4682576675678196, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 47.61349864827072, 'average_position_x': 80.7114537444934, 'average_position_y': 46.25330396475769}
# {'player_id': 7525, 'name': 'Gaëtan Perrin', 'minutes': 189.97, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 3.790072116649997, 'pass_accuracy': 75.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.47375901458124964, 'assists_per_90': 0.0, 'passes_received_per_90': 10.422698320787493, 'shots_per_90': 0.9475180291624994, 'shots_on_target_per_90': 0.4737590145812497, 'shot_accuracy': 0.5, 'goals_per_90': 0.4737590145812497, 'xg_per_90': 0.27860451544980785, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.4737590145812497, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.9475180291624993, 'successful_dribbles_per_90': 0.47375901458124964, 'dribble_success_rate': 50.0, 'progressive_runs_per_90': 0.47375901458124964, 'fouls_won_per_90': 0.47375901458124964, 'pressures_per_90': 5.2113491603937465, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.47375901458124964, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.9475180291624993, 'fouls_made_per_90': 0.9475180291624993, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.421277043743749, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 25.109227772806232, 'average_position_x': 77.9245283018868, 'average_position_y': 27.401886792452835}
# {'player_id': 7510, 'name': 'Zakarie Labidi', 'minutes': 180.43, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 4.489275619353766, 'pass_accuracy': 66.66666666666666, 'progressive_passes_per_90': 0.9976168043008368, 'progressive_pass_accuracy': 50.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 10.973784847309204, 'shots_per_90': 0.9976168043008369, 'shots_on_target_per_90': 0.49880840215041844, 'shot_accuracy': 0.5, 'goals_per_90': 0.0, 'xg_per_90': 0.10431610890650113, 'first_time_shots_per_90': 0.49880840215041844, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 1.496425206451255, 'fouls_won_per_90': 0.0, 'pressures_per_90': 3.990467217203347, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.4988084021504184, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.9976168043008368, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 28.930887324724267, 'average_position_x': 72.96724137931034, 'average_position_y': 17.974137931034484}
# {'player_id': 9860, 'name': 'Florian Sotoca', 'minutes': 52.42, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 5.1507058374666155, 'pass_accuracy': 100.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 8.584509729111026, 'shots_per_90': 1.716901945822205, 'shots_on_target_per_90': 1.716901945822205, 'shot_accuracy': 1.0, 'goals_per_90': 0.0, 'xg_per_90': 0.09729555932850056, 'first_time_shots_per_90': 0.0, 'headers_per_90': 1.716901945822205, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 1.7169019458222052, 'pressures_per_90': 1.7169019458222052, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.7169019458222052, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.7169019458222052, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 25.75352918733308, 'average_position_x': 89.12666666666664, 'average_position_y': 62.233333333333334}
# {'player_id': 7607, 'name': 'Abdoulaye Keita', 'minutes': 246.62, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 8.393479847538725, 'pass_accuracy': 60.86956521739131, 'progressive_passes_per_90': 2.55453734490309, 'progressive_pass_accuracy': 14.285714285714285, 'long_passes_per_90': 1.8246695320736357, 'long_pass_accuracy': 60.0, 'crosses_per_90': 0.7298678128294542, 'cross_accuracy': 50.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 6.203876409050361, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.0948017192441815, 'successful_dribbles_per_90': 0.3649339064147271, 'dribble_success_rate': 33.33333333333333, 'progressive_runs_per_90': 1.4597356256589085, 'fouls_won_per_90': 0.0, 'pressures_per_90': 4.014272970561998, 'blocks_per_90': 0.3649339064147271, 'interceptions_per_90': 0.3649339064147271, 'dribbled_past_per_90': 0.7298678128294542, 'clearances_per_90': 0.7298678128294542, 'ball_recoveries_per_90': 1.4597356256589085, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.4597356256589085, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 27.370042981104536, 'average_position_x': 52.79599999999999, 'average_position_y': 71.62266666666666}
# {'player_id': 16014, 'name': 'Jean Pierre Nsamé', 'minutes': 316.53, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 6.255331248222918, 'pass_accuracy': 68.18181818181817, 'progressive_passes_per_90': 0.2843332385555872, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 11.0889963036679, 'shots_per_90': 0.2843332385555872, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.0070061188512937165, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.2843332385555872, 'successful_dribbles_per_90': 0.2843332385555872, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.2843332385555872, 'pressures_per_90': 5.402331532556156, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.2843332385555872, 'clearances_per_90': 0.5686664771111744, 'ball_recoveries_per_90': 1.4216661927779357, 'fouls_made_per_90': 1.1373329542223487, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.2843332385555872, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 28.14899061700313, 'average_position_x': 76.01717171717173, 'average_position_y': 29.22323232323233}
# {'player_id': 403378, 'name': 'Antony Ranieri', 'minutes': 108.68, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 1.6562384983437612, 'pass_accuracy': 50.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 3.3124769966875225, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.8281192491718806, 'successful_dribbles_per_90': 0.8281192491718806, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 2.484357747515642, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.8281192491718806, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.8281192491718806, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 9.109311740890687, 'average_position_x': 74.07272727272726, 'average_position_y': 40.445454545454545}
# {'player_id': 4446, 'name': 'Soualiho Meïté', 'minutes': 208.15, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 10.80951237088638, 'pass_accuracy': 68.0, 'progressive_passes_per_90': 2.594282969012731, 'progressive_pass_accuracy': 83.33333333333334, 'long_passes_per_90': 0.4323804948354552, 'long_pass_accuracy': 100.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 11.241892865721836, 'shots_per_90': 0.43238049483545515, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.07614824981984146, 'first_time_shots_per_90': 0.43238049483545515, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.8647609896709104, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.8647609896709104, 'pressures_per_90': 8.215229401873648, 'blocks_per_90': 1.7295219793418208, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.4323804948354552, 'clearances_per_90': 0.4323804948354552, 'ball_recoveries_per_90': 1.7295219793418208, 'fouls_made_per_90': 0.8647609896709104, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 2.161902474177276, 'duels_won_per_90': 0.4323804948354552, 'duel_success_rate': 20.0, 'touches_per_90': 40.211386019697336, 'average_position_x': 64.46774193548386, 'average_position_y': 33.995698924731194}
# {'player_id': 401603, 'name': 'Erin Jorge Gomes Pinheiro', 'minutes': 124.35, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 4.342581423401689, 'pass_accuracy': 50.0, 'progressive_passes_per_90': 2.1712907117008444, 'progressive_pass_accuracy': 33.33333333333333, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 5.066344993968637, 'shots_per_90': 0.7237635705669482, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.013515053558504223, 'first_time_shots_per_90': 0.7237635705669482, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.7237635705669482, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.7237635705669482, 'fouls_won_per_90': 0.0, 'pressures_per_90': 10.856453558504223, 'blocks_per_90': 1.4475271411338964, 'interceptions_per_90': 0.7237635705669482, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.7237635705669482, 'ball_recoveries_per_90': 0.7237635705669482, 'fouls_made_per_90': 0.7237635705669482, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 18.094089264173704, 'average_position_x': 76.71999999999998, 'average_position_y': 49.768}
# {'player_id': 388167, 'name': 'Mohamed Ilyes Salah Chaïbi', 'minutes': 61.8, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 5.825242718446602, 'pass_accuracy': 100.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 11.650485436893204, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 8.737864077669903, 'blocks_per_90': 1.4563106796116505, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.4563106796116505, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 24.75728155339806, 'average_position_x': 76.47058823529412, 'average_position_y': 19.4}
# {'player_id': 7438, 'name': 'Hassane Kamara', 'minutes': 134.32, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 5.360333531864205, 'pass_accuracy': 75.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.6700416914830256, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 12.730792138177486, 'shots_per_90': 0.6700416914830257, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.003436325364800477, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.6700416914830257, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 2.6801667659321025, 'fouls_won_per_90': 0.6700416914830256, 'pressures_per_90': 7.3704586063132815, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.0101250744490766, 'fouls_made_per_90': 0.6700416914830256, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.3400833829660512, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 33.50208457415128, 'average_position_x': 74.632, 'average_position_y': 31.002000000000002}
# {'player_id': 10977, 'name': 'Jérémy Livolant', 'minutes': 64.3, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 4.199066874027994, 'pass_accuracy': 100.0, 'progressive_passes_per_90': 1.3996889580093312, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 1.3996889580093312, 'long_pass_accuracy': 100.0, 'crosses_per_90': 1.3996889580093312, 'cross_accuracy': 100.0, 'key_passes_per_90': 1.3996889580093312, 'assists_per_90': 0.0, 'passes_received_per_90': 6.998444790046657, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.3996889580093312, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 2.7993779160186625, 'fouls_won_per_90': 0.0, 'pressures_per_90': 4.199066874027994, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.3996889580093312, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.3996889580093312, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 20.995334370139968, 'average_position_x': 73.42666666666666, 'average_position_y': 13.346666666666664}
# {'player_id': 403310, 'name': 'Ilias Hassani', 'minutes': 68.57, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 7.875164065918041, 'pass_accuracy': 83.33333333333334, 'progressive_passes_per_90': 1.3125273443196734, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 1.3125273443196734, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 3.9375820329590203, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 2.625054688639347, 'blocks_per_90': 1.3125273443196734, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 3.9375820329590203, 'ball_recoveries_per_90': 3.9375820329590203, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 3.9375820329590203, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 28.875601575032814, 'average_position_x': 35.38181818181818, 'average_position_y': 48.23181818181818}
# {'player_id': 7322, 'name': 'Romain Del Castillo', 'minutes': 136.02, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 9.925011027790031, 'pass_accuracy': 73.33333333333333, 'progressive_passes_per_90': 1.985002205558006, 'progressive_pass_accuracy': 66.66666666666666, 'long_passes_per_90': 0.6616674018526687, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.6616674018526687, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 16.54168504631672, 'shots_per_90': 0.6616674018526686, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.06258455888839877, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.3233348037053374, 'successful_dribbles_per_90': 1.3233348037053374, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 1.3233348037053374, 'fouls_won_per_90': 0.0, 'pressures_per_90': 7.940008822232024, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 1.3233348037053374, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.985002205558006, 'fouls_made_per_90': 0.6616674018526687, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.3233348037053374, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 43.008381120423465, 'average_position_x': 77.2676923076923, 'average_position_y': 23.63076923076924}
# {'player_id': 401480, 'name': 'Mathias Serin', 'minutes': 50.93, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 0.0, 'pass_accuracy': 0.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 1.7671313567641862, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 1.7671313567641862, 'fouls_won_per_90': 0.0, 'pressures_per_90': 3.5342627135283724, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 1.7671313567641862, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 5.301394070292559, 'average_position_x': 80.8, 'average_position_y': 13.799999999999999}
# {'player_id': 4908, 'name': 'Jérémie Porsan-Clemente', 'minutes': 50.5, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 0.0, 'pass_accuracy': 0.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 0.0, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 0, 'average_position_x': None, 'average_position_y': None}
# {'player_id': 4473, 'name': 'Nicolas Janvier', 'minutes': 186.13, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 9.670660291194327, 'pass_accuracy': 65.0, 'progressive_passes_per_90': 2.9011980873582983, 'progressive_pass_accuracy': 50.0, 'long_passes_per_90': 1.4505990436791492, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.48353301455971637, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 12.088325363992908, 'shots_per_90': 0.4835330145597163, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.01808295105571375, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.48353301455971637, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.48353301455971637, 'fouls_won_per_90': 0.9670660291194327, 'pressures_per_90': 4.835330145597164, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.48353301455971637, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.48353301455971637, 'fouls_made_per_90': 0.9670660291194327, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 36.264976091978724, 'average_position_x': 73.34666666666666, 'average_position_y': 33.734666666666655}
# {'player_id': 43896, 'name': 'Thomas Henry', 'minutes': 138.0, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 3.913043478260869, 'pass_accuracy': 66.66666666666666, 'progressive_passes_per_90': 1.3043478260869565, 'progressive_pass_accuracy': 50.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 9.782608695652174, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.6521739130434783, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.6521739130434783, 'fouls_won_per_90': 1.3043478260869565, 'pressures_per_90': 6.521739130434782, 'blocks_per_90': 0.6521739130434783, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 1.3043478260869565, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.3043478260869565, 'fouls_made_per_90': 1.3043478260869565, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.9565217391304346, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 27.391304347826086, 'average_position_x': 80.35238095238094, 'average_position_y': 19.91904761904762}
# ...
# {'player_id': 7358, 'name': 'Alexis Araujo', 'minutes': 54.6, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 4.945054945054945, 'pass_accuracy': 66.66666666666666, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 1.6483516483516483, 'assists_per_90': 0.0, 'passes_received_per_90': 4.945054945054945, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 1.6483516483516483, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.6483516483516483, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 16.483516483516482, 'average_position_x': 93.23000000000002, 'average_position_y': 18.439999999999998}
# {'player_id': 403392, 'name': 'Diego Gómez', 'minutes': 80.7, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 15.613382899628252, 'pass_accuracy': 57.14285714285714, 'progressive_passes_per_90': 10.03717472118959, 'progressive_pass_accuracy': 55.55555555555556, 'long_passes_per_90': 2.2304832713754648, 'long_pass_accuracy': 0.0, 'crosses_per_90': 1.1152416356877324, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 17.843866171003718, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.1152416356877324, 'successful_dribbles_per_90': 1.1152416356877324, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 2.2304832713754648, 'fouls_won_per_90': 0.0, 'pressures_per_90': 12.267657992565056, 'blocks_per_90': 1.1152416356877324, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.2304832713754648, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.1152416356877324, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 63.56877323420074, 'average_position_x': 72.51578947368421, 'average_position_y': 31.791228070175432}
# {'player_id': 40485, 'name': 'Ryan Isaac Mendes da Graça', 'minutes': 248.5, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 15.211267605633804, 'pass_accuracy': 76.19047619047619, 'progressive_passes_per_90': 4.7082494969818915, 'progressive_pass_accuracy': 76.92307692307693, 'long_passes_per_90': 1.0865191146881288, 'long_pass_accuracy': 33.33333333333333, 'crosses_per_90': 1.0865191146881288, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 21.3682092555332, 'shots_per_90': 0.3621730382293763, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.008307691026156942, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 2.1730382293762576, 'successful_dribbles_per_90': 0.36217303822937624, 'dribble_success_rate': 16.666666666666664, 'progressive_runs_per_90': 2.1730382293762576, 'fouls_won_per_90': 0.7243460764587525, 'pressures_per_90': 7.605633802816902, 'blocks_per_90': 0.7243460764587525, 'interceptions_per_90': 0.36217303822937624, 'dribbled_past_per_90': 1.0865191146881288, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.1730382293762576, 'fouls_made_per_90': 1.0865191146881288, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 5.432595573440644, 'duels_won_per_90': 0.7243460764587525, 'duel_success_rate': 13.333333333333334, 'touches_per_90': 67.00201207243461, 'average_position_x': 77.00108108108111, 'average_position_y': 58.07243243243246}
# {'player_id': 42423, 'name': 'Mouhamadou Habib Habibou', 'minutes': 60.35, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 0.0, 'pass_accuracy': 0.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 7.456503728251864, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 4.473902236951118, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.4913007456503728, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 8.947804473902236, 'average_position_x': 85.71666666666665, 'average_position_y': 37.76666666666667}
# {'player_id': 7406, 'name': 'Julien Bègue', 'minutes': 203.13, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 7.5321222862206465, 'pass_accuracy': 47.05882352941176, 'progressive_passes_per_90': 1.3291980505095258, 'progressive_pass_accuracy': 66.66666666666666, 'long_passes_per_90': 0.4430660168365086, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.4430660168365086, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 8.861320336730172, 'shots_per_90': 0.8861320336730173, 'shots_on_target_per_90': 0.44306601683650865, 'shot_accuracy': 0.5, 'goals_per_90': 0.0, 'xg_per_90': 0.21314119051838726, 'first_time_shots_per_90': 0.44306601683650865, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.7722640673460344, 'successful_dribbles_per_90': 1.3291980505095258, 'dribble_success_rate': 75.0, 'progressive_runs_per_90': 2.215330084182543, 'fouls_won_per_90': 0.8861320336730172, 'pressures_per_90': 3.9875941515285778, 'blocks_per_90': 0.4430660168365086, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.6583961010190515, 'fouls_made_per_90': 0.4430660168365086, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.4430660168365086, 'duels_per_90': 0.4430660168365086, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 31.900753212228622, 'average_position_x': 78.18333333333334, 'average_position_y': 53.61249999999998}
# {'player_id': 141742, 'name': 'Youssef Ben Ali', 'minutes': 64.18, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 18.229978186350888, 'pass_accuracy': 76.92307692307693, 'progressive_passes_per_90': 2.8046120286693674, 'progressive_pass_accuracy': 50.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 18.229978186350888, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.4023060143346837, 'successful_dribbles_per_90': 1.4023060143346837, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 2.8046120286693674, 'fouls_won_per_90': 0.0, 'pressures_per_90': 5.609224057338735, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 4.206918043004051, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.4023060143346837, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 63.10377064506076, 'average_position_x': 88.84222222222222, 'average_position_y': 62.09555555555555}
# {'player_id': 3735, 'name': 'Wesley Saïd', 'minutes': 62.38, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 7.213850593138827, 'pass_accuracy': 60.0, 'progressive_passes_per_90': 1.4427701186277653, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 1.4427701186277653, 'assists_per_90': 0.0, 'passes_received_per_90': 10.099390830394357, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.4427701186277653, 'successful_dribbles_per_90': 1.4427701186277653, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 1.4427701186277653, 'fouls_won_per_90': 1.4427701186277653, 'pressures_per_90': 1.4427701186277653, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.4427701186277653, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 30.29817249118307, 'average_position_x': 69.66666666666667, 'average_position_y': 22.5047619047619}
# {'player_id': 3257, 'name': 'Steve Michel Mounié', 'minutes': 139.65, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 9.667024704618688, 'pass_accuracy': 93.33333333333333, 'progressive_passes_per_90': 0.6444683136412459, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.6444683136412459, 'assists_per_90': 0.0, 'passes_received_per_90': 17.40064446831364, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.6444683136412459, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 1.2889366272824918, 'pressures_per_90': 4.511278195488722, 'blocks_per_90': 1.2889366272824918, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 1.2889366272824918, 'ball_recoveries_per_90': 0.6444683136412459, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.9334049409237377, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 43.179377013963474, 'average_position_x': 81.68507462686568, 'average_position_y': 37.388059701492544}
# {'player_id': 42376, 'name': 'Albert Rafetraniaina', 'minutes': 55.67, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 1.6166696604993713, 'pass_accuracy': 0.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 0.0, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 8.083348302496857, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.6166696604993713, 'fouls_made_per_90': 1.6166696604993713, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 1.6166696604993713, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 4.850008981498114, 'average_position_x': 33.06666666666667, 'average_position_y': 29.233333333333334}
# {'player_id': 23315, 'name': 'Yohan Mollo', 'minutes': 76.23, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 11.806375442739078, 'pass_accuracy': 70.0, 'progressive_passes_per_90': 5.903187721369539, 'progressive_pass_accuracy': 40.0, 'long_passes_per_90': 2.3612750885478158, 'long_pass_accuracy': 0.0, 'crosses_per_90': 1.1806375442739079, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 10.62573789846517, 'shots_per_90': 1.1806375442739079, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.020447023612750883, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 2.3612750885478158, 'fouls_won_per_90': 1.1806375442739079, 'pressures_per_90': 2.3612750885478158, 'blocks_per_90': 1.1806375442739079, 'interceptions_per_90': 1.1806375442739079, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.1806375442739079, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 38.96103896103896, 'average_position_x': 66.0090909090909, 'average_position_y': 27.787878787878785}
# {'player_id': 4417, 'name': 'Ola Toivonen', 'minutes': 72.2, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 3.739612188365651, 'pass_accuracy': 66.66666666666666, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 8.725761772853184, 'shots_per_90': 1.2465373961218835, 'shots_on_target_per_90': 1.2465373961218835, 'shot_accuracy': 1.0, 'goals_per_90': 0.0, 'xg_per_90': 0.054299542936288095, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 2.493074792243767, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.2465373961218835, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 2.493074792243767, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 18.698060941828253, 'average_position_x': 87.61333333333332, 'average_position_y': 42.586666666666666}

# %%
import pandas as pd

df_players = pd.DataFrame(player_data)
print(df_players.head())  # To see the first few rows
# Out:
#    player_id                name  minutes       most_played_position  \
# 0       7498   Mickaël Tacalfred  1798.03          Right Center Back
# 1       7635  Gaëtan Charbonnier  1748.55  Center Attacking Midfield
# 2       5477     Ousmane Dembélé  2884.35                 Right Wing
# 3       5667      Kamil Grosicki  2808.65                 Right Wing
# 4       7369            Aly Ndom   609.45       Left Center Midfield
#
#       position  passes_per_90  pass_accuracy  progressive_passes_per_90  \
# 0  center back      29.882705      82.244556                  10.861888
# 1   midfielder      29.595951      70.782609                   7.566269
# 2       winger      22.403661      67.409471                   5.117271
# 3       winger      20.892600      63.803681                   4.293878
# 4   midfielder      26.433670      79.888268                   6.497662
#
#    progressive_pass_accuracy  long_passes_per_90  ...  smothers_per_90  \
# 0                  61.751152            5.756300  ...              NaN
# 1                  52.380952            2.110320  ...              NaN
# 2                  46.341463            2.839461  ...              NaN
# 3                  47.014925            2.819860  ...              NaN
# 4                  56.818182            1.919764  ...              NaN
#
#    collections_per_90  punches_per_90  sweeper_claims_per_90  \
# 0                 NaN             NaN                    NaN
# 1                 NaN             NaN                    NaN
# 2                 NaN             NaN                    NaN
# 3                 NaN             NaN                    NaN
# 4                 NaN             NaN                    NaN
#
#    sweeper_clears_per_90  save_percentage  smother_success_rate  \
# 0                    NaN              NaN                   NaN
# 1                    NaN              NaN                   NaN
# 2                    NaN              NaN                   NaN
# 3                    NaN              NaN                   NaN
# 4                    NaN              NaN                   NaN
#
#    collection_success_rate  punch_success_rate  sweeper_success_rate
# 0                      NaN                 NaN                   NaN
# 1                      NaN                 NaN                   NaN
# 2                      NaN                 NaN                   NaN
# 3                      NaN                 NaN                   NaN
# 4                      NaN                 NaN                   NaN
#
# [5 rows x 57 columns]

# %%
cols_to_fill = [
    'shots_faced_per_90',
    'saves_per_90',
    'goals_conceded_per_90',
    'smothers_per_90',
    'collections_per_90',
    'punches_per_90',
    'sweeper_claims_per_90',
    'sweeper_clears_per_90',
    'save_percentage',
    'smother_success_rate',
    'collection_success_rate',
    'punch_success_rate',
    'sweeper_success_rate'  # fixed missing quote here
]

df_players[cols_to_fill] = df_players[cols_to_fill].fillna(0.0)

# %%
print(df_players.columns)
print(df_players['name'].head(20))  # or try another likely column name, e.g. 'player_name'
keylor_row = df_players[df_players['name'].str.contains('José Antonio García Rabasco', case=False, na=False)]
print(keylor_row.to_dict(orient='records'))
# Out:
# Index(['player_id', 'name', 'minutes', 'most_played_position', 'position',
#        'passes_per_90', 'pass_accuracy', 'progressive_passes_per_90',
#        'progressive_pass_accuracy', 'long_passes_per_90', 'long_pass_accuracy',
#        'crosses_per_90', 'cross_accuracy', 'key_passes_per_90',
#        'assists_per_90', 'passes_received_per_90', 'shots_per_90',
#        'shots_on_target_per_90', 'shot_accuracy', 'goals_per_90', 'xg_per_90',
#        'first_time_shots_per_90', 'headers_per_90', 'shots_outside_box_per_90',
#        'dribbles_per_90', 'successful_dribbles_per_90', 'dribble_success_rate',
#        'progressive_runs_per_90', 'fouls_won_per_90', 'pressures_per_90',
#        'blocks_per_90', 'interceptions_per_90', 'dribbled_past_per_90',
#        'clearances_per_90', 'ball_recoveries_per_90', 'fouls_made_per_90',
#        'yellow_cards_per_90', 'red_cards_per_90', 'duels_per_90',
#        'duels_won_per_90', 'duel_success_rate', 'touches_per_90',
#        'average_position_x', 'average_position_y', 'shots_faced_per_90',
#        'saves_per_90', 'goals_conceded_per_90', 'smothers_per_90',
#        'collections_per_90', 'punches_per_90', 'sweeper_claims_per_90',
#        'sweeper_clears_per_90', 'save_percentage', 'smother_success_rate',
#        'collection_success_rate', 'punch_success_rate',
#        'sweeper_success_rate'],
#       dtype='object')
# 0                         Mickaël Tacalfred
# 1                        Gaëtan Charbonnier
# 2                           Ousmane Dembélé
# 3                            Kamil Grosicki
# 4                                  Aly Ndom
# 5                            Yoann Gourcuff
# 6                  Benoît Guy Robert Costil
# 7                              Romain Danzé
# 8                             Fallou Diagne
# 9                            Sylvain Armand
# 10                         Cheikh M''Bengue
# 11    Gélson da Conceição Tavares Fernandes
# 12                           Benjamin André
# 13                    Giovanni-Guy Yann Sio
# 14                          Johann Carrasso
# 15                              Aïssa Mandi
# 16                            Anthony Weber
# 17                            Hamari Traoré
# 18                 Diego Rigonato Rodrigues
# 19                           Antoine Devaux
# Name: name, dtype: object
# []

# %%
for col in df_players.columns:
    nan_count = df_players[col].isna().sum()
    if nan_count > 0:
        print(f"Column '{col}' has {nan_count} NaN(s).")
        players_with_nan = df_players[df_players[col].isna()]
        print("Players with NaN in this column:")
        for idx, row in players_with_nan.iterrows():
            pid = row.get('player_id', 'Unknown')
            name = row.get('name', 'Unknown')
            print(f" - Player ID: {pid}, Name: {name}")
        print()
# Out:
# Column 'average_position_x' has 2 NaN(s).
# Players with NaN in this column:
#  - Player ID: 7236, Name: Yakou Meïté
#  - Player ID: 4908, Name: Jérémie Porsan-Clemente
#
# Column 'average_position_y' has 2 NaN(s).
# Players with NaN in this column:
#  - Player ID: 7236, Name: Yakou Meïté
#  - Player ID: 4908, Name: Jérémie Porsan-Clemente

# %%
# Drop all rows with any NaNs
df_players_clean = df_players.dropna()

print(f"Removed {len(df_players) - len(df_players_clean)} players with NaN values.")
# Out:
# Removed 2 players with NaN values.

# %%
df_players_clean.to_csv('cleaned_player_data(ligue1).csv', index=False)
