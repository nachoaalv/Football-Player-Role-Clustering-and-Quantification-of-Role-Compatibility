# %% [markdown]
# Start data analysis with serie A 2015/16 season

# %%
import json
import pandas as pd

# Define your path (with UTF-8 encoding)
file_path = r'C:\Users\nacho\open-data\data\matches\12\27.json'

# Load La Liga 2015/16 matches
with open(file_path, 'r', encoding='utf-8') as f:
    matches = json.load(f)

# Extract match IDs
match_ids = [match['match_id'] for match in matches]

print(f"Found {len(match_ids)} La Liga 2015/16 matches.")
# Out:
# Found 380 La Liga 2015/16 matches.

# %%
'''
Checks every game for each team is in the dataset
'''
home_teams = [match['home_team']['home_team_name'] for match in matches]
away_teams = [match['away_team']['away_team_name'] for match in matches]

all_teams = home_teams + away_teams

games_per_team = pd.Series(all_teams).value_counts()

print(games_per_team)
# Out:
# Atalanta         38
# Frosinone        38
# Udinese          38
# Torino           38
# Inter Milan      38
# Lazio            38
# AS Roma          38
# Sassuolo         38
# AC Milan         38
# Sampdoria        38
# Napoli           38
# Juventus         38
# Hellas Verona    38
# Bologna          38
# Palermo          38
# Fiorentina       38
# Genoa            38
# Empoli           38
# Carpi            38
# Chievo           38
# Name: count, dtype: int64

# %%
import os
from tqdm import tqdm 

'''
to extract all match events from each match
'''

# Base folder where event files are stored
events_folder = r'C:\Users\nacho\open-data\data\events'

# List to hold all events
all_events = {}

for match_id in tqdm(match_ids):
    event_file = os.path.join(events_folder, f"{match_id}.json")
    with open(event_file, 'r', encoding='utf-8') as f:
        match_events = json.load(f)
        all_events[match_id] = match_events  # Store events under the match_id key

print(f"Loaded events for {len(all_events)} matches.")
total_events = sum(len(ev) for ev in all_events.values())
print(f"Loaded a total of {total_events} events from {len(all_events)} matches.")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 380/380 [05:55<00:00,  1.07it/s]
# Loaded events for 380 matches.
# Loaded a total of 1353739 events from 380 matches.

# %% [markdown]
# Extracting the line up of one game to check accuracy and make sure it works

# %%
first_match = matches[12]
match_id = first_match['match_id']

print(f"Match ID: {match_id}")
print(f"Home team: {first_match['home_team']['home_team_name']}")
print(f"Away team: {first_match['away_team']['away_team_name']}")
print(f"Date: {first_match['match_date']}")
# Out:
# Match ID: 3879699
# Home team: Sampdoria
# Away team: Napoli
# Date: 2016-01-24

# %%
events_for_match = all_events[match_id]

# Find the Starting XI event(s)
starting_xi_events = [e for e in events_for_match if e['type']['id'] == 35]

for event in starting_xi_events:
    print(f"Team: {event['team']['name']}, Formation: {event['tactics']['formation']}")
    lineup = event['tactics']['lineup']
    for player_info in lineup:
        player_name = player_info['player']['name']
        position_name = player_info['position']['name']
        jersey_number = player_info.get('jersey_number', 'N/A')
        print(f"  #{jersey_number} {player_name} - {position_name}")
    print()
# Out:
# Team: Sampdoria, Formation: 4231
#   #2 Emiliano Viviano - Goalkeeper
#   #5 Mattia Cassani - Right Back
#   #4 Niklas Moisander - Right Center Back
#   #87 Ervin Zukanović - Left Center Back
#   #19 Vasco Regini - Left Back
#   #8 Édgar Osvaldo Barreto Cáceres - Right Defensive Midfield
#   #7 Fernando Lucas Martins - Left Defensive Midfield
#   #77 Carlos Mario Carbonero Mancilla - Right Wing
#   #10 Carlos Joaquín Correa - Center Attacking Midfield
#   #23 Eder Citadin Martins - Left Wing
#   #99 Antonio Cassano - Center Forward
#
# Team: Napoli, Formation: 433
#   #25 José Manuel Reina Páez - Goalkeeper
#   #2 Elseid Hysaj - Right Back
#   #33 Raúl Albiol i Tortajada - Right Center Back
#   #26 Kalidou Koulibaly - Left Center Back
#   #31 Faouzi Ghoulam - Left Back
#   #8 Jorge Luiz Frello Filho - Center Defensive Midfield
#   #5 Allan Marques Loureiro - Right Center Midfield
#   #17 Marek Hamšík - Left Center Midfield
#   #7 José María Callejón Bueno - Right Wing
#   #24 Lorenzo Insigne - Left Wing
#   #9 Gonzalo Gerardo Higuaín - Center Forward

# %% [markdown]
# need to narrow down to what postions i should go,
#
# examples: treat right back and left back as one?
# treat left back and left wing back as one?
# treat defensive midfield, center midfield and attacking midfield as one?
#
# Inititally only these positions:
#
# fullback (LB, RB, LWB, RWB)
#
# centreback
#
# Midfield (CDM CM CAM)
#
# RM LM?
#
# Wingers (LW RW)
#
# Striker (ST CF

# %%
unique_positions = set()

for match_id, events in all_events.items():
    for event in events:
        if event['type']['name'] == 'Starting XI':
            lineup = event['tactics']['lineup']
            for player in lineup:
                position_name = player['position']['name']
                unique_positions.add(position_name)

print(f"Unique positions in the season: {len(unique_positions)}")
print("Position names:", unique_positions)
# Out:
# Unique positions in the season: 24
# Position names: {'Left Center Forward', 'Right Midfield', 'Left Center Midfield', 'Right Center Back', 'Right Defensive Midfield', 'Right Center Forward', 'Right Attacking Midfield', 'Center Forward', 'Left Midfield', 'Left Attacking Midfield', 'Left Center Back', 'Right Back', 'Center Back', 'Left Wing', 'Left Back', 'Right Wing Back', 'Left Defensive Midfield', 'Center Midfield', 'Goalkeeper', 'Right Wing', 'Left Wing Back', 'Center Defensive Midfield', 'Right Center Midfield', 'Center Attacking Midfield'}

# %%
'''GET MINUTES PLAYED BY EACH PLAYER'''


from collections import defaultdict

player_seconds = defaultdict(float)
player_id_to_name = {}

for match_id, events in all_events.items():
    players_on_pitch = {}  # player_id -> start_time_in_seconds
    off_periods = defaultdict(list)  # player_id -> list of {'off': time, 'on': time}
    added_time_players = defaultdict(int)
    
    for event in events:
        event_time = event['minute'] * 60 + event['second']
        
        if event['type']['id'] == 35:
            for player in event['tactics']['lineup']:
                pid = player['player']['id']
                name = player['player']['name']
                players_on_pitch[pid] = 0
                player_id_to_name[pid] = name
        
        elif event['type']['id'] == 34:
            added_time = event_time - 2700  # 45 mins in secs
            if added_time > 0:
                for pid in players_on_pitch:
                    added_time_players[pid] = added_time
        
        elif event['type']['id'] == 19:
            player_out = event['player']['id']
            player_in = event['substitution']['replacement']['id']
            time_sub = event_time
            
            if player_out in players_on_pitch:
                start_time = players_on_pitch[player_out]
                added = added_time_players.get(player_out, 0)
                player_seconds[player_out] += time_sub - start_time + added
                del players_on_pitch[player_out]
            
            players_on_pitch[player_in] = time_sub
            name = event['substitution']['replacement']['name']
            player_id_to_name[player_in] = name
        
        elif event['type']['id'] == 27:
            pid = event['player']['id']
            off_periods[pid].append({'off': event_time})
        
        elif event['type']['id'] == 26:
            pid = event['player']['id']
            if off_periods[pid] and 'off' in off_periods[pid][-1] and 'on' not in off_periods[pid][-1]:
                off_periods[pid][-1]['on'] = event_time

    # End of match: finalize playing time for players still on pitch
    if events:
        last_event = events[-1]
        match_end_time = last_event['minute'] * 60 + last_event['second']
        for pid, start_time in players_on_pitch.items():
            play_time = match_end_time - start_time + added_time_players.get(pid, 0)
            
            for period in off_periods.get(pid, []):
                if 'on' in period and 'off' in period:
                    play_time -= (period['on'] - period['off'])
                elif 'off' in period:
                    play_time -= (match_end_time - period['off'])
            
            player_seconds[pid] += play_time
'''
# Print results
for pid, seconds in player_seconds.items():
    name = player_id_to_name.get(pid, "Unknown")
    minutes = round(seconds / 60, 2)
    print(pid, name, minutes)
print(len(player_seconds))
'''
# Out:
# '\n# Print results\nfor pid, seconds in player_seconds.items():\n    name = player_id_to_name.get(pid, "Unknown")\n    minutes = round(seconds / 60, 2)\n    print(pid, name, minutes)\nprint(len(player_seconds))\n'

# %%
player_data = []

for pid, seconds in player_seconds.items():
    name = player_id_to_name.get(pid, "Unknown")
    minutes = round(seconds / 60, 2)
    player_data.append({
        'player_id': pid,
        'name': name,
        'minutes': minutes
    })

# %%
'''ADD THEIR MAIN POSITION'''

from collections import defaultdict, Counter

player_position_counts = defaultdict(Counter)


for match_id, events in all_events.items():
    for event in events:
        if event['type']['id'] == 35:  # Lineup
            for player in event['tactics']['lineup']:
                pid = player['player']['id']
                pos = player.get('position', {}).get('name')
                if pos:
                    player_position_counts[pid][pos] += 1

        elif event['type']['id'] == 19:  # Sub
            replacement = event['substitution']['replacement']
            pid = replacement['id']
            pos = replacement.get('position', {}).get('name')
            if pos:
                player_position_counts[pid][pos] += 1

for player in player_data:
    pid = player['player_id']
    position_counter = player_position_counts.get(pid, {})
    most_played = position_counter.most_common(1)[0][0] if position_counter else "Unknown"
    player['most_played_position'] = most_played

# %%
# Mapping function
def map_general_position(pos):
    pos = pos.lower()
    
    if pos == "goalkeeper":
        return "goalkeeper"
    
    elif pos in ["right back", "left back", "right wing back", "left wing back"]:
        return "full back"
    
    elif pos in ["center back", "right center back", "left center back"]:
        return "center back"
    
    elif "midfield" in pos:
        return "midfielder"
    
    elif pos in ["right wing", "left wing"]:
        return "winger"
    
    elif pos in ["striker", "center forward", "secondary striker", "right center forward", "left center forward"]:
        return "striker"
    
    return "other"  # fallback for unexpected cases

# %%
for player in player_data:
    specific_pos = player.get('most_played_position', 'Unknown')
    player['position'] = map_general_position(specific_pos)

# %%
other_count = sum(1 for player in player_data if player.get('position') == 'other')
print(f"Number of players with position 'other': {other_count}")
# Out:
# Number of players with position 'other': 38

# %% [raw]
# PASSING DATA

# %%
from collections import defaultdict

# Initialize stats containers per player
pass_stats = defaultdict(lambda: {
    'total_passes': 0,
    'completed_passes': 0,
    'progressive_passes': 0,
    'completed_progressive_passes': 0,
    'long_passes': 0,
    'completed_long_passes': 0,
    'crosses': 0,
    'completed_crosses': 0,
    'key_passes': 0,
    'assists': 0,
    'passes_received' : 0
})

def is_progressive_pass(start_x, end_x, pitch_length=100):
    # Determine progressive pass by x-coordinate movement closer to opponent goal
    if start_x < pitch_length / 2 and end_x < pitch_length / 2:
        return (end_x - start_x) >= 30
    elif (start_x < pitch_length / 2 and end_x >= pitch_length / 2) or (start_x >= pitch_length / 2 and end_x < pitch_length / 2):
        return (end_x - start_x) >= 15
    else:  # both in opponent half
        return (end_x - start_x) >= 10

def is_long_pass(length_yards, height_id):
    # Ground pass longer than 45m (~49.2 yards)
    # High pass longer than 25m (~27.3 yards)
    if height_id == 1:  # Ground Pass
        return length_yards >= 49.2
    elif height_id == 3:  # High Pass
        return length_yards >= 27.3
    return False

# Collect pass data
for match_id, events in all_events.items():
    for event in events:
        if event['type']['id'] == 30:  # Pass event
            pid = event['player']['id']
            # Completed pass if no outcome or outcome id is None
            completed = event.get('pass', {}).get('outcome', {}).get('id') is None
            length = event.get('pass', {}).get('length', 0)  # in yards
            height_id = event.get('pass', {}).get('height', {}).get('id', 1)  # default to ground pass if missing

            start_x = event.get('location', [0, 0])[0]
            end_x = event.get('pass', {}).get('end_location', [0, 0])[0]

            cross = event.get('pass', {}).get('cross', False)

            # Update total and completed passes
            pass_stats[pid]['total_passes'] += 1
            if completed:
                pass_stats[pid]['completed_passes'] += 1

            # Progressive passes
            if is_progressive_pass(start_x, end_x):
                pass_stats[pid]['progressive_passes'] += 1
                if completed:
                    pass_stats[pid]['completed_progressive_passes'] += 1

            # Long passes
            if is_long_pass(length, height_id):
                pass_stats[pid]['long_passes'] += 1
                if completed:
                    pass_stats[pid]['completed_long_passes'] += 1

            # Crosses
            if cross:
                pass_stats[pid]['crosses'] += 1
                if completed:
                    pass_stats[pid]['completed_crosses'] += 1

            # Key passes (assisted shot)
            if event.get('pass', {}).get('shot_assist', False):
                pass_stats[pid]['key_passes'] += 1

            # Assists (goal assists)
            if event.get('pass', {}).get('goal_assist', False):
                pass_stats[pid]['assists'] += 1
                
        elif event['type']['id'] == 42: #Ball receipt
            pid = event['player']['id']
            pass_stats[pid]['passes_received'] +=1

# %%
# Add passing stats per 90 minutes to player_data
for player in player_data:
    pid = player['player_id']
    minutes = player.get('minutes', 0)
    stats = pass_stats.get(pid, {})

    if minutes > 0:
        player['passes_per_90'] = stats.get('total_passes', 0) / (minutes / 90)
        player['pass_accuracy'] = (stats.get('completed_passes', 0) / max(stats.get('total_passes', 1), 1)) * 100

        player['progressive_passes_per_90'] = stats.get('progressive_passes', 0) / (minutes / 90)
        player['progressive_pass_accuracy'] = (stats.get('completed_progressive_passes', 0) / max(stats.get('progressive_passes', 1), 1)) * 100

        player['long_passes_per_90'] = stats.get('long_passes', 0) / (minutes / 90)
        player['long_pass_accuracy'] = (stats.get('completed_long_passes', 0) / max(stats.get('long_passes', 1), 1)) * 100

        player['crosses_per_90'] = stats.get('crosses', 0) / (minutes / 90)
        player['cross_accuracy'] = (stats.get('completed_crosses', 0) / max(stats.get('crosses', 1), 1)) * 100

        player['key_passes_per_90'] = stats.get('key_passes', 0) / (minutes / 90)
        player['assists_per_90'] = stats.get('assists', 0) / (minutes / 90)
        
        player['passes_received_per_90'] = stats.get('passes_received', 0) / (minutes/90)
    else:
        player['passes_per_90'] = 0
        player['pass_accuracy'] = 0
        player['progressive_passes_per_90'] = 0
        player['progressive_pass_accuracy'] = 0
        player['long_passes_per_90'] = 0
        player['long_pass_accuracy'] = 0
        player['crosses_per_90'] = 0
        player['cross_accuracy'] = 0
        player['key_passes_per_90'] = 0
        player['assists_per_90'] = 0
        player['passes_received_per_90'] = 0

# %% [raw]
# SHOT DATA

# %%
# Initialize data containers
player_shots = defaultdict(lambda: {
    'total_shots': 0,
    'shots_on_target': 0,
    'goals': 0,
    'xg': 0.0,
    'first_time_shots': 0,
    'headers': 0,
    'shots_outside_box': 0
})

# Pitch box boundaries (StatsBomb pitch is 120x80)
# The penalty box on the attacking side is approximately x >= 84 for shots inside the box
penalty_box_x = 84

for match_id, events in all_events.items():
    for event in events:
        if event['type']['id'] == 16:  # Shot event
            pid = event['player']['id']
            location = event.get('location', [0, 0])
            x, y = location
            
            # Count total shots
            player_shots[pid]['total_shots'] += 1
            
            # Check shot outcome
            outcome_id = event.get('shot', {}).get('outcome', {}).get('id')
            # On target if goal (97), saved (100), or saved to post (116)
            if outcome_id in [97, 100, 116]:
                player_shots[pid]['shots_on_target'] += 1
            
            # Count goals
            if outcome_id == 97:
                player_shots[pid]['goals'] += 1
            
            # Accumulate xG
            xg = event.get('shot', {}).get('statsbomb_xg', 0)
            player_shots[pid]['xg'] += xg
            
            # First time shots
            if event.get('shot', {}).get('first_time', False):
                player_shots[pid]['first_time_shots'] += 1
            
            # Headers
            body_part_id = event.get('shot', {}).get('body_part', {}).get('id')
            if body_part_id == 37:  # 37 corresponds to 'Head'
                player_shots[pid]['headers'] += 1
            
            # Shots from outside the box (x < penalty_box_x)
            if x < penalty_box_x:
                player_shots[pid]['shots_outside_box'] += 1

# %%
# Now calculate per 90 stats and accuracy and add to player_data
for player in player_data:
    pid = player['player_id']
    seconds_played = player.get('minutes', 0) * 60
    minutes_played = player.get('minutes', 0)
    if seconds_played == 0:
        # Avoid division by zero if no minutes played
        player.update({
            'shots_per_90': 0,
            'shots_on_target_per_90': 0,
            'shot_accuracy': 0,
            'goals_per_90': 0,
            'xg_per_90': 0,
            'first_time_shots_per_90': 0,
            'headers_per_90': 0,
            'shots_outside_box_per_90': 0
        })
        continue
    
    stats = player_shots.get(pid, {
        'total_shots': 0,
        'shots_on_target': 0,
        'goals': 0,
        'xg': 0.0,
        'first_time_shots': 0,
        'headers': 0,
        'shots_outside_box': 0
    })
    
    shots = stats['total_shots']
    shots_on_target = stats['shots_on_target']
    goals = stats['goals']
    xg = stats['xg']
    first_time = stats['first_time_shots']
    headers = stats['headers']
    shots_outside = stats['shots_outside_box']
    
    # Calculate accuracy (on target / total shots)
    accuracy = shots_on_target / shots if shots > 0 else 0
    
    player['shots_per_90'] = shots / minutes_played * 90
    player['shots_on_target_per_90'] = shots_on_target / minutes_played * 90
    player['shot_accuracy'] = round(accuracy, 3)
    player['goals_per_90'] = goals / minutes_played * 90
    player['xg_per_90'] = xg / minutes_played * 90
    player['first_time_shots_per_90'] = first_time / minutes_played * 90
    player['headers_per_90'] = headers / minutes_played * 90
    player['shots_outside_box_per_90'] = shots_outside / minutes_played * 90

# %%
print(player_data)
# Out:
# [{'player_id': 3577, 'name': 'Molla Wagué', 'minutes': 2736.15, 'most_played_position': 'Right Center Back', 'position': 'center back', 'passes_per_90': 20.62386930541089, 'pass_accuracy': 80.22328548644339, 'progressive_passes_per_90': 5.657584562249877, 'progressive_pass_accuracy': 57.55813953488372, 'long_passes_per_90': 2.302505345101694, 'long_pass_accuracy': 34.285714285714285, 'crosses_per_90': 0.16446466750726385, 'cross_accuracy': 40.0, 'key_passes_per_90': 0.13157173400581107, 'assists_per_90': 0.0, 'passes_received_per_90': 14.341319006633407, 'shots_per_90': 0.3618222685159805, 'shots_on_target_per_90': 0.06578586700290555, 'shot_accuracy': 0.182, 'goals_per_90': 0.0, 'xg_per_90': 0.03009917209582808, 'first_time_shots_per_90': 0.032892933501452774, 'headers_per_90': 0.23025053451016939, 'shots_outside_box_per_90': 0.0}, {'player_id': 6577, 'name': 'Zdravko Kuzmanović', 'minutes': 1769.95, 'most_played_position': 'Center Defensive Midfield', 'position': 'midfielder', 'passes_per_90': 29.39066075312862, 'pass_accuracy': 82.17993079584775, 'progressive_passes_per_90': 8.6443119862143, 'progressive_pass_accuracy': 65.29411764705883, 'long_passes_per_90': 3.813667052741603, 'long_pass_accuracy': 58.666666666666664, 'crosses_per_90': 0.45764004632899236, 'cross_accuracy': 22.22222222222222, 'key_passes_per_90': 0.4067911522924377, 'assists_per_90': 0.0, 'passes_received_per_90': 24.407469137546258, 'shots_per_90': 0.4067911522924376, 'shots_on_target_per_90': 0.1016977880731094, 'shot_accuracy': 0.25, 'goals_per_90': 0.0, 'xg_per_90': 0.03600322692166445, 'first_time_shots_per_90': 0.30509336421932826, 'headers_per_90': 0.1016977880731094, 'shots_outside_box_per_90': 0.0}, {'player_id': 386607, 'name': 'Gianpaolo Bellini', 'minutes': 1397.02, 'most_played_position': 'Right Back', 'position': 'full back', 'passes_per_90': 32.59795851168917, 'pass_accuracy': 80.8300395256917, 'progressive_passes_per_90': 10.951883294441025, 'progressive_pass_accuracy': 70.58823529411765, 'long_passes_per_90': 3.4144106741492606, 'long_pass_accuracy': 37.735849056603776, 'crosses_per_90': 0.8374969578101961, 'cross_accuracy': 30.76923076923077, 'key_passes_per_90': 0.06442284290847662, 'assists_per_90': 0.0, 'passes_received_per_90': 20.615309730712518, 'shots_per_90': 0.3865370574508597, 'shots_on_target_per_90': 0.06442284290847662, 'shot_accuracy': 0.167, 'goals_per_90': 0.06442284290847662, 'xg_per_90': 0.05735045006513866, 'first_time_shots_per_90': 0.19326852872542985, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0}, {'player_id': 8184, 'name': "Marco D''Alessandro", 'minutes': 2122.37, 'most_played_position': 'Right Wing', 'position': 'winger', 'passes_per_90': 15.817223198594025, 'pass_accuracy': 69.43699731903486, 'progressive_passes_per_90': 2.968379688744187, 'progressive_pass_accuracy': 55.714285714285715, 'long_passes_per_90': 1.7810278132465123, 'long_pass_accuracy': 50.0, 'crosses_per_90': 1.7386223891215953, 'cross_accuracy': 51.21951219512195, 'key_passes_per_90': 0.5936759377488374, 'assists_per_90': 0.08481084824983391, 'passes_received_per_90': 25.52806532320001, 'shots_per_90': 0.5936759377488374, 'shots_on_target_per_90': 0.2120271206245848, 'shot_accuracy': 0.357, 'goals_per_90': 0.1272162723747509, 'xg_per_90': 0.08817339144447012, 'first_time_shots_per_90': 0.33924339299933565, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0}, {'player_id': 6994, 'name': 'Marten de Roon', 'minutes': 4719.88, 'most_played_position': 'Center Defensive Midfield', 'position': 'midfielder', 'passes_per_90': 31.82496165156741, 'pass_accuracy': 77.29179149191133, 'progressive_passes_per_90': 10.239667110180767, 'progressive_pass_accuracy': 56.61080074487895, 'long_passes_per_90': 4.061543937557734, 'long_pass_accuracy': 42.72300469483568, 'crosses_per_90': 0.17161453257286202, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.34322906514572404, 'assists_per_90': 0.019068281396984667, 'passes_received_per_90': 23.225166741527325 ...

# %%
fields_to_check = [
    'minutes',
    'most_played_position',
    # Passing stats
    'passes_per_90',
    'pass_accuracy',
    'progressive_passes_per_90',
    'progressive_pass_accuracy',
    'long_passes_per_90',
    'long_pass_accuracy',
    'key_passes_per_90',
    'assists_per_90',
    'crosses_per_90',
    'cross_accuracy',
    # Shot stats
    'shots_per_90',
    'shots_on_target_per_90',
    'shot_accuracy',
    'goals_per_90',
    'xg_per_90',
    'first_time_shots_per_90',
    'headers_per_90',
    'shots_outside_box_per_90' 
]


missing_values = []

for player in player_data:
    for field in fields_to_check:
        if field not in player or player[field] is None:
            missing_values.append((player.get('player_id'), player.get('name'), field))

if missing_values:
    print(f"Missing values found for {len(missing_values)} fields:")
    for pid, name, field in missing_values:
        print(f"Player ID {pid} ({name}): Missing {field}")
else:
    print("No missing values found in checked fields.")
# Out:
# No missing values found in checked fields.

# %% [raw]
# Dribbling Data

# %%
# Dribble-related stats
dribble_stats = defaultdict(lambda: {
    'dribbles': 0,
    'successful_dribbles': 0,
    'progressive_runs': 0,
    'fouls_won': 0,
    'carry_distances' : []
})

def is_progressive_run(start_x, end_x, pitch_length=120):
    if start_x < pitch_length / 2 and end_x < pitch_length / 2:
        return (end_x - start_x) >= 30
    elif (start_x < pitch_length / 2 and end_x >= pitch_length / 2) or (start_x >= pitch_length / 2 and end_x < pitch_length / 2):
        return (end_x - start_x) >= 15
    else:
        return (end_x - start_x) >= 10

# Extract dribbling data
for match_id, events in all_events.items():
    for event in events:
        player = event.get('player')
        if not player:
            continue
        pid = player['id']
        etype = event['type']['id']

        if etype == 14:  # Dribble
            dribble_stats[pid]['dribbles'] += 1
            if event.get('dribble', {}).get('outcome', {}).get('id') == 8:
                dribble_stats[pid]['successful_dribbles'] += 1

        elif etype == 43:  # Carry
            start_x = event.get('location', [0, 0])[0]
            end_x = event.get('carry', {}).get('end_location', [0, 0])[0]
            if is_progressive_run(start_x, end_x):
                dribble_stats[pid]['progressive_runs'] += 1

        elif etype == 21:  # Foul Won
            dribble_stats[pid]['fouls_won'] += 1

# %%
for player in player_data:
    pid = player['player_id']
    minutes = player.get('minutes', 0)
    stats = dribble_stats.get(pid, {})

    if minutes > 0:
        factor = minutes / 90
        player['dribbles_per_90'] = stats.get('dribbles', 0) / factor
        player['successful_dribbles_per_90'] = stats.get('successful_dribbles', 0) / factor
        player['dribble_success_rate'] = (stats.get('successful_dribbles', 0) / max(stats.get('dribbles', 1), 1)) * 100
        player['progressive_runs_per_90'] = stats.get('progressive_runs', 0) / factor
        player['fouls_won_per_90'] = stats.get('fouls_won', 0) / factor
    else:
        player['dribbles_per_90'] = 0
        player['successful_dribbles_per_90'] = 0
        player['dribble_success_rate'] = 0
        player['progressive_runs_per_90'] = 0
        player['fouls_won_per_90'] = 0

# %% [raw]
# Defensive data

# %%
defensive_stats = defaultdict(lambda: {
    'pressures': 0,
    'blocks': 0,
    'interceptions': 0,
    'dribbled_past': 0,
    'clearances': 0,
    'ball_recoveries': 0,
    'fouls_made': 0,
    'yellow_cards': 0,
    'red_cards': 0,
    'duels': 0,
    'duels_won': 0
})

for match_id, events in all_events.items():
    for event in events:
        if 'player' not in event:
            continue

        pid = event['player']['id']
        etype = event['type']['id']

        if etype == 17:  # Pressure
            defensive_stats[pid]['pressures'] += 1
        elif etype == 2:  # Ball Recovery
            defensive_stats[pid]['ball_recoveries'] += 1
        elif etype == 4:  # Duel
            defensive_stats[pid]['duels'] += 1
            if event.get('duel', {}).get('outcome', {}).get('name') == 'Won':
                defensive_stats[pid]['duels_won'] += 1
        elif etype == 10:  # Interception
            defensive_stats[pid]['interceptions'] += 1
        elif etype == 22:  # Foul Committed (plus cards)
            defensive_stats[pid]['fouls_made'] += 1
            card = event.get('foul_committed', {}).get('card', {}).get('id')
            if card == 5:
                defensive_stats[pid]['yellow_cards'] += 1
            elif card == 6:
                defensive_stats[pid]['yellow_cards'] += 1
                defensive_stats[pid]['red_cards'] += 1
            elif card == 7:
                defensive_stats[pid]['red_cards'] += 1
        elif etype == 24:  # Bad Behaviour
            card = event.get('bad_behaviour', {}).get('card', {}).get('id')
            if card == 65:
                defensive_stats[pid]['yellow_cards'] += 1
            elif card == 66:
                defensive_stats[pid]['yellow_cards'] += 1
                defensive_stats[pid]['red_cards'] += 1
            elif card == 67:
                defensive_stats[pid]['red_cards'] += 1
        elif etype == 9:  # Clearance
            defensive_stats[pid]['clearances'] += 1
        elif etype == 6:  # Block
            defensive_stats[pid]['blocks'] += 1
        elif etype == 39:  # Dribbled Past
            defensive_stats[pid]['dribbled_past'] += 1

# %%
for player in player_data:
    pid = player['player_id']
    minutes = player.get('minutes', 0)
    stats = defensive_stats.get(pid, {})

    if minutes > 0:
        factor = minutes / 90
        player['pressures_per_90'] = stats.get('pressures', 0) / factor
        player['blocks_per_90'] = stats.get('blocks', 0) / factor
        player['interceptions_per_90'] = stats.get('interceptions', 0) / factor
        player['dribbled_past_per_90'] = stats.get('dribbled_past', 0) / factor
        player['clearances_per_90'] = stats.get('clearances', 0) / factor
        player['ball_recoveries_per_90'] = stats.get('ball_recoveries', 0) / factor
        player['fouls_made_per_90'] = stats.get('fouls_made', 0) / factor
        player['yellow_cards_per_90'] = stats.get('yellow_cards', 0) / factor
        player['red_cards_per_90'] = stats.get('red_cards', 0) / factor
        player['duels_per_90'] = stats.get('duels', 0) / factor
        player['duels_won_per_90'] = stats.get('duels_won', 0) / factor
        player['duel_success_rate'] = (stats.get('duels_won', 0) / max(stats.get('duels', 1), 1)) * 100
    else:
        player['pressures_per_90'] = 0
        player['blocks_per_90'] = 0
        player['interceptions_per_90'] = 0
        player['dribbled_past_per_90'] = 0
        player['clearances_per_90'] = 0
        player['ball_recoveries_per_90'] = 0
        player['fouls_made_per_90'] = 0
        player['yellow_cards_per_90'] = 0
        player['red_cards_per_90'] = 0
        player['duels_per_90'] = 0
        player['duels_won_per_90'] = 0
        player['duel_success_rate'] = 0

# %% [raw]
# Goalkeeper

# %%
import math

goalkeeping_stats = defaultdict(lambda: {
    'shots_faced': 0,
    'saves': 0,
    'close_range_saves': 0,
    'goals_conceded': 0,
    'smothers': 0,
    'collections': 0,
    'punches': 0,
    'sweeper_claims': 0,
    'sweeper_clears': 0,
    'successful_sweepers': 0,
    'successful_collections': 0,
    'successful_punches': 0,
    'successful_smothers': 0,
})

save_types = {29, 31, 33, 114, 110, 109}  # includes post saves, not 134 (off target)
goal_types = {26, 28}
shot_faced_types = save_types | goal_types | {32}  # include non-save faced shots
smother_type = 34
collection_types = {25, 49}  # includes "Collected" + "Collected Twice"
punch_types = {30, 117}
sweeper_type = 27

# Outcome categories
successful_outcomes = {15, 17, 47, 48, 49, 51, 53, 56, 59, 4, 16, 117}
fail_outcomes = {13, 14, 50, 52, 55, 58}

# Process events
for match_id, events in all_events.items():
    for event in events:
        if event['type']['id'] != 23:  # Not a goalkeeper event
            continue

        player = event.get('player')
        if not player:
            continue
        pid = player['id']
        gk_type = event['goalkeeper']['type']['id']
        outcome_id = event['goalkeeper'].get('outcome', {}).get('id')
        loc = event.get('location', [None, None])
        x = loc[0] if loc else None

        # Shots faced
        if gk_type in shot_faced_types:
            goalkeeping_stats[pid]['shots_faced'] += 1

        # Saves (including post saves, excluding off target saves)
        #if gk_type in save_types:
        #    goalkeeping_stats[pid]['saves'] += 1
          #  if x is not None and x <= 12:  # <12m assuming pitch 100 = 120m
           #     goalkeeping_stats[pid]['close_range_saves'] += 1
                
        # Goals conceded
        if gk_type in goal_types:
            goalkeeping_stats[pid]['goals_conceded'] += 1
            
        if gk_type in save_types:
            goalkeeping_stats[pid]['saves'] += 1

        # Smothers
        if gk_type == smother_type:
            goalkeeping_stats[pid]['smothers'] += 1
            if outcome_id in successful_outcomes:
                goalkeeping_stats[pid]['successful_smothers'] += 1

        # Collections
        if gk_type in collection_types:
            goalkeeping_stats[pid]['collections'] += 1
            if outcome_id in successful_outcomes:
                goalkeeping_stats[pid]['successful_collections'] += 1

        # Punches
        if gk_type in punch_types:
            goalkeeping_stats[pid]['punches'] += 1
            if outcome_id in successful_outcomes:
                goalkeeping_stats[pid]['successful_punches'] += 1

        # Sweeper actions
        if gk_type == sweeper_type:
            if outcome_id == 47:  # Claim
                goalkeeping_stats[pid]['sweeper_claims'] += 1
                if outcome_id in successful_outcomes:
                    goalkeeping_stats[pid]['successful_sweepers'] += 1
            elif outcome_id == 48:  # Clear
                goalkeeping_stats[pid]['sweeper_clears'] += 1
                if outcome_id in successful_outcomes:
                    goalkeeping_stats[pid]['successful_sweepers'] += 1

# %%
for player in player_data:
    pid = player['player_id']
    minutes = player.get('minutes', 0)

    if pid in goalkeeping_stats and minutes > 0:
        stats = goalkeeping_stats[pid]
        factor = minutes / 90

        player.update({

            # Per 90s
            'shots_faced_per_90': stats['shots_faced'] / factor,
            'saves_per_90': stats['saves'] / factor,
            'goals_conceded_per_90': stats['goals_conceded'] / factor,
            'smothers_per_90': stats['smothers'] / factor,
            'collections_per_90': stats['collections'] / factor,
            'punches_per_90': stats['punches'] / factor,
            'sweeper_claims_per_90': stats['sweeper_claims'] / factor,
            'sweeper_clears_per_90': stats['sweeper_clears'] / factor,

            # Success rates
            'save_percentage': (stats['saves'] / stats['shots_faced']) * 100 if stats['shots_faced'] else 0,
            'smother_success_rate': (stats['successful_smothers'] / stats['smothers']) * 100 if stats['smothers'] else 0,
            'collection_success_rate': (stats['successful_collections'] / stats['collections']) * 100 if stats['collections'] else 0,
            'punch_success_rate': (stats['successful_punches'] / stats['punches']) * 100 if stats['punches'] else 0,
            'sweeper_success_rate': (
                stats['successful_sweepers'] /
                (stats['sweeper_claims'] + stats['sweeper_clears'])
            ) * 100 if (stats['sweeper_claims'] + stats['sweeper_clears']) else 0
        })

# %%
for player in player_data:
    position = player.get('position', '').lower()
    if 'goalkeeper' in position or position == 'gk':
        print(player)
# Out:
# {'player_id': 7157, 'name': 'Marco Sportiello', 'minutes': 5166.37, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 18.883664933018736, 'pass_accuracy': 56.82656826568265, 'progressive_passes_per_90': 12.699438871006143, 'progressive_pass_accuracy': 37.997256515775035, 'long_passes_per_90': 12.925903487361534, 'long_pass_accuracy': 38.274932614555254, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.034840710208521655, 'assists_per_90': 0.0, 'passes_received_per_90': 4.860279074088771, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.017420355104260828, 'successful_dribbles_per_90': 0.017420355104260828, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.06968142041704331, 'pressures_per_90': 0.12194248572982579, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.034840710208521655, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.2053453391839923, 'fouls_made_per_90': 0.017420355104260828, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.017420355104260828, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.891420862230155, 'saves_per_90': 1.9336594165729517, 'goals_conceded_per_90': 0.7316549143789547, 'smothers_per_90': 0.017420355104260828, 'collections_per_90': 0.7490752694832156, 'punches_per_90': 0.05226106531278248, 'sweeper_claims_per_90': 0.48776994291930315, 'sweeper_clears_per_90': 0.017420355104260828, 'save_percentage': 24.503311258278146, 'smother_success_rate': 100.0, 'collection_success_rate': 100.0, 'punch_success_rate': 33.33333333333333, 'sweeper_success_rate': 100.0}
# {'player_id': 3742, 'name': 'Orestis Karnezis', 'minutes': 5426.53, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 18.160776776319306, 'pass_accuracy': 54.24657534246575, 'progressive_passes_per_90': 13.052540020971044, 'progressive_pass_accuracy': 36.975857687420586, 'long_passes_per_90': 13.185221495135934, 'long_pass_accuracy': 37.484276729559745, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 4.196051620464643, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0829259213530562, 'pressures_per_90': 0.09951110562366743, 'blocks_per_90': 0.016585184270611238, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.016585184270611238, 'clearances_per_90': 0.016585184270611238, 'ball_recoveries_per_90': 2.9521628001688005, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 8.906243953318235, 'saves_per_90': 1.87412582257907, 'goals_conceded_per_90': 0.9785258719660631, 'smothers_per_90': 0.04975555281183371, 'collections_per_90': 0.6634073708244496, 'punches_per_90': 0.2985333168710023, 'sweeper_claims_per_90': 0.3980444224946697, 'sweeper_clears_per_90': 0.033170368541222475, 'save_percentage': 21.042830540037244, 'smother_success_rate': 100.0, 'collection_success_rate': 95.0, 'punch_success_rate': 77.77777777777779, 'sweeper_success_rate': 100.0}
# {'player_id': 32037, 'name': 'Nicola Leali', 'minutes': 4725.92, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 18.682076717337576, 'pass_accuracy': 54.638124362895, 'progressive_passes_per_90': 13.997274604733047, 'progressive_pass_accuracy': 40.54421768707483, 'long_passes_per_90': 13.787791583437722, 'long_pass_accuracy': 39.64088397790056, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.03808782205369536, 'assists_per_90': 0.0, 'passes_received_per_90': 4.627670379523987, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.01904391102684768, 'fouls_won_per_90': 0.09521955513423841, 'pressures_per_90': 0.03808782205369536, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.01904391102684768, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.4757084334901984, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 12.283322612316754, 'saves_per_90': 2.342401056302265, 'goals_conceded_per_90': 1.1045468395571656, 'smothers_per_90': 0.0, 'collections_per_90': 0.9141077292886887, 'punches_per_90': 0.533229508751735, 'sweeper_claims_per_90': 0.3999221315638013, 'sweeper_clears_per_90': 0.19043911026847682, 'save_percentage': 19.069767441860467, 'smother_success_rate': 0, 'collection_success_rate': 93.75, 'punch_success_rate': 82.14285714285714, 'sweeper_success_rate': 100.0}
# {'player_id': 34881, 'name': 'Daniele Padelli', 'minutes': 5035.0, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.17974180734856, 'pass_accuracy': 72.87977632805219, 'progressive_passes_per_90': 7.5431976166832175, 'progressive_pass_accuracy': 38.15165876777251, 'long_passes_per_90': 8.11519364448858, 'long_pass_accuracy': 38.1057268722467, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.01787487586891758, 'assists_per_90': 0.0, 'passes_received_per_90': 7.310824230387289, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.03574975173783516, 'successful_dribbles_per_90': 0.03574975173783516, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.05362462760675273, 'pressures_per_90': 0.05362462760675273, 'blocks_per_90': 0.01787487586891758, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.03574975173783516, 'clearances_per_90': 0.01787487586891758, 'ball_recoveries_per_90': 2.6454816285998013, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.275074478649454, 'saves_per_90': 1.5908639523336643, 'goals_conceded_per_90': 0.8579940417080437, 'smothers_per_90': 0.01787487586891758, 'collections_per_90': 0.6613704071499503, 'punches_per_90': 0.42899702085402186, 'sweeper_claims_per_90': 0.4468718967229394, 'sweeper_clears_per_90': 0.05362462760675273, 'save_percentage': 21.867321867321866, 'smother_success_rate': 100.0, 'collection_success_rate': 100.0, 'punch_success_rate': 91.66666666666666, 'sweeper_success_rate': 100.0}
# {'player_id': 7028, 'name': 'José Manuel Reina Páez', 'minutes': 5244.0, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 18.930205949656752, 'pass_accuracy': 81.5049864007253, 'progressive_passes_per_90': 6.178489702517163, 'progressive_pass_accuracy': 46.111111111111114, 'long_passes_per_90': 5.869565217391305, 'long_pass_accuracy': 43.859649122807014, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.017162471395881007, 'assists_per_90': 0.0, 'passes_received_per_90': 8.426773455377575, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.017162471395881007, 'pressures_per_90': 0.05148741418764302, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.0892448512585813, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.017162471395881007, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 5.7837528604119, 'saves_per_90': 0.9439359267734554, 'goals_conceded_per_90': 0.4977116704805492, 'smothers_per_90': 0.034324942791762014, 'collections_per_90': 0.4462242562929062, 'punches_per_90': 0.10297482837528604, 'sweeper_claims_per_90': 0.4805491990846682, 'sweeper_clears_per_90': 0.2402745995423341, 'save_percentage': 16.320474777448073, 'smother_success_rate': 100.0, 'collection_success_rate': 88.46153846153845, 'punch_success_rate': 66.66666666666666, 'sweeper_success_rate': 100.0}
# {'player_id': 7001, 'name': 'Samir Handanovič', 'minutes': 5167.57, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 17.13764883688078, 'pass_accuracy': 75.0, 'progressive_passes_per_90': 7.628343689587176, 'progressive_pass_accuracy': 45.89041095890411, 'long_passes_per_90': 7.837339407110112, 'long_pass_accuracy': 46.44444444444444, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 5.4687212751835, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.017416309793578028, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.08708154896789014, 'pressures_per_90': 0.05224892938073408, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.716944327798172, 'fouls_made_per_90': 0.017416309793578028, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.017416309793578028, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.976669885458736, 'saves_per_90': 1.985459316467895, 'goals_conceded_per_90': 0.5747382231880749, 'smothers_per_90': 0.0, 'collections_per_90': 0.36574250566513855, 'punches_per_90': 0.20899571752293633, 'sweeper_claims_per_90': 0.5747382231880749, 'sweeper_clears_per_90': 0.13933047834862422, 'save_percentage': 24.890829694323145, 'smother_success_rate': 0, 'collection_success_rate': 95.23809523809523, 'punch_success_rate': 75.0, 'sweeper_success_rate': 100.0}
# {'player_id': 12491, 'name': 'Federico Marchetti', 'minutes': 3986.77, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 18.48865121388994, 'pass_accuracy': 70.57387057387058, 'progressive_passes_per_90': 8.962142285609653, 'progressive_pass_accuracy': 41.81360201511335, 'long_passes_per_90': 9.41363559974616, 'long_pass_accuracy': 43.884892086330936, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.022574665706825325, 'assists_per_90': 0.0, 'passes_received_per_90': 6.840123709168074, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.022574665706825325, 'successful_dribbles_per_90': 0.022574665706825325, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.1805973256546026, 'pressures_per_90': 0.11287332853412663, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.04514933141365065, 'clearances_per_90': 0.022574665706825325, 'ball_recoveries_per_90': 3.2507518617828466, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.022574665706825325, 'duels_won_per_90': 0.022574665706825325, 'duel_success_rate': 100.0, 'shots_faced_per_90': 7.5399383460796585, 'saves_per_90': 1.7608239251323754, 'goals_conceded_per_90': 0.8352626311525371, 'smothers_per_90': 0.022574665706825325, 'collections_per_90': 0.49664264555015714, 'punches_per_90': 0.2031719913614279, 'sweeper_claims_per_90': 0.3837693170160305, 'sweeper_clears_per_90': 0.22574665706825325, 'save_percentage': 23.353293413173652, 'smother_success_rate': 100.0, 'collection_success_rate': 95.45454545454545, 'punch_success_rate': 77.77777777777779, 'sweeper_success_rate': 100.0}
# {'player_id': 40332, 'name': 'Alberto Pelagotti', 'minutes': 858.87, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 18.96678193440218, 'pass_accuracy': 71.8232044198895, 'progressive_passes_per_90': 7.649586084040659, 'progressive_pass_accuracy': 34.24657534246575, 'long_passes_per_90': 7.649586084040659, 'long_pass_accuracy': 31.506849315068493, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 4.925075971916589, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.1047888504663104, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.934087813056691, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 11.317195850361522, 'saves_per_90': 2.8292989625903804, 'goals_conceded_per_90': 0.523944252331552, 'smothers_per_90': 0.0, 'collections_per_90': 0.4191554018652416, 'punches_per_90': 0.2095777009326208, 'sweeper_claims_per_90': 0.8383108037304832, 'sweeper_clears_per_90': 0.0, 'save_percentage': 25.0, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 100.0, 'sweeper_success_rate': 100.0}
# {'player_id': 3112, 'name': 'Anton Ciprian Tătărușanu', 'minutes': 5226.18, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.425278119008528, 'pass_accuracy': 75.97517730496453, 'progressive_passes_per_90': 6.647302618738734, 'progressive_pass_accuracy': 34.715025906735754, 'long_passes_per_90': 6.871175504862059, 'long_pass_accuracy': 34.83709273182957, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 9.437103199660172, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.01722099124025579, 'successful_dribbles_per_90': 0.01722099124025579, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.03444198248051158, 'pressures_per_90': 0.10332594744153473, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.03444198248051158, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.600369677278624, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 5.7001481005246655, 'saves_per_90': 1.1882483955776493, 'goals_conceded_per_90': 0.6716186583699757, 'smothers_per_90': 0.03444198248051158, 'collections_per_90': 0.6371766758894641, 'punches_per_90': 0.22387288612332523, 'sweeper_claims_per_90': 0.482187754727162, 'sweeper_clears_per_90': 0.22387288612332523, 'save_percentage': 20.84592145015106, 'smother_success_rate': 0.0, 'collection_success_rate': 94.5945945945946, 'punch_success_rate': 76.92307692307693, 'sweeper_success_rate': 100.0}
# {'player_id': 5669, 'name': 'Wojciech Szczęsny', 'minutes': 4868.9, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 22.957957649571775, 'pass_accuracy': 71.81964573268921, 'progressive_passes_per_90': 10.018690053194767, 'progressive_pass_accuracy': 38.37638376383764, 'long_passes_per_90': 10.129598061163714, 'long_pass_accuracy': 39.05109489051095, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.018484667994824292, 'assists_per_90': 0.0, 'passes_received_per_90': 10.092628725174064, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.036969335989648584, 'successful_dribbles_per_90': 0.036969335989648584, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.036969335989648584, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.018484667994824292, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.018484667994824292, 'ball_recoveries_per_90': 3.0314855511511842, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.486290537903839, 'saves_per_90': 1.9039208034669022, 'goals_conceded_per_90': 0.5915093758343773, 'smothers_per_90': 0.0, 'collections_per_90': 0.6654480478136746, 'punches_per_90': 0.2772700199223644, 'sweeper_claims_per_90': 0.5915093758343773, 'sweeper_clears_per_90': 0.2403006839327158, 'save_percentage': 25.432098765432098, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 80.0, 'sweeper_success_rate': 100.0}
# {'player_id': 11508, 'name': 'Łukasz Skorupski', 'minutes': 4445.1, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 17.938854019032192, 'pass_accuracy': 73.47629796839729, 'progressive_passes_per_90': 6.6815144766147, 'progressive_pass_accuracy': 33.63636363636363, 'long_passes_per_90': 6.6612674630492, 'long_pass_accuracy': 31.61094224924012, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 5.547681716946751, 'shots_per_90': 0.020247013565499086, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.004274292366875885, 'first_time_shots_per_90': 0.020247013565499086, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.14172909495849362, 'pressures_per_90': 0.060741040696497266, 'blocks_per_90': 0.02024701356549909, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.996558007693865, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 8.362016602551124, 'saves_per_90': 1.7817371937639197, 'goals_conceded_per_90': 0.8503745697509617, 'smothers_per_90': 0.04049402713099818, 'collections_per_90': 0.5871633933994735, 'punches_per_90': 0.5061753391374773, 'sweeper_claims_per_90': 0.6276574205304718, 'sweeper_clears_per_90': 0.3037052034824863, 'save_percentage': 21.307506053268767, 'smother_success_rate': 50.0, 'collection_success_rate': 100.0, 'punch_success_rate': 76.0, 'sweeper_success_rate': 100.0}
# {'player_id': 7132, 'name': 'Andrea Consigli', 'minutes': 5296.5, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 22.36193712829227, 'pass_accuracy': 70.51671732522796, 'progressive_passes_per_90': 10.654205607476635, 'progressive_pass_accuracy': 42.10526315789473, 'long_passes_per_90': 11.367884451996602, 'long_pass_accuracy': 43.19880418535127, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 9.430756159728123, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.016992353440951572, 'successful_dribbles_per_90': 0.016992353440951572, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.118946474086661, 'pressures_per_90': 0.033984706881903144, 'blocks_per_90': 0.016992353440951572, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.2795242141036534, 'fouls_made_per_90': 0.033984706881903144, 'yellow_cards_per_90': 0.016992353440951572, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.612574341546304, 'saves_per_90': 1.7672047578589634, 'goals_conceded_per_90': 0.6287170773152081, 'smothers_per_90': 0.016992353440951572, 'collections_per_90': 0.44180118946474084, 'punches_per_90': 0.356839422259983, 'sweeper_claims_per_90': 0.475785896346644, 'sweeper_clears_per_90': 0.16992353440951571, 'save_percentage': 23.214285714285715, 'smother_success_rate': 100.0, 'collection_success_rate': 100.0, 'punch_success_rate': 71.42857142857143, 'sweeper_success_rate': 100.0}
# {'player_id': 7174, 'name': 'Antonio Mirante', 'minutes': 4721.33, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 21.178354404373344, 'pass_accuracy': 60.12601260126013, 'progressive_passes_per_90': 13.591509172203596, 'progressive_pass_accuracy': 40.67321178120617, 'long_passes_per_90': 13.915570400713358, 'long_pass_accuracy': 40.68493150684932, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 7.605907657376205, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.05718727561936997, 'successful_dribbles_per_90': 0.05718727561936997, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.09531212603228327, 'pressures_per_90': 0.019062425206456655, 'blocks_per_90': 0.019062425206456655, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.03812485041291331, 'clearances_per_90': 0.019062425206456655, 'ball_recoveries_per_90': 3.6027983640203076, 'fouls_made_per_90': 0.019062425206456655, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.019062425206456655, 'duels_per_90': 0.019062425206456655, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 8.158717988363449, 'saves_per_90': 1.925304945852122, 'goals_conceded_per_90': 0.7815594334647229, 'smothers_per_90': 0.0, 'collections_per_90': 0.7434345830518095, 'punches_per_90': 0.40031092933558976, 'sweeper_claims_per_90': 0.7624970082582662, 'sweeper_clears_per_90': 0.11437455123873994, 'save_percentage': 23.598130841121495, 'smother_success_rate': 0, 'collection_success_rate': 92.3076923076923, 'punch_success_rate': 76.19047619047619, 'sweeper_success_rate': 100.0}
# {'player_id': 7036, 'name': 'Gianluigi Donnarumma', 'minutes': 4177.4, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.56240723895246, 'pass_accuracy': 69.60352422907489, 'progressive_passes_per_90': 8.854790060803372, 'progressive_pass_accuracy': 36.496350364963504, 'long_passes_per_90': 8.747067553980946, 'long_pass_accuracy': 34.97536945812808, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 7.712931488485662, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.12926700818691053, 'pressures_per_90': 0.08617800545794035, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.02154450136448509, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.188586201943793, 'fouls_made_per_90': 0.02154450136448509, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.4543974721118405, 'saves_per_90': 1.7881936132522624, 'goals_conceded_per_90': 0.6247905395700676, 'smothers_per_90': 0.02154450136448509, 'collections_per_90': 0.43089002728970177, 'punches_per_90': 0.4955235313831571, 'sweeper_claims_per_90': 0.6032460382055825, 'sweeper_clears_per_90': 0.236989515009336, 'save_percentage': 23.98843930635838, 'smother_success_rate': 100.0, 'collection_success_rate': 95.0, 'punch_success_rate': 73.91304347826086, 'sweeper_success_rate': 100.0}
# {'player_id': 7018, 'name': 'Emiliano Viviano', 'minutes': 5294.0, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 22.627502833396296, 'pass_accuracy': 59.429000751314796, 'progressive_passes_per_90': 14.518322629391765, 'progressive_pass_accuracy': 39.2271662763466, 'long_passes_per_90': 14.994333207404608, 'long_pass_accuracy': 39.909297052154194, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.017000377786173027, 'assists_per_90': 0.0, 'passes_received_per_90': 7.769172648281073, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.1360030222893842, 'pressures_per_90': 0.1360030222893842, 'blocks_per_90': 0.03400075557234605, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.05100113335851908, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.366074801662259, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 9.94522100491122, 'saves_per_90': 2.431054023422743, 'goals_conceded_per_90': 0.9180204004533434, 'smothers_per_90': 0.05100113335851908, 'collections_per_90': 0.8670192670948244, 'punches_per_90': 0.34000755572346053, 'sweeper_claims_per_90': 0.4420098224404987, 'sweeper_clears_per_90': 0.15300340007555724, 'save_percentage': 24.444444444444443, 'smother_success_rate': 66.66666666666666, 'collection_success_rate': 98.0392156862745, 'punch_success_rate': 65.0, 'sweeper_success_rate': 100.0}
# {'player_id': 6991, 'name': 'Etrit Berisha', 'minutes': 1467.07, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 14.477836776704587, 'pass_accuracy': 71.61016949152543, 'progressive_passes_per_90': 6.625450728322439, 'progressive_pass_accuracy': 44.44444444444444, 'long_passes_per_90': 7.300265154355279, 'long_pass_accuracy': 46.21848739495798, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 4.8463945142358575, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.18404029800895663, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.515217406122407, 'fouls_made_per_90': 0.12269353200597108, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.06134676600298554, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 5.950636302289597, 'saves_per_90': 1.7790562140865807, 'goals_conceded_per_90': 0.797507958038812, 'smothers_per_90': 0.06134676600298554, 'collections_per_90': 0.6748144260328409, 'punches_per_90': 0.18404029800895663, 'sweeper_claims_per_90': 0.42942736202089876, 'sweeper_clears_per_90': 0.18404029800895663, 'save_percentage': 29.896907216494846, 'smother_success_rate': 100.0, 'collection_success_rate': 90.9090909090909, 'punch_success_rate': 66.66666666666666, 'sweeper_success_rate': 100.0}
# {'player_id': 7803, 'name': 'Albano Benjamín Bizzarri', 'minutes': 4995.4, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.800216198902994, 'pass_accuracy': 54.14012738853503, 'progressive_passes_per_90': 13.494414861672741, 'progressive_pass_accuracy': 34.57943925233645, 'long_passes_per_90': 13.494414861672741, 'long_pass_accuracy': 34.57943925233645, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 5.963486407494896, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.03603315049845859, 'successful_dribbles_per_90': 0.03603315049845859, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.018016575249229293, 'fouls_won_per_90': 0.07206630099691717, 'pressures_per_90': 0.09008287624614647, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.03603315049845859, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.2429835448612727, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 9.891099811826882, 'saves_per_90': 2.252071906153662, 'goals_conceded_per_90': 0.738679585218401, 'smothers_per_90': 0.018016575249229293, 'collections_per_90': 0.6846298594707131, 'punches_per_90': 0.25223205348921013, 'sweeper_claims_per_90': 0.45041438123073235, 'sweeper_clears_per_90': 0.03603315049845859, 'save_percentage': 22.768670309653917, 'smother_success_rate': 100.0, 'collection_success_rate': 94.73684210526315, 'punch_success_rate': 71.42857142857143, 'sweeper_success_rate': 100.0}
# {'player_id': 6949, 'name': 'Gianluigi Buffon', 'minutes': 4984.1, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 16.03499127224574, 'pass_accuracy': 81.19369369369369, 'progressive_passes_per_90': 5.272767400333058, 'progressive_pass_accuracy': 47.94520547945205, 'long_passes_per_90': 5.525571316787383, 'long_pass_accuracy': 48.03921568627451, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 6.320097911358118, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.018057422603880338, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.018057422603880338, 'ball_recoveries_per_90': 2.6724985453742898, 'fouls_made_per_90': 0.018057422603880338, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.018057422603880338, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 5.796432655845589, 'saves_per_90': 1.390421540498786, 'goals_conceded_per_90': 0.2889187616620854, 'smothers_per_90': 0.0, 'collections_per_90': 0.21668907124656406, 'punches_per_90': 0.10834453562328203, 'sweeper_claims_per_90': 0.30697618426596573, 'sweeper_clears_per_90': 0.1444593808310427, 'save_percentage': 23.98753894080997, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 66.66666666666666, 'sweeper_success_rate': 100.0}
# {'player_id': 40529, 'name': 'Morgan De Sanctis', 'minutes': 565.37, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 12.57583529370147, 'pass_accuracy': 74.68354430379746, 'progressive_passes_per_90': 5.094009232891734, 'progressive_pass_accuracy': 40.625, 'long_passes_per_90': 5.094009232891734, 'long_pass_accuracy': 37.5, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 5.889948175531068, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.1591877885278667, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.591877885278667, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 5.253197021419601, 'saves_per_90': 1.9102534623344005, 'goals_conceded_per_90': 0.9551267311672003, 'smothers_per_90': 0.0, 'collections_per_90': 0.3183755770557334, 'punches_per_90': 0.1591877885278667, 'sweeper_claims_per_90': 0.47756336558360013, 'sweeper_clears_per_90': 0.1591877885278667, 'save_percentage': 36.36363636363637, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 100.0, 'sweeper_success_rate': 100.0}
# {'player_id': 8274, 'name': 'Pierluigi Gollini', 'minutes': 3700.92, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 20.50030803151649, 'pass_accuracy': 55.39739027283511, 'progressive_passes_per_90': 14.201874128595053, 'progressive_pass_accuracy': 37.5, 'long_passes_per_90': 14.323465516682338, 'long_pass_accuracy': 37.011884550084886, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 6.784799455270582, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.17022794332220098, 'pressures_per_90': 0.12159138808728641, 'blocks_per_90': 0.024318277617457282, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.024318277617457282, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.3316040335916477, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 8.389805778022762, 'saves_per_90': 1.7509159884569243, 'goals_conceded_per_90': 1.045685937550663, 'smothers_per_90': 0.024318277617457282, 'collections_per_90': 0.5106838299666029, 'punches_per_90': 0.4377289971142311, 'sweeper_claims_per_90': 0.6809117732888039, 'sweeper_clears_per_90': 0.17022794332220098, 'save_percentage': 20.869565217391305, 'smother_success_rate': 100.0, 'collection_success_rate': 95.23809523809523, 'punch_success_rate': 77.77777777777779, 'sweeper_success_rate': 100.0}
# {'player_id': 7055, 'name': 'Stefano Sorrentino', 'minutes': 4891.82, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.649128545204036, 'pass_accuracy': 56.46067415730337, 'progressive_passes_per_90': 14.276894898013419, 'progressive_pass_accuracy': 41.75257731958763, 'long_passes_per_90': 14.332089079320172, 'long_pass_accuracy': 41.206675224646986, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.018398060435584302, 'assists_per_90': 0.0, 'passes_received_per_90': 3.7348062684236134, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.018398060435584302, 'successful_dribbles_per_90': 0.018398060435584302, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.036796120871168604, 'pressures_per_90': 0.12878642304909013, 'blocks_per_90': 0.018398060435584302, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.036796120871168604, 'clearances_per_90': 0.07359224174233721, 'ball_recoveries_per_90': 3.458835361889849, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.018398060435584302, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 10.063739058264614, 'saves_per_90': 2.318155614883622, 'goals_conceded_per_90': 1.0118933239571366, 'smothers_per_90': 0.018398060435584302, 'collections_per_90': 0.40475732958285465, 'punches_per_90': 0.7543204778589564, 'sweeper_claims_per_90': 0.607135994374282, 'sweeper_clears_per_90': 0.07359224174233721, 'save_percentage': 23.03473491773309, 'smother_success_rate': 0.0, 'collection_success_rate': 100.0, 'punch_success_rate': 70.73170731707317, 'sweeper_success_rate': 100.0}
# {'player_id': 38312, 'name': 'Eugenio Lamanna', 'minutes': 1851.7, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 17.254414862018685, 'pass_accuracy': 65.07042253521126, 'progressive_passes_per_90': 8.554301452719123, 'progressive_pass_accuracy': 33.52272727272727, 'long_passes_per_90': 8.894529351406815, 'long_pass_accuracy': 33.33333333333333, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0486039855268132, 'assists_per_90': 0.0, 'passes_received_per_90': 5.006210509261759, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0486039855268132, 'pressures_per_90': 0.0972079710536264, 'blocks_per_90': 0.0972079710536264, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.673219203974726, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 8.50569746719231, 'saves_per_90': 1.8955554355457147, 'goals_conceded_per_90': 0.8262677539558243, 'smothers_per_90': 0.0, 'collections_per_90': 0.486039855268132, 'punches_per_90': 0.6318518118485715, 'sweeper_claims_per_90': 0.6318518118485715, 'sweeper_clears_per_90': 0.1944159421072528, 'save_percentage': 22.285714285714285, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 61.53846153846154, 'sweeper_success_rate': 100.0}
# {'player_id': 12475, 'name': 'Angelo Esmael da Costa Júnior', 'minutes': 722.6, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 18.557985053971766, 'pass_accuracy': 63.758389261744966, 'progressive_passes_per_90': 9.590368115139771, 'progressive_pass_accuracy': 31.16883116883117, 'long_passes_per_90': 10.088569056185994, 'long_pass_accuracy': 33.33333333333333, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.12455023526155548, 'assists_per_90': 0.0, 'passes_received_per_90': 6.974813174647107, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.12455023526155548, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.4910047052311097, 'fouls_made_per_90': 0.12455023526155548, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.12455023526155548, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.099363409908662, 'saves_per_90': 1.6191530584002212, 'goals_conceded_per_90': 0.4982009410462219, 'smothers_per_90': 0.0, 'collections_per_90': 0.6227511763077774, 'punches_per_90': 0.3736507057846664, 'sweeper_claims_per_90': 0.4982009410462219, 'sweeper_clears_per_90': 0.24910047052311096, 'save_percentage': 22.807017543859647, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 66.66666666666666, 'sweeper_success_rate': 100.0}
# {'player_id': 7123, 'name': 'Gianluca Pegolo', 'minutes': 253.6, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 22.00315457413249, 'pass_accuracy': 62.903225806451616, 'progressive_passes_per_90': 13.840694006309148, 'progressive_pass_accuracy': 46.15384615384615, 'long_passes_per_90': 15.260252365930599, 'long_pass_accuracy': 48.837209302325576, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 6.033123028391167, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.3548895899053628, 'blocks_per_90': 0.3548895899053628, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 4.2586750788643535, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 12.066246056782335, 'saves_per_90': 1.4195583596214512, 'goals_conceded_per_90': 0.7097791798107256, 'smothers_per_90': 0.0, 'collections_per_90': 1.0646687697160884, 'punches_per_90': 0.3548895899053628, 'sweeper_claims_per_90': 0.3548895899053628, 'sweeper_clears_per_90': 0.3548895899053628, 'save_percentage': 11.76470588235294, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 0.0, 'sweeper_success_rate': 100.0}
# {'player_id': 6768, 'name': 'Diego López Rodríguez', 'minutes': 1144.6, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.264371832954748, 'pass_accuracy': 77.14285714285715, 'progressive_passes_per_90': 8.413419535208808, 'progressive_pass_accuracy': 50.467289719626166, 'long_passes_per_90': 9.51424078280622, 'long_pass_accuracy': 54.54545454545454, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.078630089114101, 'assists_per_90': 0.0, 'passes_received_per_90': 7.155338109383192, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.078630089114101, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.078630089114101, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.3024637427922423, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.863008911410101, 'saves_per_90': 1.258081425825616, 'goals_conceded_per_90': 1.022191158483313, 'smothers_per_90': 0.0, 'collections_per_90': 0.471780534684606, 'punches_per_90': 0.39315044557050505, 'sweeper_claims_per_90': 0.157260178228202, 'sweeper_clears_per_90': 0.157260178228202, 'save_percentage': 16.0, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 60.0, 'sweeper_success_rate': 100.0}
# {'player_id': 8662, 'name': 'Vid Belec', 'minutes': 4314.63, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 17.792950959873732, 'pass_accuracy': 42.20398593200469, 'progressive_passes_per_90': 13.7462540240994, 'progressive_pass_accuracy': 27.010622154779966, 'long_passes_per_90': 14.14258001265462, 'long_pass_accuracy': 27.581120943952804, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 3.608652422108037, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.020859262555537786, 'successful_dribbles_per_90': 0.020859262555537786, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.10429631277768893, 'pressures_per_90': 0.020859262555537786, 'blocks_per_90': 0.020859262555537786, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.04171852511107557, 'ball_recoveries_per_90': 3.400059796552659, 'fouls_made_per_90': 0.020859262555537786, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.020859262555537786, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 8.427142072437265, 'saves_per_90': 1.8773336299984007, 'goals_conceded_per_90': 0.8552297647770493, 'smothers_per_90': 0.0, 'collections_per_90': 0.5632000889995202, 'punches_per_90': 0.4797630387773691, 'sweeper_claims_per_90': 0.3754667259996801, 'sweeper_clears_per_90': 0.12515557533322672, 'save_percentage': 22.277227722772277, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 82.6086956521739, 'sweeper_success_rate': 100.0}
# ...
# {'player_id': 34315, 'name': 'Simone Colombi', 'minutes': 286.13, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 14.468947681123964, 'pass_accuracy': 47.82608695652174, 'progressive_passes_per_90': 9.436270226819977, 'progressive_pass_accuracy': 20.0, 'long_passes_per_90': 10.065354908607976, 'long_pass_accuracy': 25.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 3.4599657498339917, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.145423408939992, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 9.121727885925978, 'saves_per_90': 2.201796386257995, 'goals_conceded_per_90': 0.6290846817879985, 'smothers_per_90': 0.0, 'collections_per_90': 0.6290846817879985, 'punches_per_90': 0.9436270226819977, 'sweeper_claims_per_90': 0.0, 'sweeper_clears_per_90': 0.31454234089399924, 'save_percentage': 24.137931034482758, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 100.0, 'sweeper_success_rate': 100.0}
# {'player_id': 6590, 'name': 'Norberto Murara Neto', 'minutes': 419.23, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 10.519285356486892, 'pass_accuracy': 95.91836734693877, 'progressive_passes_per_90': 1.9321136369057557, 'progressive_pass_accuracy': 77.77777777777779, 'long_passes_per_90': 1.9321136369057557, 'long_pass_accuracy': 77.77777777777779, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 3.649547980821983, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.576151515874341, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.225699496696324, 'saves_per_90': 0.6440378789685852, 'goals_conceded_per_90': 0.6440378789685852, 'smothers_per_90': 0.0, 'collections_per_90': 0.21467929298952843, 'punches_per_90': 0.21467929298952843, 'sweeper_claims_per_90': 0.21467929298952843, 'sweeper_clears_per_90': 0.0, 'save_percentage': 10.344827586206897, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 100.0, 'sweeper_success_rate': 100.0}
# {'player_id': 7804, 'name': 'Alberto Brignoli', 'minutes': 135.03, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 29.326816263052656, 'pass_accuracy': 43.18181818181818, 'progressive_passes_per_90': 21.328593645856476, 'progressive_pass_accuracy': 21.875, 'long_passes_per_90': 21.328593645856476, 'long_pass_accuracy': 21.875, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 10.664296822928238, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.6665185514330149, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.3325927571650746, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 15.996445234392358, 'saves_per_90': 4.665629860031104, 'goals_conceded_per_90': 3.3325927571650746, 'smothers_per_90': 0.0, 'collections_per_90': 0.0, 'punches_per_90': 1.9995556542990447, 'sweeper_claims_per_90': 0.0, 'sweeper_clears_per_90': 0.0, 'save_percentage': 29.166666666666668, 'smother_success_rate': 0, 'collection_success_rate': 0, 'punch_success_rate': 66.66666666666666, 'sweeper_success_rate': 0}
# {'player_id': 386510, 'name': 'Massimo Zenildo Zappino', 'minutes': 520.87, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 20.216176781154605, 'pass_accuracy': 60.68376068376068, 'progressive_passes_per_90': 15.896480887745502, 'progressive_pass_accuracy': 52.17391304347826, 'long_passes_per_90': 16.414844394954596, 'long_pass_accuracy': 53.68421052631579, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.34557567147272833, 'assists_per_90': 0.0, 'passes_received_per_90': 4.4924837291454685, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.110181043254555, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 17.969934916581874, 'saves_per_90': 3.455756714727283, 'goals_conceded_per_90': 2.4190297003090984, 'smothers_per_90': 0.0, 'collections_per_90': 0.8639391786818208, 'punches_per_90': 0.34557567147272833, 'sweeper_claims_per_90': 0.34557567147272833, 'sweeper_clears_per_90': 0.5183635072090924, 'save_percentage': 19.230769230769234, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 100.0, 'sweeper_success_rate': 100.0}
# {'player_id': 13614, 'name': 'Francesco Bardi', 'minutes': 174.73, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 21.118296800778346, 'pass_accuracy': 31.70731707317073, 'progressive_passes_per_90': 19.5730555714531, 'progressive_pass_accuracy': 28.947368421052634, 'long_passes_per_90': 19.5730555714531, 'long_pass_accuracy': 28.947368421052634, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 2.575402048875408, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.605562868425571, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 15.452412293252447, 'saves_per_90': 5.150804097750816, 'goals_conceded_per_90': 1.5452412293252449, 'smothers_per_90': 0.0, 'collections_per_90': 1.0301608195501633, 'punches_per_90': 1.0301608195501633, 'sweeper_claims_per_90': 0.5150804097750816, 'sweeper_clears_per_90': 0.0, 'save_percentage': 33.33333333333333, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 100.0, 'sweeper_success_rate': 100.0}
# {'player_id': 30767, 'name': 'Gabriel Vasconelos Ferreira', 'minutes': 146.17, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 13.545871245809675, 'pass_accuracy': 90.9090909090909, 'progressive_passes_per_90': 2.4628856810563042, 'progressive_pass_accuracy': 75.0, 'long_passes_per_90': 1.8471642607922283, 'long_pass_accuracy': 66.66666666666666, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 4.9257713621126085, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.6157214202640761, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.8471642607922283, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.772935622904837, 'saves_per_90': 2.4628856810563042, 'goals_conceded_per_90': 1.8471642607922283, 'smothers_per_90': 0.0, 'collections_per_90': 0.0, 'punches_per_90': 0.0, 'sweeper_claims_per_90': 0.0, 'sweeper_clears_per_90': 0.0, 'save_percentage': 36.36363636363637, 'smother_success_rate': 0, 'collection_success_rate': 0, 'punch_success_rate': 0, 'sweeper_success_rate': 0}
# {'player_id': 29161, 'name': 'Josip Posavec', 'minutes': 140.97, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 24.89891466269419, 'pass_accuracy': 56.41025641025641, 'progressive_passes_per_90': 17.87614386039583, 'progressive_pass_accuracy': 42.857142857142854, 'long_passes_per_90': 18.51457756969568, 'long_pass_accuracy': 44.827586206896555, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 5.107469674398808, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.638433709299851, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.638433709299851, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 7.0227708022983615, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 10.853373058097468, 'saves_per_90': 3.1921685464992553, 'goals_conceded_per_90': 0.0, 'smothers_per_90': 0.0, 'collections_per_90': 0.638433709299851, 'punches_per_90': 0.638433709299851, 'sweeper_claims_per_90': 0.0, 'sweeper_clears_per_90': 0.0, 'save_percentage': 29.411764705882355, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 100.0, 'sweeper_success_rate': 0}
# {'player_id': 41067, 'name': 'Davide Bassi', 'minutes': 142.93, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 23.29811795984048, 'pass_accuracy': 48.64864864864865, 'progressive_passes_per_90': 15.74197159448681, 'progressive_pass_accuracy': 32.0, 'long_passes_per_90': 15.74197159448681, 'long_pass_accuracy': 32.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 6.926467501574196, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.51871545511789, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 8.815504092912613, 'saves_per_90': 1.8890365913384173, 'goals_conceded_per_90': 1.8890365913384173, 'smothers_per_90': 0.0, 'collections_per_90': 1.8890365913384173, 'punches_per_90': 0.0, 'sweeper_claims_per_90': 2.51871545511789, 'sweeper_clears_per_90': 0.0, 'save_percentage': 21.428571428571427, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 0, 'sweeper_success_rate': 100.0}
# {'player_id': 57655, 'name': 'Željko Brkić', 'minutes': 541.58, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 14.45769784704014, 'pass_accuracy': 51.724137931034484, 'progressive_passes_per_90': 9.804645666383545, 'progressive_pass_accuracy': 30.508474576271187, 'long_passes_per_90': 9.804645666383545, 'long_pass_accuracy': 28.8135593220339, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 3.323608700468998, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.1661804350234499, 'pressures_per_90': 0.1661804350234499, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.1661804350234499, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.991247830422098, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 9.139923926289745, 'saves_per_90': 2.1603456553048486, 'goals_conceded_per_90': 1.9941652202813986, 'smothers_per_90': 0.0, 'collections_per_90': 0.6647217400937996, 'punches_per_90': 0.1661804350234499, 'sweeper_claims_per_90': 0.3323608700468998, 'sweeper_clears_per_90': 0.3323608700468998, 'save_percentage': 23.636363636363637, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 100.0, 'sweeper_success_rate': 100.0}

# %% [raw]
# Involvement data

# %%
# Define event type IDs that count as touches
# (You should adjust this list based on your event types)
touch_event_types = {
    42, # Reception
    2, # Recovery
    3, # Dispossessed
    4, # Duel
    6, # Block
    9, # Clearance
    10,  # Interception
    14,  # Dribble 
    16, # Shot
    21, # Foul Won
    23, #Goalkeeper
    30, # Pass
    33, #50-50
    37, #Error
    38, # Miscontrol
    43, # Carry
    
    # Add other event IDs that mean ball touch here
}

other_stats = defaultdict(lambda: {
    'x_total': 0.0,
    'y_total': 0.0,
    'touches': 0
})

for match_id, events in all_events.items():
    for event in events:
        player = event.get('player')
        location = event.get('location')
        etype = event.get('type', {}).get('id')

        # Skip if no player, location, or type
        if not player or not location or len(location) < 2 or etype not in touch_event_types:
            continue

        pid = player['id']
        x, y = location[0], location[1]

        other_stats[pid]['x_total'] += x
        other_stats[pid]['y_total'] += y
        other_stats[pid]['touches'] += 1

# %%
# Add to player data
for player in player_data:
    pid = player['player_id']
    minutes = player.get('minutes', 0)
    stats = other_stats.get(pid, {})

    if minutes > 0 and stats.get('touches', 0) > 0:
        factor = minutes / 90
        player['touches_per_90'] = stats['touches'] / factor
        player['average_position_x'] = stats['x_total'] / stats['touches']
        player['average_position_y'] = stats['y_total'] / stats['touches']
    else:
        player['touches_per_90'] = 0
        player['average_position_x'] = None
        player['average_position_y'] = None

# %%
print(player_data)
# Out:
# [{'player_id': 3577, 'name': 'Molla Wagué', 'minutes': 2736.15, 'most_played_position': 'Right Center Back', 'position': 'center back', 'passes_per_90': 20.62386930541089, 'pass_accuracy': 80.22328548644339, 'progressive_passes_per_90': 5.657584562249877, 'progressive_pass_accuracy': 57.55813953488372, 'long_passes_per_90': 2.302505345101694, 'long_pass_accuracy': 34.285714285714285, 'crosses_per_90': 0.16446466750726385, 'cross_accuracy': 40.0, 'key_passes_per_90': 0.13157173400581107, 'assists_per_90': 0.0, 'passes_received_per_90': 14.341319006633407, 'shots_per_90': 0.3618222685159805, 'shots_on_target_per_90': 0.06578586700290555, 'shot_accuracy': 0.182, 'goals_per_90': 0.0, 'xg_per_90': 0.03009917209582808, 'first_time_shots_per_90': 0.032892933501452774, 'headers_per_90': 0.23025053451016939, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.06578586700290553, 'successful_dribbles_per_90': 0.03289293350145277, 'dribble_success_rate': 50.0, 'progressive_runs_per_90': 0.49339400252179155, 'fouls_won_per_90': 0.723644537031961, 'pressures_per_90': 9.473164848418397, 'blocks_per_90': 1.3815032070610163, 'interceptions_per_90': 1.1183597390493942, 'dribbled_past_per_90': 0.03289293350145277, 'clearances_per_90': 3.157721616139466, 'ball_recoveries_per_90': 2.269612411600241, 'fouls_made_per_90': 1.0525738720464886, 'yellow_cards_per_90': 0.03289293350145277, 'red_cards_per_90': 0.23025053451016939, 'duels_per_90': 2.3682912121045994, 'duels_won_per_90': 0.39471520201743326, 'duel_success_rate': 16.666666666666664, 'touches_per_90': 59.43753083712516, 'average_position_x': 46.5006640841174, 'average_position_y': 57.130547869396736}, {'player_id': 6577, 'name': 'Zdravko Kuzmanović', 'minutes': 1769.95, 'most_played_position': 'Center Defensive Midfield', 'position': 'midfielder', 'passes_per_90': 29.39066075312862, 'pass_accuracy': 82.17993079584775, 'progressive_passes_per_90': 8.6443119862143, 'progressive_pass_accuracy': 65.29411764705883, 'long_passes_per_90': 3.813667052741603, 'long_pass_accuracy': 58.666666666666664, 'crosses_per_90': 0.45764004632899236, 'cross_accuracy': 22.22222222222222, 'key_passes_per_90': 0.4067911522924377, 'assists_per_90': 0.0, 'passes_received_per_90': 24.407469137546258, 'shots_per_90': 0.4067911522924376, 'shots_on_target_per_90': 0.1016977880731094, 'shot_accuracy': 0.25, 'goals_per_90': 0.0, 'xg_per_90': 0.03600322692166445, 'first_time_shots_per_90': 0.30509336421932826, 'headers_per_90': 0.1016977880731094, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.5593378344021017, 'successful_dribbles_per_90': 0.30509336421932826, 'dribble_success_rate': 54.54545454545454, 'progressive_runs_per_90': 0.6101867284386565, 'fouls_won_per_90': 0.6101867284386565, 'pressures_per_90': 12.152885674736575, 'blocks_per_90': 0.9661289866945394, 'interceptions_per_90': 0.45764004632899236, 'dribbled_past_per_90': 0.45764004632899236, 'clearances_per_90': 0.8135823045848753, 'ball_recoveries_per_90': 4.017062628887822, 'fouls_made_per_90': 1.6271646091697507, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.2542444701827735, 'duels_per_90': 1.4237690330235317, 'duels_won_per_90': 0.15254668210966413, 'duel_success_rate': 10.714285714285714, 'touches_per_90': 86.18887539196022, 'average_position_x': 58.53380530973444, 'average_position_y': 38.67050147492618}, {'player_id': 386607, 'name': 'Gianpaolo Bellini', 'minutes': 1397.02, 'most_played_position': 'Right Back', 'position': 'full back', 'passes_per_90': 32.59795851168917, 'pass_accuracy': 80.8300395256917, 'progressive_passes_per_90': 10.951883294441025, 'progressive_pass_accuracy': 70.58823529411765, 'long_passes_per_90': 3.4144106741492606, 'long_pass_accuracy': 37.735849056603776, 'crosses_per_90': 0.8374969578101961, 'cross_accuracy': 30.76923076923077, 'key_passes_per_90': 0.06442284290847662, 'assists_per_90': 0.0, 'passes_received_per_90': 20.615309730712518, 'shots_per_90': 0.3865370574508597, 'shots_on_target_per_90': 0.064422842908476 ...

# %%
import math

def check_nan_or_errors(player_data):
    problematic = []
    for player in player_data:
        for key, value in player.items():
            if value is None:
                problematic.append((player.get('player_id', 'unknown'), key, 'None'))
            elif isinstance(value, float) and math.isnan(value):
                problematic.append((player.get('player_id', 'unknown'), key, 'NaN'))
            # You can add more error checks here if needed

    if problematic:
        print("Found NaN or None in the following player stats:")
        for pid, col, val in problematic:
            print(f"Player {pid} - Column: {col} - Value: {val}")
    else:
        print("No NaN or None values found in player stats.")

check_nan_or_errors(player_data)
# Out:
# Found NaN or None in the following player stats:
# Player 13428 - Column: average_position_x - Value: None
# Player 13428 - Column: average_position_y - Value: None

# %%
for player in player_data:
    if player.get('player_id') == 206604:
        print(player)
        break

# %%
unknown_positions = sum(1 for player in player_data if player.get('most_played_position') == 'Unknown')
print(f"Number of players with 'Unknown' position: {unknown_positions}")
# Out:
# Number of players with 'Unknown' position: 38

# %%
for player in player_data:
    if player.get('most_played_position') == 'Unknown':
        print(player)
# Out:
# {'player_id': 7466, 'name': 'Simone Edera', 'minutes': 101.7, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 0.8849557522123893, 'pass_accuracy': 100.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 5.309734513274336, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 1.7699115044247786, 'pressures_per_90': 2.654867256637168, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 10.619469026548671, 'average_position_x': 77.34166666666665, 'average_position_y': 42.12499999999999}
# {'player_id': 16495, 'name': 'Omar El Kaddouri', 'minutes': 1280.15, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 12.022028668515407, 'pass_accuracy': 85.38011695906432, 'progressive_passes_per_90': 2.249736359020427, 'progressive_pass_accuracy': 78.125, 'long_passes_per_90': 0.4921298285357184, 'long_pass_accuracy': 57.14285714285714, 'crosses_per_90': 0.3515213060969417, 'cross_accuracy': 60.0, 'key_passes_per_90': 0.4921298285357184, 'assists_per_90': 0.1406085224387767, 'passes_received_per_90': 15.959067296801155, 'shots_per_90': 0.7733468734132718, 'shots_on_target_per_90': 0.35152130609694177, 'shot_accuracy': 0.455, 'goals_per_90': 0.07030426121938835, 'xg_per_90': 0.12258011410381595, 'first_time_shots_per_90': 0.2812170448775534, 'headers_per_90': 0.07030426121938835, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.6327383509744952, 'successful_dribbles_per_90': 0.2812170448775534, 'dribble_success_rate': 44.44444444444444, 'progressive_runs_per_90': 1.827910791704097, 'fouls_won_per_90': 0.6327383509744952, 'pressures_per_90': 6.116470726086786, 'blocks_per_90': 0.3515213060969417, 'interceptions_per_90': 0.4218255673163301, 'dribbled_past_per_90': 0.1406085224387767, 'clearances_per_90': 0.1406085224387767, 'ball_recoveries_per_90': 1.2654767019489903, 'fouls_made_per_90': 0.7733468734132718, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.1406085224387767, 'duels_per_90': 0.7030426121938834, 'duels_won_per_90': 0.21091278365816504, 'duel_success_rate': 30.0, 'touches_per_90': 45.838378315041204, 'average_position_x': 74.76840490797552, 'average_position_y': 40.64923312883432}
# {'player_id': 20637, 'name': 'Salih Uçan', 'minutes': 199.47, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 10.377500375996389, 'pass_accuracy': 86.95652173913044, 'progressive_passes_per_90': 0.9023913370431643, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 0.45119566852158216, 'long_pass_accuracy': 100.0, 'crosses_per_90': 0.45119566852158216, 'cross_accuracy': 100.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.45119566852158216, 'passes_received_per_90': 13.084674387125883, 'shots_per_90': 0.45119566852158216, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.04940319867649271, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.45119566852158216, 'successful_dribbles_per_90': 0.45119566852158216, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.9023913370431643, 'fouls_won_per_90': 0.45119566852158216, 'pressures_per_90': 9.023913370431643, 'blocks_per_90': 0.9023913370431643, 'interceptions_per_90': 0.9023913370431643, 'dribbled_past_per_90': 0.45119566852158216, 'clearances_per_90': 0.45119566852158216, 'ball_recoveries_per_90': 1.8047826740863286, 'fouls_made_per_90': 1.3535870055647465, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 3.158369679651075, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 40.60761016694239, 'average_position_x': 65.30888888888884, 'average_position_y': 40.24888888888889}
# {'player_id': 7773, 'name': 'Federico Bonazzoli', 'minutes': 277.7, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 7.454087144400432, 'pass_accuracy': 91.30434782608695, 'progressive_passes_per_90': 0.9722722362261433, 'progressive_pass_accuracy': 66.66666666666666, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.3240907454087144, 'assists_per_90': 0.0, 'passes_received_per_90': 12.639539070939863, 'shots_per_90': 0.32409074540871446, 'shots_on_target_per_90': 0.32409074540871446, 'shot_accuracy': 1.0, 'goals_per_90': 0.0, 'xg_per_90': 0.011051070507742167, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.3240907454087144, 'successful_dribbles_per_90': 0.3240907454087144, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.9722722362261433, 'pressures_per_90': 4.213179690313288, 'blocks_per_90': 0.6481814908174288, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.6481814908174288, 'fouls_made_per_90': 0.3240907454087144, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.9722722362261433, 'duels_won_per_90': 0.6481814908174288, 'duel_success_rate': 66.66666666666666, 'touches_per_90': 33.38134677709758, 'average_position_x': 71.38640776699027, 'average_position_y': 47.97184466019418}
# {'player_id': 4407, 'name': 'Sanjin Prcić', 'minutes': 130.98, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 12.368300503893726, 'pass_accuracy': 77.77777777777779, 'progressive_passes_per_90': 4.809894640403115, 'progressive_pass_accuracy': 42.857142857142854, 'long_passes_per_90': 2.748511223087495, 'long_pass_accuracy': 100.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 1.3742556115437474, 'assists_per_90': 0.0, 'passes_received_per_90': 9.61978928080623, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.6871278057718737, 'successful_dribbles_per_90': 0.6871278057718737, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 6.871278057718737, 'blocks_per_90': 1.3742556115437474, 'interceptions_per_90': 2.061383417315621, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.3742556115437474, 'fouls_made_per_90': 1.3742556115437474, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 2.061383417315621, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 38.47915712322492, 'average_position_x': 57.578571428571415, 'average_position_y': 45.66607142857141}
# {'player_id': 26827, 'name': 'Ravel Morrison', 'minutes': 267.48, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 16.1507402422611, 'pass_accuracy': 95.83333333333334, 'progressive_passes_per_90': 4.037685060565275, 'progressive_pass_accuracy': 91.66666666666666, 'long_passes_per_90': 0.6729475100942126, 'long_pass_accuracy': 100.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.3364737550471063, 'assists_per_90': 0.0, 'passes_received_per_90': 22.54374158815612, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.3458950201884252, 'successful_dribbles_per_90': 0.6729475100942126, 'dribble_success_rate': 50.0, 'progressive_runs_per_90': 2.0188425302826376, 'fouls_won_per_90': 0.3364737550471063, 'pressures_per_90': 5.0471063257065945, 'blocks_per_90': 0.3364737550471063, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.6823687752355314, 'fouls_made_per_90': 0.3364737550471063, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.3364737550471063, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 62.92059219380887, 'average_position_x': 69.5112299465241, 'average_position_y': 34.094652406417104}
# {'player_id': 20043, 'name': 'Norbert Gyömbér', 'minutes': 409.02, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 11.441983277101366, 'pass_accuracy': 80.76923076923077, 'progressive_passes_per_90': 3.9606865189966265, 'progressive_pass_accuracy': 66.66666666666666, 'long_passes_per_90': 1.7603051195540562, 'long_pass_accuracy': 50.0, 'crosses_per_90': 0.22003813994425703, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.44007627988851405, 'assists_per_90': 0.0, 'passes_received_per_90': 9.68167815754731, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.44007627988851405, 'successful_dribbles_per_90': 0.44007627988851405, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.22003813994425703, 'pressures_per_90': 5.060877218717912, 'blocks_per_90': 1.5402669796097992, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.22003813994425703, 'clearances_per_90': 1.3202288396655422, 'ball_recoveries_per_90': 1.3202288396655422, 'fouls_made_per_90': 1.1001906997212851, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.22003813994425703, 'duels_per_90': 0.8801525597770281, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 37.18644565057944, 'average_position_x': 51.62071005917161, 'average_position_y': 36.33372781065088}
# {'player_id': 40419, 'name': 'Accursio Bentivegna', 'minutes': 59.47, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 9.080208508491676, 'pass_accuracy': 66.66666666666666, 'progressive_passes_per_90': 1.5133680847486126, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 1.5133680847486126, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 12.106944677988901, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.5133680847486126, 'successful_dribbles_per_90': 1.5133680847486126, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 1.5133680847486126, 'fouls_won_per_90': 0.0, 'pressures_per_90': 3.0267361694972252, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.5133680847486126, 'fouls_made_per_90': 1.5133680847486126, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 1.5133680847486126, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 40.860938288212544, 'average_position_x': 76.85555555555555, 'average_position_y': 14.03703703703704}
# {'player_id': 23987, 'name': 'Rey Manaj', 'minutes': 246.67, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 2.9188794746016944, 'pass_accuracy': 87.5, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.3648599343252118, 'assists_per_90': 0.0, 'passes_received_per_90': 7.662058620829448, 'shots_per_90': 0.7297198686504237, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.06093606397210849, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 1.0945798029756355, 'pressures_per_90': 3.648599343252118, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 3.2837394089269063, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.3648599343252118, 'duels_per_90': 0.3648599343252118, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 17.513276847610168, 'average_position_x': 83.20208333333333, 'average_position_y': 37.50416666666667}
# {'player_id': 32722, 'name': 'Norbert Sándor Balogh', 'minutes': 256.18, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 7.728940588648607, 'pass_accuracy': 72.72727272727273, 'progressive_passes_per_90': 0.7026309626044188, 'progressive_pass_accuracy': 50.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.3513154813022094, 'cross_accuracy': 100.0, 'key_passes_per_90': 0.3513154813022094, 'assists_per_90': 0.0, 'passes_received_per_90': 14.755250214692795, 'shots_per_90': 0.7026309626044187, 'shots_on_target_per_90': 0.35131548130220935, 'shot_accuracy': 0.5, 'goals_per_90': 0.0, 'xg_per_90': 0.09197075161995473, 'first_time_shots_per_90': 0.7026309626044187, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.7565774065110469, 'successful_dribbles_per_90': 0.7026309626044188, 'dribble_success_rate': 40.0, 'progressive_runs_per_90': 1.0539464439066282, 'fouls_won_per_90': 0.0, 'pressures_per_90': 10.890779920368491, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.7565774065110469, 'fouls_made_per_90': 1.4052619252088376, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.7565774065110469, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 38.293387461940824, 'average_position_x': 79.42201834862387, 'average_position_y': 41.68990825688074}
# {'player_id': 26197, 'name': 'Christian Abbiati', 'minutes': 124.53, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 18.7906528547338, 'pass_accuracy': 50.0, 'progressive_passes_per_90': 10.118043844856661, 'progressive_pass_accuracy': 14.285714285714285, 'long_passes_per_90': 10.118043844856661, 'long_pass_accuracy': 21.428571428571427, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 7.9498915923873765, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.1681522524692847, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 10.118043844856661, 'saves_per_90': 3.6135870874488076, 'goals_conceded_per_90': 0.0, 'smothers_per_90': 0.0, 'collections_per_90': 0.0, 'punches_per_90': 0.0, 'sweeper_claims_per_90': 0.7227174174897616, 'sweeper_clears_per_90': 0.0, 'save_percentage': 35.714285714285715, 'smother_success_rate': 0, 'collection_success_rate': 0, 'punch_success_rate': 0, 'sweeper_success_rate': 100.0, 'touches_per_90': 47.699349554324264, 'average_position_x': 8.472727272727273, 'average_position_y': 37.177272727272715}
# {'player_id': 7120, 'name': 'Claud Adjapong', 'minutes': 125.02, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 9.358502639577669, 'pass_accuracy': 84.61538461538461, 'progressive_passes_per_90': 0.7198848184290514, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 4.319308910574309, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 2.1596544552871544, 'blocks_per_90': 0.7198848184290514, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.7198848184290514, 'ball_recoveries_per_90': 0.7198848184290514, 'fouls_made_per_90': 0.7198848184290514, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 2.1596544552871544, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 23.036314189729644, 'average_position_x': 48.78125000000001, 'average_position_y': 74.30937499999997}
# {'player_id': 6951, 'name': 'Filippo Costa', 'minutes': 441.62, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 14.877043612155246, 'pass_accuracy': 63.013698630136986, 'progressive_passes_per_90': 4.891082831393506, 'progressive_pass_accuracy': 45.83333333333333, 'long_passes_per_90': 2.037951179747294, 'long_pass_accuracy': 40.0, 'crosses_per_90': 0.4075902359494588, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.4075902359494588, 'assists_per_90': 0.0, 'passes_received_per_90': 12.635297314433222, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.8151804718989176, 'successful_dribbles_per_90': 0.6113853539241882, 'dribble_success_rate': 75.0, 'progressive_runs_per_90': 1.2227707078483765, 'fouls_won_per_90': 0.8151804718989176, 'pressures_per_90': 6.929034011140799, 'blocks_per_90': 1.018975589873647, 'interceptions_per_90': 0.2037951179747294, 'dribbled_past_per_90': 0.4075902359494588, 'clearances_per_90': 1.4265658258231058, 'ball_recoveries_per_90': 2.037951179747294, 'fouls_made_per_90': 0.4075902359494588, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.2227707078483765, 'duels_won_per_90': 0.2037951179747294, 'duel_success_rate': 16.666666666666664, 'touches_per_90': 47.68805760608668, 'average_position_x': 63.365811965811965, 'average_position_y': 25.567948717948724}
# {'player_id': 7694, 'name': 'Rômulo Souza Orestes Caldeira', 'minutes': 736.35, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 19.800366673456917, 'pass_accuracy': 78.39506172839506, 'progressive_passes_per_90': 2.9333876553269507, 'progressive_pass_accuracy': 62.5, 'long_passes_per_90': 1.588918313302098, 'long_pass_accuracy': 38.46153846153847, 'crosses_per_90': 0.8555713994703605, 'cross_accuracy': 28.57142857142857, 'key_passes_per_90': 0.6111224281931147, 'assists_per_90': 0.12222448563862294, 'passes_received_per_90': 22.367080871867998, 'shots_per_90': 1.3444693420248521, 'shots_on_target_per_90': 0.4888979425544917, 'shot_accuracy': 0.364, 'goals_per_90': 0.0, 'xg_per_90': 0.08828733746180485, 'first_time_shots_per_90': 0.7333469138317376, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.8555713994703605, 'successful_dribbles_per_90': 0.36667345691586883, 'dribble_success_rate': 42.857142857142854, 'progressive_runs_per_90': 1.588918313302098, 'fouls_won_per_90': 0.48889794255449176, 'pressures_per_90': 5.744550825015278, 'blocks_per_90': 0.6111224281931147, 'interceptions_per_90': 0.36667345691586883, 'dribbled_past_per_90': 0.36667345691586883, 'clearances_per_90': 0.24444897127724588, 'ball_recoveries_per_90': 3.3000611122428194, 'fouls_made_per_90': 0.48889794255449176, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.1000203707476064, 'duels_won_per_90': 0.12222448563862294, 'duel_success_rate': 11.11111111111111, 'touches_per_90': 69.54573232837645, 'average_position_x': 71.38137082601064, 'average_position_y': 55.52688927943755}
# {'player_id': 27328, 'name': 'Alexander Farnerud', 'minutes': 364.85, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 17.020693435658487, 'pass_accuracy': 76.81159420289855, 'progressive_passes_per_90': 3.70015074688228, 'progressive_pass_accuracy': 60.0, 'long_passes_per_90': 3.4534740304234615, 'long_pass_accuracy': 50.0, 'crosses_per_90': 0.9867068658352747, 'cross_accuracy': 25.0, 'key_passes_per_90': 0.740030149376456, 'assists_per_90': 0.0, 'passes_received_per_90': 16.033986569823213, 'shots_per_90': 0.49335343291763734, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.006375229244895162, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.49335343291763734, 'successful_dribbles_per_90': 0.24667671645881867, 'dribble_success_rate': 50.0, 'progressive_runs_per_90': 1.9734137316705493, 'fouls_won_per_90': 0.24667671645881867, 'pressures_per_90': 3.9468274633410987, 'blocks_per_90': 0.24667671645881867, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.24667671645881867, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.480060298752912, 'fouls_made_per_90': 0.49335343291763734, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.9867068658352747, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 50.56872687405782, 'average_position_x': 66.68048780487803, 'average_position_y': 29.090731707317083}
# {'player_id': 386606, 'name': 'Luigi Giorgi', 'minutes': 66.98, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 24.186324275903253, 'pass_accuracy': 94.44444444444444, 'progressive_passes_per_90': 1.3436846819946253, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 1.3436846819946253, 'long_pass_accuracy': 100.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 1.3436846819946253, 'assists_per_90': 0.0, 'passes_received_per_90': 24.186324275903253, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 1.3436846819946253, 'fouls_won_per_90': 1.3436846819946253, 'pressures_per_90': 4.0310540459838755, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 4.0310540459838755, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.3436846819946253, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 76.59002687369365, 'average_position_x': 65.55087719298247, 'average_position_y': 21.947368421052623}
# {'player_id': 28066, 'name': 'Marcelo Alejandro Estigarribia Balmori', 'minutes': 241.95, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 6.3236205827650345, 'pass_accuracy': 58.82352941176471, 'progressive_passes_per_90': 0.7439553626782394, 'progressive_pass_accuracy': 50.0, 'long_passes_per_90': 0.3719776813391197, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.3719776813391197, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 8.555486670799754, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.3719776813391197, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.7439553626782394, 'fouls_won_per_90': 1.4879107253564787, 'pressures_per_90': 2.2318660880347183, 'blocks_per_90': 0.7439553626782394, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.3719776813391197, 'clearances_per_90': 0.3719776813391197, 'ball_recoveries_per_90': 1.8598884066955985, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.3719776813391197, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 29.014259144451337, 'average_position_x': 67.35000000000001, 'average_position_y': 32.44615384615384}
# {'player_id': 22822, 'name': 'Alejandro Miguel Rodriguez', 'minutes': 365.1, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 0.7395234182415776, 'pass_accuracy': 33.33333333333333, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 4.437140509449466, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 2.711585866885785, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.4930156121610518, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 7.641741988496302, 'average_position_x': 93.96451612903226, 'average_position_y': 44.19354838709676}
# {'player_id': 8717, 'name': 'Dominik Furman', 'minutes': 74.98, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 20.405441451053612, 'pass_accuracy': 88.23529411764706, 'progressive_passes_per_90': 3.600960256068285, 'progressive_pass_accuracy': 33.33333333333333, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 21.60576153640971, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 12.00320085356095, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 2.40064017071219, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 60.016004267804746, 'average_position_x': 60.382, 'average_position_y': 43.12}
# {'player_id': 41063, 'name': 'Aaron Mattia Tabacchi', 'minutes': 58.67, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 13.806033748082493, 'pass_accuracy': 66.66666666666666, 'progressive_passes_per_90': 3.0680074995738873, 'progressive_pass_accuracy': 50.0, 'long_passes_per_90': 1.5340037497869436, 'long_pass_accuracy': 100.0, 'crosses_per_90': 4.602011249360832, 'cross_accuracy': 0.0, 'key_passes_per_90': 1.5340037497869436, 'assists_per_90': 0.0, 'passes_received_per_90': 12.27202999829555, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 4.602011249360832, 'fouls_won_per_90': 0.0, 'pressures_per_90': 6.136014999147775, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.0680074995738873, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 41.41810124424748, 'average_position_x': 83.63703703703702, 'average_position_y': 11.14814814814815}
# {'player_id': 44395, 'name': 'Andrés Fabián Ponce Núñez', 'minutes': 49.98, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 5.402160864345738, 'pass_accuracy': 66.66666666666666, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 9.00360144057623, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 3.601440576230492, 'blocks_per_90': 1.800720288115246, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 1.800720288115246, 'ball_recoveries_per_90': 1.800720288115246, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 5.402160864345738, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 27.010804321728692, 'average_position_x': 73.37333333333335, 'average_position_y': 51.966666666666676}
# {'player_id': 18237, 'name': 'Ionuț Andrei Radu', 'minutes': 67.18, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 8.03810657933909, 'pass_accuracy': 50.0, 'progressive_passes_per_90': 4.019053289669545, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 4.019053289669545, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 5.358737719559392, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 18.755582018457872, 'average_position_x': 8.128571428571428, 'average_position_y': 39.73571428571428}
# {'player_id': 42271, 'name': 'Fabio Della Giovanna', 'minutes': 57.92, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 7.769337016574585, 'pass_accuracy': 60.0, 'progressive_passes_per_90': 4.661602209944752, 'progressive_pass_accuracy': 66.66666666666666, 'long_passes_per_90': 1.5538674033149171, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 6.2154696132596685, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 1.5538674033149171, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 1.5538674033149171, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 20.200276243093924, 'average_position_x': 50.66923076923077, 'average_position_y': 21.646153846153844}
# {'player_id': 31383, 'name': 'Nikola Ninković', 'minutes': 53.05, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 8.482563619227145, 'pass_accuracy': 60.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 1.696512723845429, 'long_pass_accuracy': 0.0, 'crosses_per_90': 1.696512723845429, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 10.179076343072573, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.696512723845429, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 8.482563619227145, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 3.393025447690858, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 33.93025447690858, 'average_position_x': 73.43, 'average_position_y': 31.759999999999998}
# {'player_id': 11519, 'name': 'Antonino La Gumina', 'minutes': 229.6, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 5.487804878048781, 'pass_accuracy': 78.57142857142857, 'progressive_passes_per_90': 0.39198606271777003, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 14.895470383275262, 'shots_per_90': 1.17595818815331, 'shots_on_target_per_90': 0.39198606271777003, 'shot_accuracy': 0.333, 'goals_per_90': 0.0, 'xg_per_90': 0.05762589459930313, 'first_time_shots_per_90': 0.39198606271777003, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.39198606271777003, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.39198606271777003, 'fouls_won_per_90': 0.0, 'pressures_per_90': 4.70383275261324, 'blocks_per_90': 0.39198606271777003, 'interceptions_per_90': 1.17595818815331, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.39198606271777003, 'fouls_made_per_90': 0.39198606271777003, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 2.35191637630662, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 35.670731707317074, 'average_position_x': 81.76263736263732, 'average_position_y': 51.22637362637361}
# {'player_id': 3287, 'name': 'Nathaniel Chalobah', 'minutes': 284.7, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 13.909378292939937, 'pass_accuracy': 90.9090909090909, 'progressive_passes_per_90': 1.5806111696522656, 'progressive_pass_accuracy': 80.0, 'long_passes_per_90': 0.31612223393045313, 'long_pass_accuracy': 100.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.6322444678609063, 'assists_per_90': 0.0, 'passes_received_per_90': 16.12223393045311, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.6322444678609063, 'fouls_won_per_90': 0.31612223393045313, 'pressures_per_90': 4.109589041095891, 'blocks_per_90': 0.6322444678609063, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.5806111696522656, 'fouls_made_per_90': 0.6322444678609063, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.9483667017913594, 'duels_won_per_90': 0.31612223393045313, 'duel_success_rate': 33.33333333333333, 'touches_per_90': 46.15384615384616, 'average_position_x': 67.91643835616439, 'average_position_y': 24.85479452054795}
# {'player_id': 7701, 'name': 'Franco Zuculini', 'minutes': 71.5, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 20.13986013986014, 'pass_accuracy': 87.5, 'progressive_passes_per_90': 6.293706293706294, 'progressive_pass_accuracy': 80.0, 'long_passes_per_90': 1.2587412587412588, 'long_pass_accuracy': 0.0, 'crosses_per_90': 1.2587412587412588, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 18.881118881118883, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 2.5174825174825175, 'pressures_per_90': 6.293706293706294, 'blocks_per_90': 3.7762237762237763, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 6.293706293706294, 'fouls_made_per_90': 1.2587412587412588, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 2.5174825174825175, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 76.78321678321679, 'average_position_x': 74.77213114754099, 'average_position_y': 50.92459016393443}
# {'player_id': 13428, 'name': 'Andrea Favilli', 'minutes': 51.7, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 0.0, 'pass_accuracy': 0.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 0.0, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 0, 'average_position_x': None, 'average_position_y': None}
# {'player_id': 390310, 'name': 'Lorenzo Di Livio', 'minutes': 73.0, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 9.863013698630137, 'pass_accuracy': 100.0, 'progressive_passes_per_90': 1.2328767123287672, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 13.561643835616438, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 8.63013698630137, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 2.4657534246575343, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 1.2328767123287672, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 30.82191780821918, 'average_position_x': 69.53999999999998, 'average_position_y': 61.744000000000014}
# {'player_id': 8424, 'name': 'Marco Tumminello', 'minutes': 51.42, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 0.0, 'pass_accuracy': 0.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 5.250875145857643, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 3.5005834305717616, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 1.7502917152858808, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 7.001166861143523, 'average_position_x': 51.300000000000004, 'average_position_y': 56.400000000000006}
# {'player_id': 8792, 'name': 'Mattia Zaccagni', 'minutes': 208.15, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 8.215229401873648, 'pass_accuracy': 63.1578947368421, 'progressive_passes_per_90': 2.594282969012731, 'progressive_pass_accuracy': 16.666666666666664, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 15.133317319240932, 'shots_per_90': 0.8647609896709103, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.037205933845784286, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 1.2971414845063656, 'fouls_won_per_90': 0.8647609896709104, 'pressures_per_90': 8.215229401873648, 'blocks_per_90': 0.8647609896709104, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.8647609896709104, 'fouls_made_per_90': 0.4323804948354552, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 2.161902474177276, 'duels_won_per_90': 0.4323804948354552, 'duel_success_rate': 20.0, 'touches_per_90': 38.049483545520054, 'average_position_x': 73.86704545454545, 'average_position_y': 43.55568181818182}
# {'player_id': 387428, 'name': 'Amauri Carvalho de Oliveira', 'minutes': 67.57, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 5.32780819890484, 'pass_accuracy': 75.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 1.33195204972621, 'assists_per_90': 0.0, 'passes_received_per_90': 17.315376646440733, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 2.66390409945242, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 1.33195204972621, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 2.66390409945242, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 25.307088944797993, 'average_position_x': 83.05263157894738, 'average_position_y': 35.48421052631579}
# {'player_id': 31265, 'name': 'Michele Rocca', 'minutes': 81.42, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 16.58069270449521, 'pass_accuracy': 46.666666666666664, 'progressive_passes_per_90': 8.843036109064112, 'progressive_pass_accuracy': 37.5, 'long_passes_per_90': 2.210759027266028, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 12.159174649963154, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 4.421518054532056, 'fouls_won_per_90': 0.0, 'pressures_per_90': 5.52689756816507, 'blocks_per_90': 2.210759027266028, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 2.210759027266028, 'ball_recoveries_per_90': 4.421518054532056, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 2.210759027266028, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 55.268975681650694, 'average_position_x': 62.43199999999999, 'average_position_y': 64.83599999999998}
# {'player_id': 40453, 'name': 'Segundo Víctor Ibarbo Guerrero', 'minutes': 111.65, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 2.418271383788625, 'pass_accuracy': 33.33333333333333, 'progressive_passes_per_90': 0.806090461262875, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 4.030452306314375, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.806090461262875, 'pressures_per_90': 0.806090461262875, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.806090461262875, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 12.091356918943125, 'average_position_x': 61.49333333333334, 'average_position_y': 60.89333333333333}
# {'player_id': 41948, 'name': 'Franco Signorelli', 'minutes': 84.8, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 15.919811320754718, 'pass_accuracy': 86.66666666666667, 'progressive_passes_per_90': 6.367924528301887, 'progressive_pass_accuracy': 83.33333333333334, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 18.04245283018868, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.0613207547169812, 'successful_dribbles_per_90': 1.0613207547169812, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 1.0613207547169812, 'pressures_per_90': 8.49056603773585, 'blocks_per_90': 1.0613207547169812, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 1.0613207547169812, 'ball_recoveries_per_90': 1.0613207547169812, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 2.1226415094339623, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 52.00471698113208, 'average_position_x': 70.34081632653061, 'average_position_y': 20.824489795918367}
# {'player_id': 3486, 'name': 'Fernando Llorente Torres', 'minutes': 68.68, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 5.2417006406523, 'pass_accuracy': 25.0, 'progressive_passes_per_90': 1.310425160163075, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 11.793826441467676, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 6.552125800815375, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 30.139778683750727, 'average_position_x': 95.50434782608697, 'average_position_y': 49.41304347826087}
# {'player_id': 18874, 'name': 'Mauricio Aníbal Isla Isla', 'minutes': 66.72, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 17.535971223021583, 'pass_accuracy': 84.61538461538461, 'progressive_passes_per_90': 4.046762589928058, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 1.3489208633093526, 'cross_accuracy': 100.0, 'key_passes_per_90': 1.3489208633093526, 'assists_per_90': 0.0, 'passes_received_per_90': 13.489208633093526, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 2.697841726618705, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 4.046762589928058, 'blocks_per_90': 1.3489208633093526, 'interceptions_per_90': 1.3489208633093526, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 2.697841726618705, 'ball_recoveries_per_90': 2.697841726618705, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.3489208633093526, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 60.701438848920866, 'average_position_x': 79.62444444444442, 'average_position_y': 68.3977777777778}
# {'player_id': 31335, 'name': 'Giuseppe Panico', 'minutes': 58.52, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 0.0, 'pass_accuracy': 0.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 1.5379357484620642, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 1.5379357484620642, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.5379357484620642, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 6.151742993848257, 'average_position_x': 50.95, 'average_position_y': 6.700000000000001}

# %%
import pandas as pd

df_players = pd.DataFrame(player_data)
print(df_players.head())  # To see the first few rows
# Out:
#    player_id                 name  minutes       most_played_position  \
# 0       3577          Molla Wagué  2736.15          Right Center Back
# 1       6577   Zdravko Kuzmanović  1769.95  Center Defensive Midfield
# 2     386607    Gianpaolo Bellini  1397.02                 Right Back
# 3       8184  Marco D''Alessandro  2122.37                 Right Wing
# 4       6994       Marten de Roon  4719.88  Center Defensive Midfield
#
#       position  passes_per_90  pass_accuracy  progressive_passes_per_90  \
# 0  center back      20.623869      80.223285                   5.657585
# 1   midfielder      29.390661      82.179931                   8.644312
# 2    full back      32.597959      80.830040                  10.951883
# 3       winger      15.817223      69.436997                   2.968380
# 4   midfielder      31.824962      77.291791                  10.239667
#
#    progressive_pass_accuracy  long_passes_per_90  ...  smothers_per_90  \
# 0                  57.558140            2.302505  ...              NaN
# 1                  65.294118            3.813667  ...              NaN
# 2                  70.588235            3.414411  ...              NaN
# 3                  55.714286            1.781028  ...              NaN
# 4                  56.610801            4.061544  ...              NaN
#
#    collections_per_90  punches_per_90  sweeper_claims_per_90  \
# 0                 NaN             NaN                    NaN
# 1                 NaN             NaN                    NaN
# 2                 NaN             NaN                    NaN
# 3                 NaN             NaN                    NaN
# 4                 NaN             NaN                    NaN
#
#    sweeper_clears_per_90  save_percentage  smother_success_rate  \
# 0                    NaN              NaN                   NaN
# 1                    NaN              NaN                   NaN
# 2                    NaN              NaN                   NaN
# 3                    NaN              NaN                   NaN
# 4                    NaN              NaN                   NaN
#
#    collection_success_rate  punch_success_rate  sweeper_success_rate
# 0                      NaN                 NaN                   NaN
# 1                      NaN                 NaN                   NaN
# 2                      NaN                 NaN                   NaN
# 3                      NaN                 NaN                   NaN
# 4                      NaN                 NaN                   NaN
#
# [5 rows x 57 columns]

# %%
cols_to_fill = [
    'shots_faced_per_90',
    'saves_per_90',
    'goals_conceded_per_90',
    'smothers_per_90',
    'collections_per_90',
    'punches_per_90',
    'sweeper_claims_per_90',
    'sweeper_clears_per_90',
    'save_percentage',
    'smother_success_rate',
    'collection_success_rate',
    'punch_success_rate',
    'sweeper_success_rate'  # fixed missing quote here
]

df_players[cols_to_fill] = df_players[cols_to_fill].fillna(0.0)

# %%
print(df_players.columns)
print(df_players['name'].head(20))  # or try another likely column name, e.g. 'player_name'
keylor_row = df_players[df_players['name'].str.contains('José Antonio García Rabasco', case=False, na=False)]
print(keylor_row.to_dict(orient='records'))
# Out:
# Index(['player_id', 'name', 'minutes', 'most_played_position', 'position',
#        'passes_per_90', 'pass_accuracy', 'progressive_passes_per_90',
#        'progressive_pass_accuracy', 'long_passes_per_90', 'long_pass_accuracy',
#        'crosses_per_90', 'cross_accuracy', 'key_passes_per_90',
#        'assists_per_90', 'passes_received_per_90', 'shots_per_90',
#        'shots_on_target_per_90', 'shot_accuracy', 'goals_per_90', 'xg_per_90',
#        'first_time_shots_per_90', 'headers_per_90', 'shots_outside_box_per_90',
#        'dribbles_per_90', 'successful_dribbles_per_90', 'dribble_success_rate',
#        'progressive_runs_per_90', 'fouls_won_per_90', 'pressures_per_90',
#        'blocks_per_90', 'interceptions_per_90', 'dribbled_past_per_90',
#        'clearances_per_90', 'ball_recoveries_per_90', 'fouls_made_per_90',
#        'yellow_cards_per_90', 'red_cards_per_90', 'duels_per_90',
#        'duels_won_per_90', 'duel_success_rate', 'touches_per_90',
#        'average_position_x', 'average_position_y', 'shots_faced_per_90',
#        'saves_per_90', 'goals_conceded_per_90', 'smothers_per_90',
#        'collections_per_90', 'punches_per_90', 'sweeper_claims_per_90',
#        'sweeper_clears_per_90', 'save_percentage', 'smother_success_rate',
#        'collection_success_rate', 'punch_success_rate',
#        'sweeper_success_rate'],
#       dtype='object')
# 0                     Molla Wagué
# 1              Zdravko Kuzmanović
# 2               Gianpaolo Bellini
# 3             Marco D''Alessandro
# 4                  Marten de Roon
# 5                Marco Sportiello
# 6                 Andrea Masiello
# 7                  Berat Djimsiti
# 8                   Davide Brivio
# 9                   Luca Cigarini
# 10            Alessandro Diamanti
# 11                  Jasmin Kurtič
# 12                Marco Borriello
# 13               Orestis Karnezis
# 14              Danilo Larangeira
# 15               Maurizio Domizzi
# 16                  Silvan Widmer
# 17    Ali Adnan Kadhim Al Tameemi
# 18         Emmanuel Agyemang-Badu
# 19              Emil Hallfreðsson
# Name: name, dtype: object
# []

# %%
for col in df_players.columns:
    nan_count = df_players[col].isna().sum()
    if nan_count > 0:
        print(f"Column '{col}' has {nan_count} NaN(s).")
        players_with_nan = df_players[df_players[col].isna()]
        print("Players with NaN in this column:")
        for idx, row in players_with_nan.iterrows():
            pid = row.get('player_id', 'Unknown')
            name = row.get('name', 'Unknown')
            print(f" - Player ID: {pid}, Name: {name}")
        print()
# Out:
# Column 'average_position_x' has 1 NaN(s).
# Players with NaN in this column:
#  - Player ID: 13428, Name: Andrea Favilli
#
# Column 'average_position_y' has 1 NaN(s).
# Players with NaN in this column:
#  - Player ID: 13428, Name: Andrea Favilli

# %%
# Drop all rows with any NaNs
df_players_clean = df_players.dropna()

print(f"Removed {len(df_players) - len(df_players_clean)} players with NaN values.")
# Out:
# Removed 1 players with NaN values.

# %%
df_players_clean.to_csv('cleaned_player_data(serieA).csv', index=False)
