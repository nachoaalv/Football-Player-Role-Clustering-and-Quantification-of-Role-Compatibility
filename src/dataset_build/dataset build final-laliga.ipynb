# %% [markdown]
# Start data analysis with La Liga 2015/16 season

# %%
import json
import pandas as pd

# Define your path (with UTF-8 encoding)
file_path = r'C:\Users\nacho\open-data\data\matches\11\27.json'

# Load La Liga 2015/16 matches
with open(file_path, 'r', encoding='utf-8') as f:
    matches = json.load(f)

# Extract match IDs
match_ids = [match['match_id'] for match in matches]

print(f"Found {len(match_ids)} La Liga 2015/16 matches.")
# Out:
# Found 380 La Liga 2015/16 matches.

# %%
'''
Checks every game for each team is in the dataset
'''
home_teams = [match['home_team']['home_team_name'] for match in matches]
away_teams = [match['away_team']['away_team_name'] for match in matches]

all_teams = home_teams + away_teams

games_per_team = pd.Series(all_teams).value_counts()

print(games_per_team)
# Out:
# Levante UD                38
# Las Palmas                38
# RC Deportivo La Coruña    38
# Málaga                    38
# Espanyol                  38
# Sporting Gijón            38
# Rayo Vallecano            38
# Real Betis                38
# Athletic Club             38
# Atlético Madrid           38
# Valencia                  38
# Eibar                     38
# Getafe                    38
# Villarreal                38
# Sevilla                   38
# Granada                   38
# Real Sociedad             38
# Celta Vigo                38
# Real Madrid               38
# Barcelona                 38
# Name: count, dtype: int64

# %%
import os
from tqdm import tqdm 

'''
to extract all match events from each match
'''

# Base folder where event files are stored
events_folder = r'C:\Users\nacho\open-data\data\events'

# List to hold all events
all_events = {}

for match_id in tqdm(match_ids):
    event_file = os.path.join(events_folder, f"{match_id}.json")
    with open(event_file, 'r', encoding='utf-8') as f:
        match_events = json.load(f)
        all_events[match_id] = match_events  # Store events under the match_id key

print(f"Loaded events for {len(all_events)} matches.")
total_events = sum(len(ev) for ev in all_events.values())
print(f"Loaded a total of {total_events} events from {len(all_events)} matches.")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 380/380 [00:19<00:00, 19.17it/s]
# Loaded events for 380 matches.
# Loaded a total of 1295354 events from 380 matches.

# %% [markdown]
# Extracting the line up of one game to check accuracy and make sure it works

# %%
first_match = matches[12]
match_id = first_match['match_id']

print(f"Match ID: {match_id}")
print(f"Home team: {first_match['home_team']['home_team_name']}")
print(f"Away team: {first_match['away_team']['away_team_name']}")
print(f"Date: {first_match['match_date']}")
# Out:
# Match ID: 3825849
# Home team: Valencia
# Away team: Real Sociedad
# Date: 2016-05-13

# %%
events_for_match = all_events[match_id]

# Find the Starting XI event(s)
starting_xi_events = [e for e in events_for_match if e['type']['id'] == 35]

for event in starting_xi_events:
    print(f"Team: {event['team']['name']}, Formation: {event['tactics']['formation']}")
    lineup = event['tactics']['lineup']
    for player_info in lineup:
        player_name = player_info['player']['name']
        position_name = player_info['position']['name']
        jersey_number = player_info.get('jersey_number', 'N/A')
        print(f"  #{jersey_number} {player_name} - {position_name}")
    print()
# Out:
# Team: Valencia, Formation: 433
#   #13 Jaume Doménech Sánchez - Goalkeeper
#   #19 Antonio Barragán Fernández - Right Back
#   #4 Aderllan Leandro de Jesus Santos - Right Center Back
#   #3 Rúben Miguel Nunes Vezo - Left Center Back
#   #6 Guilherme Magdalena Siqueira - Left Back
#   #12 Danilo Barbosa da Silva - Center Defensive Midfield
#   #10 Daniel Parejo Muñoz - Right Center Midfield
#   #21 André Filipe Tavares Gomes - Left Center Midfield
#   #22 Santiago Mina Lorenzo - Right Wing
#   #11 Pablo Daniel Piatti - Left Wing
#   #9 Francisco Alcácer García - Center Forward
#
# Team: Real Sociedad, Formation: 4231
#   #1 Gerónimo Rulli - Goalkeeper
#   #30 Aritz Elustondo Irribaria - Right Back
#   #3 Mikel González de Martín Martínez - Right Center Back
#   #23 Diego Antonio Reyes Rosales - Left Center Back
#   #24 Alberto De La Bella Madureño - Left Back
#   #4 Asier Illarramendi Andonegi - Right Defensive Midfield
#   #14 Rubén Pardo Gutiérrez - Left Defensive Midfield
#   #10 Xabier Prieto Argarate - Right Wing
#   #28 Mikel Oyarzabal Ugarte - Center Attacking Midfield
#   #17 David Zurutuza Veillet - Left Wing
#   #35 Jon Bautista Orgilles - Center Forward

# %% [markdown]
# need to narrow down to what postions i should go,
#
# examples: treat right back and left back as one?
# treat left back and left wing back as one?
# treat defensive midfield, center midfield and attacking midfield as one?
#
# Inititally only these positions:
#
# fullback (LB, RB, LWB, RWB)
#
# centreback
#
# Midfield (CDM CM CAM)
#
# RM LM?
#
# Wingers (LW RW)
#
# Striker (ST CF

# %%
unique_positions = set()

for match_id, events in all_events.items():
    for event in events:
        if event['type']['name'] == 'Starting XI':
            lineup = event['tactics']['lineup']
            for player in lineup:
                position_name = player['position']['name']
                unique_positions.add(position_name)

print(f"Unique positions in the season: {len(unique_positions)}")
print("Position names:", unique_positions)
# Out:
# Unique positions in the season: 22
# Position names: {'Center Back', 'Right Wing', 'Left Center Forward', 'Right Wing Back', 'Center Attacking Midfield', 'Right Defensive Midfield', 'Right Center Back', 'Center Midfield', 'Left Wing Back', 'Left Back', 'Right Center Forward', 'Left Center Midfield', 'Right Midfield', 'Goalkeeper', 'Right Back', 'Left Wing', 'Left Midfield', 'Center Defensive Midfield', 'Left Center Back', 'Right Center Midfield', 'Left Defensive Midfield', 'Center Forward'}

# %%
'''GET MINUTES PLAYED BY EACH PLAYER'''


from collections import defaultdict

player_seconds = defaultdict(float)
player_id_to_name = {}

for match_id, events in all_events.items():
    players_on_pitch = {}  # player_id -> start_time_in_seconds
    off_periods = defaultdict(list)  # player_id -> list of {'off': time, 'on': time}
    added_time_players = defaultdict(int)
    
    for event in events:
        event_time = event['minute'] * 60 + event['second']
        
        if event['type']['id'] == 35:
            for player in event['tactics']['lineup']:
                pid = player['player']['id']
                name = player['player']['name']
                players_on_pitch[pid] = 0
                player_id_to_name[pid] = name
        
        elif event['type']['id'] == 34:
            added_time = event_time - 2700  # 45 mins in secs
            if added_time > 0:
                for pid in players_on_pitch:
                    added_time_players[pid] = added_time
        
        elif event['type']['id'] == 19:
            player_out = event['player']['id']
            player_in = event['substitution']['replacement']['id']
            time_sub = event_time
            
            if player_out in players_on_pitch:
                start_time = players_on_pitch[player_out]
                added = added_time_players.get(player_out, 0)
                player_seconds[player_out] += time_sub - start_time + added
                del players_on_pitch[player_out]
            
            players_on_pitch[player_in] = time_sub
            name = event['substitution']['replacement']['name']
            player_id_to_name[player_in] = name
        
        elif event['type']['id'] == 27:
            pid = event['player']['id']
            off_periods[pid].append({'off': event_time})
        
        elif event['type']['id'] == 26:
            pid = event['player']['id']
            if off_periods[pid] and 'off' in off_periods[pid][-1] and 'on' not in off_periods[pid][-1]:
                off_periods[pid][-1]['on'] = event_time

    # End of match: finalize playing time for players still on pitch
    if events:
        last_event = events[-1]
        match_end_time = last_event['minute'] * 60 + last_event['second']
        for pid, start_time in players_on_pitch.items():
            play_time = match_end_time - start_time + added_time_players.get(pid, 0)
            
            for period in off_periods.get(pid, []):
                if 'on' in period and 'off' in period:
                    play_time -= (period['on'] - period['off'])
                elif 'off' in period:
                    play_time -= (match_end_time - period['off'])
            
            player_seconds[pid] += play_time
'''
# Print results
for pid, seconds in player_seconds.items():
    name = player_id_to_name.get(pid, "Unknown")
    minutes = round(seconds / 60, 2)
    print(pid, name, minutes)
print(len(player_seconds))
'''
# Out:
# '\n# Print results\nfor pid, seconds in player_seconds.items():\n    name = player_id_to_name.get(pid, "Unknown")\n    minutes = round(seconds / 60, 2)\n    print(pid, name, minutes)\nprint(len(player_seconds))\n'

# %%
player_data = []

for pid, seconds in player_seconds.items():
    name = player_id_to_name.get(pid, "Unknown")
    minutes = round(seconds / 60, 2)
    player_data.append({
        'player_id': pid,
        'name': name,
        'minutes': minutes
    })

# %%
'''ADD THEIR MAIN POSITION'''

from collections import defaultdict, Counter

player_position_counts = defaultdict(Counter)


for match_id, events in all_events.items():
    for event in events:
        if event['type']['id'] == 35:  # Lineup
            for player in event['tactics']['lineup']:
                pid = player['player']['id']
                pos = player.get('position', {}).get('name')
                if pos:
                    player_position_counts[pid][pos] += 1

        elif event['type']['id'] == 19:  # Sub
            replacement = event['substitution']['replacement']
            pid = replacement['id']
            pos = replacement.get('position', {}).get('name')
            if pos:
                player_position_counts[pid][pos] += 1

for player in player_data:
    pid = player['player_id']
    position_counter = player_position_counts.get(pid, {})
    most_played = position_counter.most_common(1)[0][0] if position_counter else "Unknown"
    player['most_played_position'] = most_played

# %%
# Mapping function
def map_general_position(pos):
    pos = pos.lower()
    
    if pos == "goalkeeper":
        return "goalkeeper"
    
    elif pos in ["right back", "left back", "right wing back", "left wing back"]:
        return "full back"
    
    elif pos in ["center back", "right center back", "left center back"]:
        return "center back"
    
    elif "midfield" in pos:
        return "midfielder"
    
    elif pos in ["right wing", "left wing"]:
        return "winger"
    
    elif pos in ["striker", "center forward", "secondary striker", "right center forward", "left center forward"]:
        return "striker"
    
    return "other"  # fallback for unexpected cases

# %%
for player in player_data:
    specific_pos = player.get('most_played_position', 'Unknown')
    player['position'] = map_general_position(specific_pos)

# %%
other_count = sum(1 for player in player_data if player.get('position') == 'other')
print(f"Number of players with position 'other': {other_count}")
# Out:
# Number of players with position 'other': 32

# %% [raw]
# PASSING DATA

# %%
from collections import defaultdict

# Initialize stats containers per player
pass_stats = defaultdict(lambda: {
    'total_passes': 0,
    'completed_passes': 0,
    'progressive_passes': 0,
    'completed_progressive_passes': 0,
    'long_passes': 0,
    'completed_long_passes': 0,
    'crosses': 0,
    'completed_crosses': 0,
    'key_passes': 0,
    'assists': 0,
    'passes_received' : 0
})

def is_progressive_pass(start_x, end_x, pitch_length=100):
    # Determine progressive pass by x-coordinate movement closer to opponent goal
    if start_x < pitch_length / 2 and end_x < pitch_length / 2:
        return (end_x - start_x) >= 30
    elif (start_x < pitch_length / 2 and end_x >= pitch_length / 2) or (start_x >= pitch_length / 2 and end_x < pitch_length / 2):
        return (end_x - start_x) >= 15
    else:  # both in opponent half
        return (end_x - start_x) >= 10

def is_long_pass(length_yards, height_id):
    # Ground pass longer than 45m (~49.2 yards)
    # High pass longer than 25m (~27.3 yards)
    if height_id == 1:  # Ground Pass
        return length_yards >= 49.2
    elif height_id == 3:  # High Pass
        return length_yards >= 27.3
    return False

# Collect pass data
for match_id, events in all_events.items():
    for event in events:
        if event['type']['id'] == 30:  # Pass event
            pid = event['player']['id']
            # Completed pass if no outcome or outcome id is None
            completed = event.get('pass', {}).get('outcome', {}).get('id') is None
            length = event.get('pass', {}).get('length', 0)  # in yards
            height_id = event.get('pass', {}).get('height', {}).get('id', 1)  # default to ground pass if missing

            start_x = event.get('location', [0, 0])[0]
            end_x = event.get('pass', {}).get('end_location', [0, 0])[0]

            cross = event.get('pass', {}).get('cross', False)

            # Update total and completed passes
            pass_stats[pid]['total_passes'] += 1
            if completed:
                pass_stats[pid]['completed_passes'] += 1

            # Progressive passes
            if is_progressive_pass(start_x, end_x):
                pass_stats[pid]['progressive_passes'] += 1
                if completed:
                    pass_stats[pid]['completed_progressive_passes'] += 1

            # Long passes
            if is_long_pass(length, height_id):
                pass_stats[pid]['long_passes'] += 1
                if completed:
                    pass_stats[pid]['completed_long_passes'] += 1

            # Crosses
            if cross:
                pass_stats[pid]['crosses'] += 1
                if completed:
                    pass_stats[pid]['completed_crosses'] += 1

            # Key passes (assisted shot)
            if event.get('pass', {}).get('shot_assist', False):
                pass_stats[pid]['key_passes'] += 1

            # Assists (goal assists)
            if event.get('pass', {}).get('goal_assist', False):
                pass_stats[pid]['assists'] += 1
                
        elif event['type']['id'] == 42: #Ball receipt
            pid = event['player']['id']
            pass_stats[pid]['passes_received'] +=1

# %%
# Add passing stats per 90 minutes to player_data
for player in player_data:
    pid = player['player_id']
    minutes = player.get('minutes', 0)
    stats = pass_stats.get(pid, {})

    if minutes > 0:
        player['passes_per_90'] = stats.get('total_passes', 0) / (minutes / 90)
        player['pass_accuracy'] = (stats.get('completed_passes', 0) / max(stats.get('total_passes', 1), 1)) * 100

        player['progressive_passes_per_90'] = stats.get('progressive_passes', 0) / (minutes / 90)
        player['progressive_pass_accuracy'] = (stats.get('completed_progressive_passes', 0) / max(stats.get('progressive_passes', 1), 1)) * 100

        player['long_passes_per_90'] = stats.get('long_passes', 0) / (minutes / 90)
        player['long_pass_accuracy'] = (stats.get('completed_long_passes', 0) / max(stats.get('long_passes', 1), 1)) * 100

        player['crosses_per_90'] = stats.get('crosses', 0) / (minutes / 90)
        player['cross_accuracy'] = (stats.get('completed_crosses', 0) / max(stats.get('crosses', 1), 1)) * 100

        player['key_passes_per_90'] = stats.get('key_passes', 0) / (minutes / 90)
        player['assists_per_90'] = stats.get('assists', 0) / (minutes / 90)
        
        player['passes_received_per_90'] = stats.get('passes_received', 0) / (minutes/90)
    else:
        player['passes_per_90'] = 0
        player['pass_accuracy'] = 0
        player['progressive_passes_per_90'] = 0
        player['progressive_pass_accuracy'] = 0
        player['long_passes_per_90'] = 0
        player['long_pass_accuracy'] = 0
        player['crosses_per_90'] = 0
        player['cross_accuracy'] = 0
        player['key_passes_per_90'] = 0
        player['assists_per_90'] = 0
        player['passes_received_per_90'] = 0

# %% [raw]
# SHOT DATA

# %%
# Initialize data containers
player_shots = defaultdict(lambda: {
    'total_shots': 0,
    'shots_on_target': 0,
    'goals': 0,
    'xg': 0.0,
    'first_time_shots': 0,
    'headers': 0,
    'shots_outside_box': 0
})

# Pitch box boundaries (StatsBomb pitch is 120x80)
# The penalty box on the attacking side is approximately x >= 84 for shots inside the box
penalty_box_x = 84

for match_id, events in all_events.items():
    for event in events:
        if event['type']['id'] == 16:  # Shot event
            pid = event['player']['id']
            location = event.get('location', [0, 0])
            x, y = location
            
            # Count total shots
            player_shots[pid]['total_shots'] += 1
            
            # Check shot outcome
            outcome_id = event.get('shot', {}).get('outcome', {}).get('id')
            # On target if goal (97), saved (100), or saved to post (116)
            if outcome_id in [97, 100, 116]:
                player_shots[pid]['shots_on_target'] += 1
            
            # Count goals
            if outcome_id == 97:
                player_shots[pid]['goals'] += 1
            
            # Accumulate xG
            xg = event.get('shot', {}).get('statsbomb_xg', 0)
            player_shots[pid]['xg'] += xg
            
            # First time shots
            if event.get('shot', {}).get('first_time', False):
                player_shots[pid]['first_time_shots'] += 1
            
            # Headers
            body_part_id = event.get('shot', {}).get('body_part', {}).get('id')
            if body_part_id == 37:  # 37 corresponds to 'Head'
                player_shots[pid]['headers'] += 1
            
            # Shots from outside the box (x < penalty_box_x)
            if x < penalty_box_x:
                player_shots[pid]['shots_outside_box'] += 1

# %%
# Now calculate per 90 stats and accuracy and add to player_data
for player in player_data:
    pid = player['player_id']
    seconds_played = player.get('minutes', 0) * 60
    minutes_played = player.get('minutes', 0)
    if seconds_played == 0:
        # Avoid division by zero if no minutes played
        player.update({
            'shots_per_90': 0,
            'shots_on_target_per_90': 0,
            'shot_accuracy': 0,
            'goals_per_90': 0,
            'xg_per_90': 0,
            'first_time_shots_per_90': 0,
            'headers_per_90': 0,
            'shots_outside_box_per_90': 0
        })
        continue
    
    stats = player_shots.get(pid, {
        'total_shots': 0,
        'shots_on_target': 0,
        'goals': 0,
        'xg': 0.0,
        'first_time_shots': 0,
        'headers': 0,
        'shots_outside_box': 0
    })
    
    shots = stats['total_shots']
    shots_on_target = stats['shots_on_target']
    goals = stats['goals']
    xg = stats['xg']
    first_time = stats['first_time_shots']
    headers = stats['headers']
    shots_outside = stats['shots_outside_box']
    
    # Calculate accuracy (on target / total shots)
    accuracy = shots_on_target / shots if shots > 0 else 0
    
    player['shots_per_90'] = shots / minutes_played * 90
    player['shots_on_target_per_90'] = shots_on_target / minutes_played * 90
    player['shot_accuracy'] = round(accuracy, 3)
    player['goals_per_90'] = goals / minutes_played * 90
    player['xg_per_90'] = xg / minutes_played * 90
    player['first_time_shots_per_90'] = first_time / minutes_played * 90
    player['headers_per_90'] = headers / minutes_played * 90
    player['shots_outside_box_per_90'] = shots_outside / minutes_played * 90

# %%
print(player_data)
# Out:
# [{'player_id': 24149, 'name': 'José Antonio García Rabasco', 'minutes': 3369.15, 'most_played_position': 'Right Defensive Midfield', 'position': 'midfielder', 'passes_per_90': 36.3830639775611, 'pass_accuracy': 77.01908957415566, 'progressive_passes_per_90': 11.913984239348203, 'progressive_pass_accuracy': 60.0896860986547, 'long_passes_per_90': 7.319353546146654, 'long_pass_accuracy': 43.79562043795621, 'crosses_per_90': 0.9883798584212634, 'cross_accuracy': 24.324324324324326, 'key_passes_per_90': 1.095231735007346, 'assists_per_90': 0.0801389074395619, 'passes_received_per_90': 27.674636035795377, 'shots_per_90': 0.6678242286630159, 'shots_on_target_per_90': 0.18699078402564442, 'shot_accuracy': 0.28, 'goals_per_90': 0.053425938293041264, 'xg_per_90': 0.05210306754908508, 'first_time_shots_per_90': 0.21370375317216506, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.026712969146520632}, {'player_id': 26023, 'name': 'Juan Francisco García García', 'minutes': 2249.52, 'most_played_position': 'Left Center Back', 'position': 'center back', 'passes_per_90': 30.60652939293716, 'pass_accuracy': 64.70588235294117, 'progressive_passes_per_90': 15.363277499199828, 'progressive_pass_accuracy': 50.78125, 'long_passes_per_90': 10.002133788541554, 'long_pass_accuracy': 38.4, 'crosses_per_90': 1.0402219140083218, 'cross_accuracy': 23.076923076923077, 'key_passes_per_90': 0.16003414061666488, 'assists_per_90': 0.04000853515416622, 'passes_received_per_90': 18.32390910060813, 'shots_per_90': 0.12002560546249867, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.005781829324922651, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.040008535154166226, 'shots_outside_box_per_90': 0.0}, {'player_id': 6742, 'name': 'Sergio Gontán Gallardo', 'minutes': 3311.02, 'most_played_position': 'Right Wing', 'position': 'winger', 'passes_per_90': 25.007399532470355, 'pass_accuracy': 64.89130434782608, 'progressive_passes_per_90': 6.469305531226027, 'progressive_pass_accuracy': 50.42016806722689, 'long_passes_per_90': 3.071561029531685, 'long_pass_accuracy': 36.283185840707965, 'crosses_per_90': 2.8269234254096927, 'cross_accuracy': 32.69230769230769, 'key_passes_per_90': 1.03291432851508, 'assists_per_90': 0.0815458680406642, 'passes_received_per_90': 34.629811961268736, 'shots_per_90': 0.9785504164879706, 'shots_on_target_per_90': 0.3533654281762116, 'shot_accuracy': 0.361, 'goals_per_90': 0.0815458680406642, 'xg_per_90': 0.0773425093883456, 'first_time_shots_per_90': 0.27181956013554737, 'headers_per_90': 0.027181956013554737, 'shots_outside_box_per_90': 0.054363912027109475}, {'player_id': 6566, 'name': 'Borja González Tomás', 'minutes': 3721.57, 'most_played_position': 'Center Forward', 'position': 'striker', 'passes_per_90': 15.646622258885362, 'pass_accuracy': 69.39721792890263, 'progressive_passes_per_90': 2.684350959406917, 'progressive_pass_accuracy': 49.549549549549546, 'long_passes_per_90': 0.5804002074393334, 'long_pass_accuracy': 45.83333333333333, 'crosses_per_90': 0.33856678767294446, 'cross_accuracy': 21.428571428571427, 'key_passes_per_90': 0.38693347162622227, 'assists_per_90': 0.07255002592991668, 'passes_received_per_90': 33.15536184997192, 'shots_per_90': 2.273234145804056, 'shots_on_target_per_90': 1.0157003630188335, 'shot_accuracy': 0.447, 'goals_per_90': 0.4353001555795, 'xg_per_90': 0.408036205828454, 'first_time_shots_per_90': 0.9431503370889167, 'headers_per_90': 0.4353001555795, 'shots_outside_box_per_90': 0.0}, {'player_id': 5678, 'name': 'Jefferson Andrés Lerma Solís', 'minutes': 4122.73, 'most_played_position': 'Right Center Midfield', 'position': 'midfielder', 'passes_per_90': 26.436366194245082, 'pass_accuracy': 73.98843930635837, 'progressive_passes_per_90': 7.531417289029358, 'progressive_pass_accuracy': 52.7536231884058, 'long_passes_per_90': 3.689302961872352, 'long_pass_accuracy': 46.15384615384615, 'crosses_per_90': 0.8077172165045978, 'cross_accuracy': 24.324324324324326 ...

# %%
fields_to_check = [
    'minutes',
    'most_played_position',
    # Passing stats
    'passes_per_90',
    'pass_accuracy',
    'progressive_passes_per_90',
    'progressive_pass_accuracy',
    'long_passes_per_90',
    'long_pass_accuracy',
    'key_passes_per_90',
    'assists_per_90',
    'crosses_per_90',
    'cross_accuracy',
    # Shot stats
    'shots_per_90',
    'shots_on_target_per_90',
    'shot_accuracy',
    'goals_per_90',
    'xg_per_90',
    'first_time_shots_per_90',
    'headers_per_90',
    'shots_outside_box_per_90' 
]


missing_values = []

for player in player_data:
    for field in fields_to_check:
        if field not in player or player[field] is None:
            missing_values.append((player.get('player_id'), player.get('name'), field))

if missing_values:
    print(f"Missing values found for {len(missing_values)} fields:")
    for pid, name, field in missing_values:
        print(f"Player ID {pid} ({name}): Missing {field}")
else:
    print("No missing values found in checked fields.")
# Out:
# No missing values found in checked fields.

# %% [raw]
# Dribbling Data

# %%
# Dribble-related stats
dribble_stats = defaultdict(lambda: {
    'dribbles': 0,
    'successful_dribbles': 0,
    'progressive_runs': 0,
    'fouls_won': 0,
    'carry_distances' : []
})

def is_progressive_run(start_x, end_x, pitch_length=120):
    if start_x < pitch_length / 2 and end_x < pitch_length / 2:
        return (end_x - start_x) >= 30
    elif (start_x < pitch_length / 2 and end_x >= pitch_length / 2) or (start_x >= pitch_length / 2 and end_x < pitch_length / 2):
        return (end_x - start_x) >= 15
    else:
        return (end_x - start_x) >= 10

# Extract dribbling data
for match_id, events in all_events.items():
    for event in events:
        player = event.get('player')
        if not player:
            continue
        pid = player['id']
        etype = event['type']['id']

        if etype == 14:  # Dribble
            dribble_stats[pid]['dribbles'] += 1
            if event.get('dribble', {}).get('outcome', {}).get('id') == 8:
                dribble_stats[pid]['successful_dribbles'] += 1

        elif etype == 43:  # Carry
            start_x = event.get('location', [0, 0])[0]
            end_x = event.get('carry', {}).get('end_location', [0, 0])[0]
            if is_progressive_run(start_x, end_x):
                dribble_stats[pid]['progressive_runs'] += 1

        elif etype == 21:  # Foul Won
            dribble_stats[pid]['fouls_won'] += 1

# %%
for player in player_data:
    pid = player['player_id']
    minutes = player.get('minutes', 0)
    stats = dribble_stats.get(pid, {})

    if minutes > 0:
        factor = minutes / 90
        player['dribbles_per_90'] = stats.get('dribbles', 0) / factor
        player['successful_dribbles_per_90'] = stats.get('successful_dribbles', 0) / factor
        player['dribble_success_rate'] = (stats.get('successful_dribbles', 0) / max(stats.get('dribbles', 1), 1)) * 100
        player['progressive_runs_per_90'] = stats.get('progressive_runs', 0) / factor
        player['fouls_won_per_90'] = stats.get('fouls_won', 0) / factor
    else:
        player['dribbles_per_90'] = 0
        player['successful_dribbles_per_90'] = 0
        player['dribble_success_rate'] = 0
        player['progressive_runs_per_90'] = 0
        player['fouls_won_per_90'] = 0

# %% [raw]
# Defensive data

# %%
defensive_stats = defaultdict(lambda: {
    'pressures': 0,
    'blocks': 0,
    'interceptions': 0,
    'dribbled_past': 0,
    'clearances': 0,
    'ball_recoveries': 0,
    'fouls_made': 0,
    'yellow_cards': 0,
    'red_cards': 0,
    'duels': 0,
    'duels_won': 0
})

for match_id, events in all_events.items():
    for event in events:
        if 'player' not in event:
            continue

        pid = event['player']['id']
        etype = event['type']['id']

        if etype == 17:  # Pressure
            defensive_stats[pid]['pressures'] += 1
        elif etype == 2:  # Ball Recovery
            defensive_stats[pid]['ball_recoveries'] += 1
        elif etype == 4:  # Duel
            defensive_stats[pid]['duels'] += 1
            if event.get('duel', {}).get('outcome', {}).get('name') == 'Won':
                defensive_stats[pid]['duels_won'] += 1
        elif etype == 10:  # Interception
            defensive_stats[pid]['interceptions'] += 1
        elif etype == 22:  # Foul Committed (plus cards)
            defensive_stats[pid]['fouls_made'] += 1
            card = event.get('foul_committed', {}).get('card', {}).get('id')
            if card == 5:
                defensive_stats[pid]['yellow_cards'] += 1
            elif card == 6:
                defensive_stats[pid]['yellow_cards'] += 1
                defensive_stats[pid]['red_cards'] += 1
            elif card == 7:
                defensive_stats[pid]['red_cards'] += 1
        elif etype == 24:  # Bad Behaviour
            card = event.get('bad_behaviour', {}).get('card', {}).get('id')
            if card == 65:
                defensive_stats[pid]['yellow_cards'] += 1
            elif card == 66:
                defensive_stats[pid]['yellow_cards'] += 1
                defensive_stats[pid]['red_cards'] += 1
            elif card == 67:
                defensive_stats[pid]['red_cards'] += 1
        elif etype == 9:  # Clearance
            defensive_stats[pid]['clearances'] += 1
        elif etype == 6:  # Block
            defensive_stats[pid]['blocks'] += 1
        elif etype == 39:  # Dribbled Past
            defensive_stats[pid]['dribbled_past'] += 1

# %%
for player in player_data:
    pid = player['player_id']
    minutes = player.get('minutes', 0)
    stats = defensive_stats.get(pid, {})

    if minutes > 0:
        factor = minutes / 90
        player['pressures_per_90'] = stats.get('pressures', 0) / factor
        player['blocks_per_90'] = stats.get('blocks', 0) / factor
        player['interceptions_per_90'] = stats.get('interceptions', 0) / factor
        player['dribbled_past_per_90'] = stats.get('dribbled_past', 0) / factor
        player['clearances_per_90'] = stats.get('clearances', 0) / factor
        player['ball_recoveries_per_90'] = stats.get('ball_recoveries', 0) / factor
        player['fouls_made_per_90'] = stats.get('fouls_made', 0) / factor
        player['yellow_cards_per_90'] = stats.get('yellow_cards', 0) / factor
        player['red_cards_per_90'] = stats.get('red_cards', 0) / factor
        player['duels_per_90'] = stats.get('duels', 0) / factor
        player['duels_won_per_90'] = stats.get('duels_won', 0) / factor
        player['duel_success_rate'] = (stats.get('duels_won', 0) / max(stats.get('duels', 1), 1)) * 100
    else:
        player['pressures_per_90'] = 0
        player['blocks_per_90'] = 0
        player['interceptions_per_90'] = 0
        player['dribbled_past_per_90'] = 0
        player['clearances_per_90'] = 0
        player['ball_recoveries_per_90'] = 0
        player['fouls_made_per_90'] = 0
        player['yellow_cards_per_90'] = 0
        player['red_cards_per_90'] = 0
        player['duels_per_90'] = 0
        player['duels_won_per_90'] = 0
        player['duel_success_rate'] = 0

# %% [raw]
# Goalkeeper

# %%
import math

goalkeeping_stats = defaultdict(lambda: {
    'shots_faced': 0,
    'saves': 0,
    'close_range_saves': 0,
    'goals_conceded': 0,
    'smothers': 0,
    'collections': 0,
    'punches': 0,
    'sweeper_claims': 0,
    'sweeper_clears': 0,
    'successful_sweepers': 0,
    'successful_collections': 0,
    'successful_punches': 0,
    'successful_smothers': 0,
})

save_types = {29, 31, 33, 114, 110, 109}  # includes post saves, not 134 (off target)
goal_types = {26, 28}
shot_faced_types = save_types | goal_types | {32}  # include non-save faced shots
smother_type = 34
collection_types = {25, 49}  # includes "Collected" + "Collected Twice"
punch_types = {30, 117}
sweeper_type = 27

# Outcome categories
successful_outcomes = {15, 17, 47, 48, 49, 51, 53, 56, 59, 4, 16, 117}
fail_outcomes = {13, 14, 50, 52, 55, 58}

# Process events
for match_id, events in all_events.items():
    for event in events:
        if event['type']['id'] != 23:  # Not a goalkeeper event
            continue

        player = event.get('player')
        if not player:
            continue
        pid = player['id']
        gk_type = event['goalkeeper']['type']['id']
        outcome_id = event['goalkeeper'].get('outcome', {}).get('id')
        loc = event.get('location', [None, None])
        x = loc[0] if loc else None

        # Shots faced
        if gk_type in shot_faced_types:
            goalkeeping_stats[pid]['shots_faced'] += 1

        # Saves (including post saves, excluding off target saves)
        #if gk_type in save_types:
        #    goalkeeping_stats[pid]['saves'] += 1
          #  if x is not None and x <= 12:  # <12m assuming pitch 100 = 120m
           #     goalkeeping_stats[pid]['close_range_saves'] += 1
                
        # Goals conceded
        if gk_type in goal_types:
            goalkeeping_stats[pid]['goals_conceded'] += 1
            
        if gk_type in save_types:
            goalkeeping_stats[pid]['saves'] += 1

        # Smothers
        if gk_type == smother_type:
            goalkeeping_stats[pid]['smothers'] += 1
            if outcome_id in successful_outcomes:
                goalkeeping_stats[pid]['successful_smothers'] += 1

        # Collections
        if gk_type in collection_types:
            goalkeeping_stats[pid]['collections'] += 1
            if outcome_id in successful_outcomes:
                goalkeeping_stats[pid]['successful_collections'] += 1

        # Punches
        if gk_type in punch_types:
            goalkeeping_stats[pid]['punches'] += 1
            if outcome_id in successful_outcomes:
                goalkeeping_stats[pid]['successful_punches'] += 1

        # Sweeper actions
        if gk_type == sweeper_type:
            if outcome_id == 47:  # Claim
                goalkeeping_stats[pid]['sweeper_claims'] += 1
                if outcome_id in successful_outcomes:
                    goalkeeping_stats[pid]['successful_sweepers'] += 1
            elif outcome_id == 48:  # Clear
                goalkeeping_stats[pid]['sweeper_clears'] += 1
                if outcome_id in successful_outcomes:
                    goalkeeping_stats[pid]['successful_sweepers'] += 1

# %%
for player in player_data:
    pid = player['player_id']
    minutes = player.get('minutes', 0)

    if pid in goalkeeping_stats and minutes > 0:
        stats = goalkeeping_stats[pid]
        factor = minutes / 90

        player.update({

            # Per 90s
            'shots_faced_per_90': stats['shots_faced'] / factor,
            'saves_per_90': stats['saves'] / factor,
            'goals_conceded_per_90': stats['goals_conceded'] / factor,
            'smothers_per_90': stats['smothers'] / factor,
            'collections_per_90': stats['collections'] / factor,
            'punches_per_90': stats['punches'] / factor,
            'sweeper_claims_per_90': stats['sweeper_claims'] / factor,
            'sweeper_clears_per_90': stats['sweeper_clears'] / factor,

            # Success rates
            'save_percentage': (stats['saves'] / stats['shots_faced']) * 100 if stats['shots_faced'] else 0,
            'smother_success_rate': (stats['successful_smothers'] / stats['smothers']) * 100 if stats['smothers'] else 0,
            'collection_success_rate': (stats['successful_collections'] / stats['collections']) * 100 if stats['collections'] else 0,
            'punch_success_rate': (stats['successful_punches'] / stats['punches']) * 100 if stats['punches'] else 0,
            'sweeper_success_rate': (
                stats['successful_sweepers'] /
                (stats['sweeper_claims'] + stats['sweeper_clears'])
            ) * 100 if (stats['sweeper_claims'] + stats['sweeper_clears']) else 0
        })

# %%
for player in player_data:
    position = player.get('position', '').lower()
    if 'goalkeeper' in position or position == 'gk':
        print(player)
# Out:
# {'player_id': 6730, 'name': 'Rubén Iván Martínez Andrade', 'minutes': 2124.32, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 17.49736386231829, 'pass_accuracy': 55.205811138014525, 'progressive_passes_per_90': 12.32865105068916, 'progressive_pass_accuracy': 37.80068728522337, 'long_passes_per_90': 12.159185056865255, 'long_pass_accuracy': 37.63066202090592, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 4.872147322437297, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.042366498455976495, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.042366498455976495, 'ball_recoveries_per_90': 2.8385553965504253, 'fouls_made_per_90': 0.042366498455976495, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.042366498455976495, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.837802214355651, 'saves_per_90': 1.7793929351510127, 'goals_conceded_per_90': 1.1438954583113654, 'smothers_per_90': 0.0, 'collections_per_90': 0.6778639752956239, 'punches_per_90': 0.4236649845597649, 'sweeper_claims_per_90': 0.46603148301574143, 'sweeper_clears_per_90': 0.042366498455976495, 'save_percentage': 22.702702702702705, 'smother_success_rate': 0, 'collection_success_rate': 93.75, 'punch_success_rate': 70.0, 'sweeper_success_rate': 100.0}
# {'player_id': 10763, 'name': 'Asier Riesgo Unamuno', 'minutes': 4803.5, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.972936400541272, 'pass_accuracy': 47.467166979362105, 'progressive_passes_per_90': 17.218694701779953, 'progressive_pass_accuracy': 40.26115342763873, 'long_passes_per_90': 17.143749349432706, 'long_pass_accuracy': 39.89071038251366, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.018736338086811702, 'assists_per_90': 0.0, 'passes_received_per_90': 5.658374102217134, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.018736338086811702, 'fouls_won_per_90': 0.18736338086811702, 'pressures_per_90': 0.0562090142604351, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.037472676173623404, 'clearances_per_90': 0.1124180285208702, 'ball_recoveries_per_90': 3.9533673363172688, 'fouls_made_per_90': 0.018736338086811702, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.018736338086811702, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.632663682731342, 'saves_per_90': 1.5176433850317477, 'goals_conceded_per_90': 0.9930259186010202, 'smothers_per_90': 0.07494535234724681, 'collections_per_90': 0.9555532424273967, 'punches_per_90': 0.4121994379098574, 'sweeper_claims_per_90': 0.5995628187779745, 'sweeper_clears_per_90': 0.3559904236494223, 'save_percentage': 22.88135593220339, 'smother_success_rate': 75.0, 'collection_success_rate': 98.0392156862745, 'punch_success_rate': 59.09090909090909, 'sweeper_success_rate': 100.0}
# {'player_id': 26753, 'name': 'Javier Varas Herrera', 'minutes': 4393.57, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 25.01155097107819, 'pass_accuracy': 62.40786240786241, 'progressive_passes_per_90': 14.175260665017287, 'progressive_pass_accuracy': 37.283236994219656, 'long_passes_per_90': 14.543981318153575, 'long_pass_accuracy': 37.605633802816904, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 11.082104074818428, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.061453442189381306, 'successful_dribbles_per_90': 0.061453442189381306, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.02048448072979377, 'fouls_won_per_90': 0.16387584583835016, 'pressures_per_90': 0.14339136510855638, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.02048448072979377, 'clearances_per_90': 0.04096896145958754, 'ball_recoveries_per_90': 3.605268608443703, 'fouls_made_per_90': 0.04096896145958754, 'yellow_cards_per_90': 0.02048448072979377, 'red_cards_per_90': 0.02048448072979377, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.39489754345555, 'saves_per_90': 2.027963592249583, 'goals_conceded_per_90': 0.798894748461957, 'smothers_per_90': 0.02048448072979377, 'collections_per_90': 0.4506585760554629, 'punches_per_90': 0.49162753751505045, 'sweeper_claims_per_90': 0.6350189026236068, 'sweeper_clears_per_90': 0.22532928802773144, 'save_percentage': 27.42382271468144, 'smother_success_rate': 0.0, 'collection_success_rate': 95.45454545454545, 'punch_success_rate': 62.5, 'sweeper_success_rate': 100.0}
# {'player_id': 6823, 'name': 'Sergio Rico González', 'minutes': 4824.12, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.029377378672173, 'pass_accuracy': 66.47058823529412, 'progressive_passes_per_90': 10.39153254894157, 'progressive_pass_accuracy': 40.93357271095152, 'long_passes_per_90': 10.447501305937664, 'long_pass_accuracy': 40.17857142857143, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 7.201313400164175, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.14925001865625234, 'pressures_per_90': 0.07462500932812617, 'blocks_per_90': 0.05596875699609463, 'interceptions_per_90': 0.037312504664063086, 'dribbled_past_per_90': 0.018656252332031543, 'clearances_per_90': 0.018656252332031543, 'ball_recoveries_per_90': 2.9850003731250467, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 8.880376110047015, 'saves_per_90': 2.0895002611875326, 'goals_conceded_per_90': 0.7462500932812617, 'smothers_per_90': 0.018656252332031543, 'collections_per_90': 0.8768438596054825, 'punches_per_90': 0.6902813362851671, 'sweeper_claims_per_90': 0.2611875326484416, 'sweeper_clears_per_90': 0.1679062709882839, 'save_percentage': 23.52941176470588, 'smother_success_rate': 100.0, 'collection_success_rate': 95.74468085106383, 'punch_success_rate': 70.27027027027027, 'sweeper_success_rate': 100.0}
# {'player_id': 27457, 'name': 'Manuel Fernández Muñíz', 'minutes': 1090.75, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 20.215448086179236, 'pass_accuracy': 46.53061224489796, 'progressive_passes_per_90': 17.492550997020402, 'progressive_pass_accuracy': 39.62264150943396, 'long_passes_per_90': 17.079990831996334, 'long_pass_accuracy': 38.164251207729464, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0825120330048132, 'assists_per_90': 0.0, 'passes_received_per_90': 7.6736190694476285, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.24753609901443963, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0825120330048132, 'clearances_per_90': 0.1650240660096264, 'ball_recoveries_per_90': 2.31033692413477, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.931010772404309, 'saves_per_90': 1.3201925280770113, 'goals_conceded_per_90': 1.4027045610818245, 'smothers_per_90': 0.0, 'collections_per_90': 0.6600962640385056, 'punches_per_90': 0.49507219802887925, 'sweeper_claims_per_90': 0.5775842310336925, 'sweeper_clears_per_90': 0.49507219802887925, 'save_percentage': 19.047619047619047, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 66.66666666666666, 'sweeper_success_rate': 100.0}
# {'player_id': 6625, 'name': 'Vicente Guaita Panadero', 'minutes': 5375.87, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.302922131673572, 'pass_accuracy': 52.818733738074584, 'progressive_passes_per_90': 13.292732153121262, 'progressive_pass_accuracy': 32.7455919395466, 'long_passes_per_90': 13.292732153121262, 'long_pass_accuracy': 32.7455919395466, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.03348295252675381, 'assists_per_90': 0.0, 'passes_received_per_90': 6.445468361400108, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.016741476263376905, 'successful_dribbles_per_90': 0.016741476263376905, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.06696590505350762, 'pressures_per_90': 0.03348295252675381, 'blocks_per_90': 0.016741476263376905, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.05022442879013071, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.9130168698275813, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 8.00242565389416, 'saves_per_90': 2.126167485448867, 'goals_conceded_per_90': 1.1049374333828756, 'smothers_per_90': 0.016741476263376905, 'collections_per_90': 1.037971528329368, 'punches_per_90': 0.6864005267984531, 'sweeper_claims_per_90': 0.46876133537455333, 'sweeper_clears_per_90': 0.21763919142389976, 'save_percentage': 26.569037656903767, 'smother_success_rate': 100.0, 'collection_success_rate': 96.7741935483871, 'punch_success_rate': 78.04878048780488, 'sweeper_success_rate': 100.0}
# {'player_id': 5577, 'name': 'Francisco Guillermo Ochoa Magaña', 'minutes': 1516.6, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 17.44692074376896, 'pass_accuracy': 56.80272108843537, 'progressive_passes_per_90': 11.690623763681922, 'progressive_pass_accuracy': 37.055837563451774, 'long_passes_per_90': 11.927996835025716, 'long_pass_accuracy': 37.81094527363184, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 5.756296980087037, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.11868653567189769, 'blocks_per_90': 0.05934326783594884, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.2045364631412374, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.705789265462219, 'saves_per_90': 1.7209547672425163, 'goals_conceded_per_90': 0.5934326783594884, 'smothers_per_90': 0.11868653567189769, 'collections_per_90': 0.7714624818673349, 'punches_per_90': 0.2967163391797442, 'sweeper_claims_per_90': 0.2967163391797442, 'sweeper_clears_per_90': 0.11868653567189769, 'save_percentage': 25.663716814159294, 'smother_success_rate': 0.0, 'collection_success_rate': 92.3076923076923, 'punch_success_rate': 100.0, 'sweeper_success_rate': 100.0}
# {'player_id': 23843, 'name': 'Diego Mariño Villar', 'minutes': 3258.85, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 22.8945793761603, 'pass_accuracy': 69.96381182147165, 'progressive_passes_per_90': 12.869570554029796, 'progressive_pass_accuracy': 47.63948497854077, 'long_passes_per_90': 12.64863372048422, 'long_pass_accuracy': 47.59825327510917, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.05523420838639397, 'assists_per_90': 0.0, 'passes_received_per_90': 8.80985623762984, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.027617104193196986, 'successful_dribbles_per_90': 0.027617104193196986, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.16570262515918194, 'pressures_per_90': 0.05523420838639397, 'blocks_per_90': 0.05523420838639397, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.027617104193196986, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.6178406493088056, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 8.89270755020943, 'saves_per_90': 2.209368335455759, 'goals_conceded_per_90': 1.1046841677278796, 'smothers_per_90': 0.0, 'collections_per_90': 1.2980038970802583, 'punches_per_90': 0.5799591880571368, 'sweeper_claims_per_90': 0.49710787547754576, 'sweeper_clears_per_90': 0.1933197293523789, 'save_percentage': 24.84472049689441, 'smother_success_rate': 0, 'collection_success_rate': 97.87234042553192, 'punch_success_rate': 61.904761904761905, 'sweeper_success_rate': 100.0}
# {'player_id': 6792, 'name': 'Pau López Sabata', 'minutes': 5054.5, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 17.431991294885744, 'pass_accuracy': 55.260469867211434, 'progressive_passes_per_90': 11.929963398951429, 'progressive_pass_accuracy': 37.3134328358209, 'long_passes_per_90': 11.573845088534968, 'long_pass_accuracy': 35.38461538461539, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 4.8432090216638635, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.1246414086457612, 'pressures_per_90': 0.1246414086457612, 'blocks_per_90': 0.03561183104164606, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.03561183104164606, 'clearances_per_90': 0.01780591552082303, 'ball_recoveries_per_90': 3.044811554060738, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 8.17291522405777, 'saves_per_90': 1.816203383123949, 'goals_conceded_per_90': 1.0861608467702049, 'smothers_per_90': 0.01780591552082303, 'collections_per_90': 0.8012661984370363, 'punches_per_90': 0.3561183104164606, 'sweeper_claims_per_90': 0.3561183104164606, 'sweeper_clears_per_90': 0.3205064793748145, 'save_percentage': 22.22222222222222, 'smother_success_rate': 0.0, 'collection_success_rate': 95.55555555555556, 'punch_success_rate': 70.0, 'sweeper_success_rate': 100.0}
# {'player_id': 27462, 'name': 'Xabier Iruretagoiena Aranzamendi', 'minutes': 566.63, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 17.78938637205937, 'pass_accuracy': 47.32142857142857, 'progressive_passes_per_90': 14.771544041085013, 'progressive_pass_accuracy': 36.55913978494624, 'long_passes_per_90': 14.453876427298239, 'long_pass_accuracy': 36.26373626373626, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 6.35335227573549, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.31766761378677444, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.15883380689338722, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.4943437516545193, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.035684661948714, 'saves_per_90': 2.064839489614034, 'goals_conceded_per_90': 1.1118366482537105, 'smothers_per_90': 0.0, 'collections_per_90': 0.7941690344669362, 'punches_per_90': 0.6353352275735489, 'sweeper_claims_per_90': 0.15883380689338722, 'sweeper_clears_per_90': 0.6353352275735489, 'save_percentage': 34.21052631578947, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 75.0, 'sweeper_success_rate': 100.0}
# {'player_id': 7905, 'name': 'Raúl Lizoáin Cruz', 'minutes': 1114.77, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 23.816572028310773, 'pass_accuracy': 58.644067796610166, 'progressive_passes_per_90': 13.321133507360264, 'progressive_pass_accuracy': 34.54545454545455, 'long_passes_per_90': 14.451411501924165, 'long_pass_accuracy': 34.63687150837989, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 9.365160526386608, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.16146828493770016, 'pressures_per_90': 0.08073414246885008, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.08073414246885008, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.7137705535671035, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 9.76883123873086, 'saves_per_90': 2.9871632713474527, 'goals_conceded_per_90': 1.049543852095051, 'smothers_per_90': 0.08073414246885008, 'collections_per_90': 0.8073414246885008, 'punches_per_90': 0.6458731397508006, 'sweeper_claims_per_90': 0.4036707123442504, 'sweeper_clears_per_90': 0.48440485481310047, 'save_percentage': 30.57851239669421, 'smother_success_rate': 100.0, 'collection_success_rate': 100.0, 'punch_success_rate': 87.5, 'sweeper_success_rate': 100.0}
# {'player_id': 6610, 'name': 'Iván Cuéllar Sacristán', 'minutes': 4527.05, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 20.258225555273302, 'pass_accuracy': 43.179587831207066, 'progressive_passes_per_90': 15.82487491854519, 'progressive_pass_accuracy': 29.2713567839196, 'long_passes_per_90': 15.804994422416364, 'long_pass_accuracy': 28.30188679245283, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.019880496128825614, 'assists_per_90': 0.03976099225765123, 'passes_received_per_90': 6.262356280580069, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.15904396903060491, 'pressures_per_90': 0.05964148838647684, 'blocks_per_90': 0.019880496128825614, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.07952198451530246, 'clearances_per_90': 0.019880496128825614, 'ball_recoveries_per_90': 3.200759876740924, 'fouls_made_per_90': 0.019880496128825614, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 8.926342761842701, 'saves_per_90': 2.3061375509437716, 'goals_conceded_per_90': 0.9542638141836295, 'smothers_per_90': 0.019880496128825614, 'collections_per_90': 0.8946223257971527, 'punches_per_90': 0.6958173645088965, 'sweeper_claims_per_90': 0.5964148838647685, 'sweeper_clears_per_90': 0.21868545741708176, 'save_percentage': 25.83518930957684, 'smother_success_rate': 100.0, 'collection_success_rate': 91.11111111111111, 'punch_success_rate': 74.28571428571429, 'sweeper_success_rate': 100.0}
# {'player_id': 6860, 'name': 'Mariano Damián Barbosa', 'minutes': 277.9, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 13.925872616048938, 'pass_accuracy': 76.74418604651163, 'progressive_passes_per_90': 4.534005037783375, 'progressive_pass_accuracy': 35.714285714285715, 'long_passes_per_90': 5.505577545879813, 'long_pass_accuracy': 41.17647058823529, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 5.829435048578626, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.3238575026988125, 'successful_dribbles_per_90': 0.3238575026988125, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.914717524289313, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.772580064771501, 'saves_per_90': 1.9431450161928752, 'goals_conceded_per_90': 1.29543001079525, 'smothers_per_90': 0.0, 'collections_per_90': 0.3238575026988125, 'punches_per_90': 0.647715005397625, 'sweeper_claims_per_90': 0.0, 'sweeper_clears_per_90': 0.3238575026988125, 'save_percentage': 25.0, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 0.0, 'sweeper_success_rate': 100.0}
# {'player_id': 10612, 'name': 'Yoel Rodríguez Oterino', 'minutes': 1272.63, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 25.034770514603615, 'pass_accuracy': 64.12429378531074, 'progressive_passes_per_90': 13.15386247377478, 'progressive_pass_accuracy': 35.483870967741936, 'long_passes_per_90': 12.588104948021027, 'long_pass_accuracy': 33.146067415730336, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.07071969071921926, 'assists_per_90': 0.0, 'passes_received_per_90': 10.678673298602106, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.1414393814384385, 'pressures_per_90': 0.07071969071921926, 'blocks_per_90': 0.07071969071921926, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.07071969071921926, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 4.101742061714717, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 9.052120412060065, 'saves_per_90': 1.9094316494189199, 'goals_conceded_per_90': 1.697272577261262, 'smothers_per_90': 0.0, 'collections_per_90': 0.7071969071921925, 'punches_per_90': 0.282878762876877, 'sweeper_claims_per_90': 0.4243181443153155, 'sweeper_clears_per_90': 1.2022347422267272, 'save_percentage': 21.09375, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 75.0, 'sweeper_success_rate': 100.0}
# {'player_id': 8803, 'name': 'Daniel Giménez Hernández', 'minutes': 365.33, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 21.186324692743547, 'pass_accuracy': 54.65116279069767, 'progressive_passes_per_90': 14.042098924260259, 'progressive_pass_accuracy': 31.57894736842105, 'long_passes_per_90': 13.795746311553938, 'long_pass_accuracy': 30.357142857142854, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 9.607751895546492, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.956231352475844, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 5.6661100922453675, 'saves_per_90': 1.2317630635316017, 'goals_conceded_per_90': 0.49270522541264067, 'smothers_per_90': 0.0, 'collections_per_90': 0.9854104508252813, 'punches_per_90': 0.0, 'sweeper_claims_per_90': 0.0, 'sweeper_clears_per_90': 0.24635261270632033, 'save_percentage': 21.73913043478261, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 0, 'sweeper_success_rate': 100.0}
# {'player_id': 20086, 'name': 'Stipe Pletikosa', 'minutes': 278.17, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.736132580795914, 'pass_accuracy': 50.81967213114754, 'progressive_passes_per_90': 15.206528381924722, 'progressive_pass_accuracy': 42.5531914893617, 'long_passes_per_90': 14.559442067800266, 'long_pass_accuracy': 37.77777777777778, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 7.117949455369018, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.32354315706222814, 'ball_recoveries_per_90': 2.588345256497825, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 9.382751554804615, 'saves_per_90': 1.6177157853111406, 'goals_conceded_per_90': 1.9412589423733688, 'smothers_per_90': 0.0, 'collections_per_90': 0.0, 'punches_per_90': 0.0, 'sweeper_claims_per_90': 0.32354315706222814, 'sweeper_clears_per_90': 0.32354315706222814, 'save_percentage': 17.24137931034483, 'smother_success_rate': 0, 'collection_success_rate': 0, 'punch_success_rate': 0, 'sweeper_success_rate': 100.0}
# {'player_id': 5597, 'name': 'Keylor Navas Gamboa', 'minutes': 4788.0, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 17.01127819548872, 'pass_accuracy': 69.28176795580112, 'progressive_passes_per_90': 8.19548872180451, 'progressive_pass_accuracy': 39.22018348623853, 'long_passes_per_90': 8.026315789473683, 'long_pass_accuracy': 37.00234192037471, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.018796992481203006, 'assists_per_90': 0.0, 'passes_received_per_90': 6.672932330827067, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.11278195488721804, 'pressures_per_90': 0.07518796992481203, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.03759398496240601, 'ball_recoveries_per_90': 2.725563909774436, 'fouls_made_per_90': 0.03759398496240601, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.274436090225564, 'saves_per_90': 1.7857142857142856, 'goals_conceded_per_90': 0.5263157894736842, 'smothers_per_90': 0.05639097744360902, 'collections_per_90': 0.5263157894736842, 'punches_per_90': 0.3383458646616541, 'sweeper_claims_per_90': 0.41353383458646614, 'sweeper_clears_per_90': 0.2819548872180451, 'save_percentage': 24.54780361757106, 'smother_success_rate': 100.0, 'collection_success_rate': 100.0, 'punch_success_rate': 77.77777777777779, 'sweeper_success_rate': 100.0}
# {'player_id': 6576, 'name': 'Gorka Iraizoz Moreno', 'minutes': 5232.77, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 23.373853618637927, 'pass_accuracy': 60.191317144959534, 'progressive_passes_per_90': 16.218943313006303, 'progressive_pass_accuracy': 43.47826086956522, 'long_passes_per_90': 16.18454470576769, 'long_pass_accuracy': 43.145589798087144, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.05159791085792037, 'assists_per_90': 0.0, 'passes_received_per_90': 11.076351530833573, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.05159791085792037, 'pressures_per_90': 0.01719930361930679, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.01719930361930679, 'clearances_per_90': 0.05159791085792037, 'ball_recoveries_per_90': 3.3882628130034376, 'fouls_made_per_90': 0.01719930361930679, 'yellow_cards_per_90': 0.01719930361930679, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.105752784853911, 'saves_per_90': 1.5823359329762248, 'goals_conceded_per_90': 0.6019756266757377, 'smothers_per_90': 0.0, 'collections_per_90': 0.6707728411529649, 'punches_per_90': 0.2751888579089086, 'sweeper_claims_per_90': 0.5847763230564309, 'sweeper_clears_per_90': 0.49877980495989693, 'save_percentage': 25.915492957746476, 'smother_success_rate': 0, 'collection_success_rate': 97.43589743589743, 'punch_success_rate': 93.75, 'sweeper_success_rate': 100.0}
# {'player_id': 6378, 'name': 'Jan Oblak', 'minutes': 5378.6, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 13.687576692819691, 'pass_accuracy': 51.71149144254279, 'progressive_passes_per_90': 9.772059643773472, 'progressive_pass_accuracy': 33.9041095890411, 'long_passes_per_90': 9.755326664931394, 'long_pass_accuracy': 33.61921097770154, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.01673297884207786, 'assists_per_90': 0.0, 'passes_received_per_90': 4.099579816309077, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.01673297884207786, 'successful_dribbles_per_90': 0.01673297884207786, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0836648942103893, 'pressures_per_90': 0.0, 'blocks_per_90': 0.01673297884207786, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.01673297884207786, 'clearances_per_90': 0.03346595768415572, 'ball_recoveries_per_90': 2.2589521436805113, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.241401108095043, 'saves_per_90': 1.455769159260774, 'goals_conceded_per_90': 0.3011936191574015, 'smothers_per_90': 0.0, 'collections_per_90': 0.6191202171568809, 'punches_per_90': 0.28446064031532364, 'sweeper_claims_per_90': 0.2509946826311679, 'sweeper_clears_per_90': 0.0836648942103893, 'save_percentage': 23.324396782841823, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 82.35294117647058, 'sweeper_success_rate': 100.0}
# {'player_id': 6884, 'name': 'Sergio Álvarez Conde', 'minutes': 4327.18, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 20.81956378056841, 'pass_accuracy': 58.341658341658345, 'progressive_passes_per_90': 12.936831839673875, 'progressive_pass_accuracy': 35.048231511254016, 'long_passes_per_90': 12.791240484565005, 'long_pass_accuracy': 33.4959349593496, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 9.151456606843256, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.020798765015552854, 'pressures_per_90': 0.06239629504665856, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.04159753003110571, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.849430807130741, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.799536880832321, 'saves_per_90': 1.871888851399757, 'goals_conceded_per_90': 0.9359444256998785, 'smothers_per_90': 0.0, 'collections_per_90': 0.6863592455132442, 'punches_per_90': 0.3535790052643985, 'sweeper_claims_per_90': 0.5407678904043742, 'sweeper_clears_per_90': 0.12479259009331713, 'save_percentage': 24.0, 'smother_success_rate': 0, 'collection_success_rate': 93.93939393939394, 'punch_success_rate': 70.58823529411765, 'sweeper_success_rate': 100.0}
# {'player_id': 6898, 'name': 'Jaume Doménech Sánchez', 'minutes': 2407.9, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.286515220731758, 'pass_accuracy': 59.10852713178295, 'progressive_passes_per_90': 12.633415008928942, 'progressive_pass_accuracy': 40.23668639053255, 'long_passes_per_90': 12.857676813821172, 'long_pass_accuracy': 39.825581395348834, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.03737696748203829, 'assists_per_90': 0.0, 'passes_received_per_90': 6.540969309356701, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.18688483741019143, 'pressures_per_90': 0.03737696748203829, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.03737696748203829, 'clearances_per_90': 0.03737696748203829, 'ball_recoveries_per_90': 2.579010756260642, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 9.119980065617343, 'saves_per_90': 2.429502886332489, 'goals_conceded_per_90': 0.6727854146766892, 'smothers_per_90': 0.03737696748203829, 'collections_per_90': 0.48590057726649777, 'punches_per_90': 0.4111466423024212, 'sweeper_claims_per_90': 0.22426180489222974, 'sweeper_clears_per_90': 0.07475393496407658, 'save_percentage': 26.639344262295083, 'smother_success_rate': 100.0, 'collection_success_rate': 100.0, 'punch_success_rate': 27.27272727272727, 'sweeper_success_rate': 100.0}
# {'player_id': 6694, 'name': 'Gerónimo Rulli', 'minutes': 5087.58, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 22.112674395292064, 'pass_accuracy': 62.08, 'progressive_passes_per_90': 13.692167985564847, 'progressive_pass_accuracy': 40.43927648578811, 'long_passes_per_90': 13.409125753305108, 'long_pass_accuracy': 39.44591029023747, 'crosses_per_90': 0.01769013951623365, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.01769013951623365, 'assists_per_90': 0.0, 'passes_received_per_90': 10.401802035545387, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0353802790324673, 'successful_dribbles_per_90': 0.0353802790324673, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.10614083709740191, 'pressures_per_90': 0.15921125564610286, 'blocks_per_90': 0.01769013951623365, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0707605580649346, 'clearances_per_90': 0.0353802790324673, 'ball_recoveries_per_90': 2.795042043564917, 'fouls_made_per_90': 0.0353802790324673, 'yellow_cards_per_90': 0.01769013951623365, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.005295248428526, 'saves_per_90': 1.9105350677532345, 'goals_conceded_per_90': 0.7429858596818134, 'smothers_per_90': 0.0707605580649346, 'collections_per_90': 0.5130140459707759, 'punches_per_90': 0.3714929298409067, 'sweeper_claims_per_90': 0.4776337669383086, 'sweeper_clears_per_90': 0.17690139516233652, 'save_percentage': 27.27272727272727, 'smother_success_rate': 50.0, 'collection_success_rate': 93.10344827586206, 'punch_success_rate': 47.61904761904761, 'sweeper_success_rate': 100.0}
# {'player_id': 6654, 'name': 'Antonio Adán Garrido', 'minutes': 5030.25, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 20.46816758610407, 'pass_accuracy': 43.35664335664335, 'progressive_passes_per_90': 16.013120620247502, 'progressive_pass_accuracy': 29.385474860335197, 'long_passes_per_90': 16.031012375130462, 'long_pass_accuracy': 29.017857142857146, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.03578350976591621, 'assists_per_90': 0.0, 'passes_received_per_90': 6.441031757864917, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.017891754882958105, 'successful_dribbles_per_90': 0.017891754882958105, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.05367526464887431, 'pressures_per_90': 0.10735052929774862, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.05367526464887431, 'clearances_per_90': 0.017891754882958105, 'ball_recoveries_per_90': 2.9700313105710454, 'fouls_made_per_90': 0.017891754882958105, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.017891754882958105, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 9.035336215893842, 'saves_per_90': 2.272252870135679, 'goals_conceded_per_90': 0.8766959892649471, 'smothers_per_90': 0.05367526464887431, 'collections_per_90': 1.0556135380945282, 'punches_per_90': 0.5904279111376174, 'sweeper_claims_per_90': 0.3757268525421202, 'sweeper_clears_per_90': 0.12524228418070674, 'save_percentage': 25.14851485148515, 'smother_success_rate': 100.0, 'collection_success_rate': 94.91525423728814, 'punch_success_rate': 78.78787878787878, 'sweeper_success_rate': 100.0}
# {'player_id': 8697, 'name': 'Andrés Eduardo Fernández Moreno', 'minutes': 5265.23, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.41795515105703, 'pass_accuracy': 56.690140845070424, 'progressive_passes_per_90': 13.572056681284579, 'progressive_pass_accuracy': 40.17632241813602, 'long_passes_per_90': 13.503683599766772, 'long_pass_accuracy': 39.24050632911392, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.03418654075890322, 'assists_per_90': 0.0, 'passes_received_per_90': 5.845898469772451, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.03418654075890322, 'successful_dribbles_per_90': 0.01709327037945161, 'dribble_success_rate': 50.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.1538394334150645, 'pressures_per_90': 0.10255962227670966, 'blocks_per_90': 0.03418654075890322, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.06837308151780644, 'clearances_per_90': 0.03418654075890322, 'ball_recoveries_per_90': 3.6237733204437417, 'fouls_made_per_90': 0.01709327037945161, 'yellow_cards_per_90': 0.01709327037945161, 'red_cards_per_90': 0.0, 'duels_per_90': 0.01709327037945161, 'duels_won_per_90': 0.01709327037945161, 'duel_success_rate': 100.0, 'shots_faced_per_90': 7.144987018610773, 'saves_per_90': 1.7606068490835158, 'goals_conceded_per_90': 1.093969304284903, 'smothers_per_90': 0.03418654075890322, 'collections_per_90': 0.8717567893520322, 'punches_per_90': 0.5982644632808064, 'sweeper_claims_per_90': 0.307678866830129, 'sweeper_clears_per_90': 0.2905855964506774, 'save_percentage': 24.641148325358852, 'smother_success_rate': 100.0, 'collection_success_rate': 96.07843137254902, 'punch_success_rate': 65.71428571428571, 'sweeper_success_rate': 100.0}
# {'player_id': 6755, 'name': 'Sergio Asenjo Andrés', 'minutes': 570.03, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 16.578074838166412, 'pass_accuracy': 57.14285714285714, 'progressive_passes_per_90': 12.473027735382349, 'progressive_pass_accuracy': 44.303797468354425, 'long_passes_per_90': 12.630914162412504, 'long_pass_accuracy': 46.25, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 4.736592810904689, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.7367506973317193, 'fouls_made_per_90': 0.15788642703015632, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.15788642703015632, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 9.315299194779222, 'saves_per_90': 1.8946371243618756, 'goals_conceded_per_90': 0.7894321351507815, 'smothers_per_90': 0.15788642703015632, 'collections_per_90': 0.9473185621809378, 'punches_per_90': 0.6315457081206253, 'sweeper_claims_per_90': 0.31577285406031264, 'sweeper_clears_per_90': 0.15788642703015632, 'save_percentage': 20.33898305084746, 'smother_success_rate': 100.0, 'collection_success_rate': 100.0, 'punch_success_rate': 25.0, 'sweeper_success_rate': 100.0}
# {'player_id': 31904, 'name': 'Giedrius Arlauskis', 'minutes': 325.27, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.645217819042642, 'pass_accuracy': 42.25352112676056, 'progressive_passes_per_90': 14.664740062102254, 'progressive_pass_accuracy': 26.41509433962264, 'long_passes_per_90': 14.664740062102254, 'long_pass_accuracy': 26.41509433962264, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 6.640637009253851, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.8300796261567314, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.3203185046269255, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.5533864174378209, 'duels_won_per_90': 0.27669320871891045, 'duel_success_rate': 50.0, 'shots_faced_per_90': 10.237648722599687, 'saves_per_90': 1.9368524610323732, 'goals_conceded_per_90': 3.043625295908015, 'smothers_per_90': 0.0, 'collections_per_90': 0.5533864174378209, 'punches_per_90': 1.3834660435945523, 'sweeper_claims_per_90': 0.5533864174378209, 'sweeper_clears_per_90': 0.0, 'save_percentage': 18.91891891891892, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 60.0, 'sweeper_success_rate': 100.0}
# {'player_id': 6692, 'name': 'Oier Olazábal Paredes', 'minutes': 381.72, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 21.927066960075447, 'pass_accuracy': 54.83870967741935, 'progressive_passes_per_90': 14.853819553599497, 'progressive_pass_accuracy': 33.33333333333333, 'long_passes_per_90': 14.618044640050298, 'long_pass_accuracy': 32.25806451612903, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 9.430996541967934, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.23577491354919836, 'pressures_per_90': 0.23577491354919836, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.3008487896887773, 'fouls_made_per_90': 0.23577491354919836, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.23577491354919836, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.837472492926753, 'saves_per_90': 0.9430996541967934, 'goals_conceded_per_90': 1.1788745677459918, 'smothers_per_90': 0.0, 'collections_per_90': 0.7073247406475951, 'punches_per_90': 0.0, 'sweeper_claims_per_90': 0.4715498270983967, 'sweeper_clears_per_90': 0.0, 'save_percentage': 13.793103448275861, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 0, 'sweeper_success_rate': 100.0}
# ...
# {'player_id': 27305, 'name': 'Germán Darío Lux', 'minutes': 4009.88, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 22.98323141839656, 'pass_accuracy': 52.63671875, 'progressive_passes_per_90': 17.416980059253643, 'progressive_pass_accuracy': 39.819587628865975, 'long_passes_per_90': 17.34964637345756, 'long_pass_accuracy': 39.19793014230272, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.02244456193202789, 'assists_per_90': 0.0, 'passes_received_per_90': 9.965385497820384, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.02244456193202789, 'successful_dribbles_per_90': 0.02244456193202789, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.02244456193202789, 'fouls_won_per_90': 0.15711193352419522, 'pressures_per_90': 0.06733368579608368, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.06733368579608368, 'clearances_per_90': 0.06733368579608368, 'ball_recoveries_per_90': 2.9626821750276817, 'fouls_made_per_90': 0.02244456193202789, 'yellow_cards_per_90': 0.02244456193202789, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.755813141540395, 'saves_per_90': 1.7057867068341197, 'goals_conceded_per_90': 0.8304487914850319, 'smothers_per_90': 0.0, 'collections_per_90': 0.7182259818248925, 'punches_per_90': 0.2917793051163626, 'sweeper_claims_per_90': 0.5386694863686694, 'sweeper_clears_per_90': 0.17955649545622313, 'save_percentage': 25.249169435215947, 'smother_success_rate': 0, 'collection_success_rate': 96.875, 'punch_success_rate': 61.53846153846154, 'sweeper_success_rate': 100.0}
# {'player_id': 26103, 'name': 'Idriss Carlos Kameni', 'minutes': 3869.67, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 18.187597392025676, 'pass_accuracy': 65.98465473145781, 'progressive_passes_per_90': 11.187000441898146, 'progressive_pass_accuracy': 47.60914760914761, 'long_passes_per_90': 11.163742644721642, 'long_pass_accuracy': 47.291666666666664, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.023257797176503423, 'passes_received_per_90': 4.3026924776531335, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.046515594353006846, 'successful_dribbles_per_90': 0.046515594353006846, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.023257797176503423, 'pressures_per_90': 0.046515594353006846, 'blocks_per_90': 0.023257797176503423, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.023257797176503423, 'ball_recoveries_per_90': 3.302607199063486, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.907565761421517, 'saves_per_90': 1.8141081797672671, 'goals_conceded_per_90': 0.5116715378830753, 'smothers_per_90': 0.023257797176503423, 'collections_per_90': 1.4419834249432122, 'punches_per_90': 0.37212475482405477, 'sweeper_claims_per_90': 0.5581871322360822, 'sweeper_clears_per_90': 0.16280458023552397, 'save_percentage': 26.262626262626267, 'smother_success_rate': 100.0, 'collection_success_rate': 96.7741935483871, 'punch_success_rate': 43.75, 'sweeper_success_rate': 100.0}
# {'player_id': 11537, 'name': 'Alberto García Cabrera', 'minutes': 862.73, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 21.4899215281722, 'pass_accuracy': 49.51456310679612, 'progressive_passes_per_90': 15.022081068236877, 'progressive_pass_accuracy': 29.166666666666668, 'long_passes_per_90': 14.60480103856363, 'long_pass_accuracy': 26.42857142857143, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 6.676480474771945, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.10432000741831164, 'pressures_per_90': 0.0, 'blocks_per_90': 0.10432000741831164, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.20864001483662328, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.233920229967661, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 10.11904071957623, 'saves_per_90': 2.920960207712726, 'goals_conceded_per_90': 1.3561600964380514, 'smothers_per_90': 0.10432000741831164, 'collections_per_90': 0.41728002967324657, 'punches_per_90': 0.41728002967324657, 'sweeper_claims_per_90': 0.7302400519281815, 'sweeper_clears_per_90': 0.10432000741831164, 'save_percentage': 28.865979381443296, 'smother_success_rate': 0.0, 'collection_success_rate': 100.0, 'punch_success_rate': 75.0, 'sweeper_success_rate': 100.0}
# {'player_id': 6706, 'name': 'Francisco Casilla Cortés', 'minutes': 563.2, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 13.902698863636363, 'pass_accuracy': 66.66666666666666, 'progressive_passes_per_90': 5.912642045454545, 'progressive_pass_accuracy': 29.72972972972973, 'long_passes_per_90': 6.551846590909091, 'long_pass_accuracy': 34.146341463414636, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 5.113636363636363, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.237215909090909, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 7.830255681818182, 'saves_per_90': 2.237215909090909, 'goals_conceded_per_90': 0.9588068181818181, 'smothers_per_90': 0.0, 'collections_per_90': 0.6392045454545454, 'punches_per_90': 0.3196022727272727, 'sweeper_claims_per_90': 0.3196022727272727, 'sweeper_clears_per_90': 0.15980113636363635, 'save_percentage': 28.57142857142857, 'smother_success_rate': 0, 'collection_success_rate': 75.0, 'punch_success_rate': 100.0, 'sweeper_success_rate': 100.0}
# {'player_id': 27111, 'name': 'António Alberto Bastos Pimparel', 'minutes': 562.6, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 19.35655883398507, 'pass_accuracy': 71.900826446281, 'progressive_passes_per_90': 10.558123000355492, 'progressive_pass_accuracy': 50.0, 'long_passes_per_90': 10.71809456096694, 'long_pass_accuracy': 49.25373134328358, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 7.198720227515108, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.3199431212228937, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.239601848560256, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 10.878066121578385, 'saves_per_90': 2.239601848560256, 'goals_conceded_per_90': 1.2797724848915748, 'smothers_per_90': 0.0, 'collections_per_90': 0.47991468183434055, 'punches_per_90': 0.7998578030572342, 'sweeper_claims_per_90': 0.0, 'sweeper_clears_per_90': 0.0, 'save_percentage': 20.588235294117645, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 80.0, 'sweeper_success_rate': 0}
# {'player_id': 4691, 'name': 'Claudio Andrés Bravo Muñoz', 'minutes': 4437.65, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 20.362128604103525, 'pass_accuracy': 84.4621513944223, 'progressive_passes_per_90': 5.232499183126205, 'progressive_pass_accuracy': 46.51162790697674, 'long_passes_per_90': 5.212218178540445, 'long_pass_accuracy': 44.3579766536965, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 11.073428503825225, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.020281004585760484, 'successful_dribbles_per_90': 0.020281004585760484, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.020281004585760484, 'pressures_per_90': 0.060843013757281454, 'blocks_per_90': 0.020281004585760484, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.04056200917152097, 'clearances_per_90': 0.04056200917152097, 'ball_recoveries_per_90': 2.4134395457054976, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.165425394071187, 'saves_per_90': 1.7036043852038807, 'goals_conceded_per_90': 0.4056200917152097, 'smothers_per_90': 0.0, 'collections_per_90': 0.3650580825436887, 'punches_per_90': 0.20281004585760484, 'sweeper_claims_per_90': 0.08112401834304193, 'sweeper_clears_per_90': 0.16224803668608387, 'save_percentage': 27.631578947368425, 'smother_success_rate': 0, 'collection_success_rate': 94.44444444444444, 'punch_success_rate': 70.0, 'sweeper_success_rate': 100.0}
# {'player_id': 26070, 'name': 'Antonio Rodríguez Martínez', 'minutes': 1349.25, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 22.07893274041134, 'pass_accuracy': 73.1117824773414, 'progressive_passes_per_90': 10.00555864369094, 'progressive_pass_accuracy': 46.0, 'long_passes_per_90': 10.27237354085603, 'long_pass_accuracy': 47.4025974025974, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 9.605336297943301, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.20011117287381877, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.06670372429127293, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 4.402445803224013, 'fouls_made_per_90': 0.13340744858254586, 'yellow_cards_per_90': 0.06670372429127293, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.136742634797109, 'saves_per_90': 1.7342968315730962, 'goals_conceded_per_90': 0.8004446914952751, 'smothers_per_90': 0.0, 'collections_per_90': 0.5336297943301834, 'punches_per_90': 0.6670372429127293, 'sweeper_claims_per_90': 0.6003335186214563, 'sweeper_clears_per_90': 0.5336297943301834, 'save_percentage': 28.26086956521739, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 80.0, 'sweeper_success_rate': 100.0}
# {'player_id': 6662, 'name': 'Iago Herrerín Buisán', 'minutes': 272.7, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 26.732673267326735, 'pass_accuracy': 53.086419753086425, 'progressive_passes_per_90': 22.772277227722775, 'progressive_pass_accuracy': 46.3768115942029, 'long_passes_per_90': 21.782178217821784, 'long_pass_accuracy': 46.96969696969697, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 11.551155115511552, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.33003300330033003, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.6303630363036308, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 9.570957095709572, 'saves_per_90': 0.6600660066006601, 'goals_conceded_per_90': 2.6402640264026402, 'smothers_per_90': 0.33003300330033003, 'collections_per_90': 0.33003300330033003, 'punches_per_90': 0.33003300330033003, 'sweeper_claims_per_90': 0.9900990099009902, 'sweeper_clears_per_90': 0.6600660066006601, 'save_percentage': 6.896551724137931, 'smother_success_rate': 0.0, 'collection_success_rate': 100.0, 'punch_success_rate': 100.0, 'sweeper_success_rate': 100.0}
# {'player_id': 20055, 'name': 'Marc-André ter Stegen', 'minutes': 893.42, 'most_played_position': 'Goalkeeper', 'position': 'goalkeeper', 'passes_per_90': 18.83772469835016, 'pass_accuracy': 88.23529411764706, 'progressive_passes_per_90': 5.339034272794431, 'progressive_pass_accuracy': 62.264150943396224, 'long_passes_per_90': 5.9434532470730455, 'long_pass_accuracy': 62.71186440677966, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.10073649571310248, 'assists_per_90': 0.0, 'passes_received_per_90': 9.267757605605427, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.3169394014013567, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 6.245662734212353, 'saves_per_90': 1.309574444270332, 'goals_conceded_per_90': 0.7051554699917173, 'smothers_per_90': 0.0, 'collections_per_90': 0.8058919657048198, 'punches_per_90': 0.20147299142620495, 'sweeper_claims_per_90': 0.20147299142620495, 'sweeper_clears_per_90': 0.20147299142620495, 'save_percentage': 20.967741935483872, 'smother_success_rate': 0, 'collection_success_rate': 100.0, 'punch_success_rate': 50.0, 'sweeper_success_rate': 100.0}

# %% [raw]
# Involvement data

# %%
# Define event type IDs that count as touches
# (You should adjust this list based on your event types)
touch_event_types = {
    42, # Reception
    2, # Recovery
    3, # Dispossessed
    4, # Duel
    6, # Block
    9, # Clearance
    10,  # Interception
    14,  # Dribble 
    16, # Shot
    21, # Foul Won
    23, #Goalkeeper
    30, # Pass
    33, #50-50
    37, #Error
    38, # Miscontrol
    43, # Carry
    
    # Add other event IDs that mean ball touch here
}

other_stats = defaultdict(lambda: {
    'x_total': 0.0,
    'y_total': 0.0,
    'touches': 0
})

for match_id, events in all_events.items():
    for event in events:
        player = event.get('player')
        location = event.get('location')
        etype = event.get('type', {}).get('id')

        # Skip if no player, location, or type
        if not player or not location or len(location) < 2 or etype not in touch_event_types:
            continue

        pid = player['id']
        x, y = location[0], location[1]

        other_stats[pid]['x_total'] += x
        other_stats[pid]['y_total'] += y
        other_stats[pid]['touches'] += 1

# %%
# Add to player data
for player in player_data:
    pid = player['player_id']
    minutes = player.get('minutes', 0)
    stats = other_stats.get(pid, {})

    if minutes > 0 and stats.get('touches', 0) > 0:
        factor = minutes / 90
        player['touches_per_90'] = stats['touches'] / factor
        player['average_position_x'] = stats['x_total'] / stats['touches']
        player['average_position_y'] = stats['y_total'] / stats['touches']
    else:
        player['touches_per_90'] = 0
        player['average_position_x'] = None
        player['average_position_y'] = None

# %%
print(player_data)
# Out:
# [{'player_id': 24149, 'name': 'José Antonio García Rabasco', 'minutes': 3369.15, 'most_played_position': 'Right Defensive Midfield', 'position': 'midfielder', 'passes_per_90': 36.3830639775611, 'pass_accuracy': 77.01908957415566, 'progressive_passes_per_90': 11.913984239348203, 'progressive_pass_accuracy': 60.0896860986547, 'long_passes_per_90': 7.319353546146654, 'long_pass_accuracy': 43.79562043795621, 'crosses_per_90': 0.9883798584212634, 'cross_accuracy': 24.324324324324326, 'key_passes_per_90': 1.095231735007346, 'assists_per_90': 0.0801389074395619, 'passes_received_per_90': 27.674636035795377, 'shots_per_90': 0.6678242286630159, 'shots_on_target_per_90': 0.18699078402564442, 'shot_accuracy': 0.28, 'goals_per_90': 0.053425938293041264, 'xg_per_90': 0.05210306754908508, 'first_time_shots_per_90': 0.21370375317216506, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.026712969146520632, 'dribbles_per_90': 0.5075464137838921, 'successful_dribbles_per_90': 0.34726859890476824, 'dribble_success_rate': 68.42105263157895, 'progressive_runs_per_90': 0.9616668892747429, 'fouls_won_per_90': 0.8548150126886603, 'pressures_per_90': 11.994123146787764, 'blocks_per_90': 0.8815279818351809, 'interceptions_per_90': 0.9082409509817015, 'dribbled_past_per_90': 0.7212501669560571, 'clearances_per_90': 0.8281020435421397, 'ball_recoveries_per_90': 3.3391211433150794, 'fouls_made_per_90': 1.1486576733003873, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.24041672231868572, 'duels_per_90': 1.816481901963403, 'duels_won_per_90': 0.34726859890476824, 'duel_success_rate': 19.11764705882353, 'touches_per_90': 99.74622679310805, 'average_position_x': 58.189582217461066, 'average_position_y': 44.31456882699508}, {'player_id': 26023, 'name': 'Juan Francisco García García', 'minutes': 2249.52, 'most_played_position': 'Left Center Back', 'position': 'center back', 'passes_per_90': 30.60652939293716, 'pass_accuracy': 64.70588235294117, 'progressive_passes_per_90': 15.363277499199828, 'progressive_pass_accuracy': 50.78125, 'long_passes_per_90': 10.002133788541554, 'long_pass_accuracy': 38.4, 'crosses_per_90': 1.0402219140083218, 'cross_accuracy': 23.076923076923077, 'key_passes_per_90': 0.16003414061666488, 'assists_per_90': 0.04000853515416622, 'passes_received_per_90': 18.32390910060813, 'shots_per_90': 0.12002560546249867, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.005781829324922651, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.040008535154166226, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.8401792382374906, 'successful_dribbles_per_90': 0.44009388669582844, 'dribble_success_rate': 52.38095238095239, 'progressive_runs_per_90': 1.0402219140083218, 'fouls_won_per_90': 0.720153632774992, 'pressures_per_90': 5.721220527045769, 'blocks_per_90': 1.1202389843166543, 'interceptions_per_90': 1.4002987303958176, 'dribbled_past_per_90': 1.080230449162488, 'clearances_per_90': 2.160460898324976, 'ball_recoveries_per_90': 2.9606316014083003, 'fouls_made_per_90': 0.7601621679291583, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.28005974607916356, 'duels_per_90': 2.0004267577083112, 'duels_won_per_90': 0.4000853515416622, 'duel_success_rate': 20.0, 'touches_per_90': 79.69700202709912, 'average_position_x': 48.67515060240957, 'average_position_y': 14.832479919678677}, {'player_id': 6742, 'name': 'Sergio Gontán Gallardo', 'minutes': 3311.02, 'most_played_position': 'Right Wing', 'position': 'winger', 'passes_per_90': 25.007399532470355, 'pass_accuracy': 64.89130434782608, 'progressive_passes_per_90': 6.469305531226027, 'progressive_pass_accuracy': 50.42016806722689, 'long_passes_per_90': 3.071561029531685, 'long_pass_accuracy': 36.283185840707965, 'crosses_per_90': 2.8269234254096927, 'cross_accuracy': 32.69230769230769, 'key_passes_per_90': 1.03291432851508, 'assists_per_90': 0.0815458680406642, 'passes_received_per_90': 34.629811961268736, 'shots_per_90': 0.9785504164879706, 'shots_on_target_ ...

# %%
import math

def check_nan_or_errors(player_data):
    problematic = []
    for player in player_data:
        for key, value in player.items():
            if value is None:
                problematic.append((player.get('player_id', 'unknown'), key, 'None'))
            elif isinstance(value, float) and math.isnan(value):
                problematic.append((player.get('player_id', 'unknown'), key, 'NaN'))
            # You can add more error checks here if needed

    if problematic:
        print("Found NaN or None in the following player stats:")
        for pid, col, val in problematic:
            print(f"Player {pid} - Column: {col} - Value: {val}")
    else:
        print("No NaN or None values found in player stats.")

check_nan_or_errors(player_data)
# Out:
# Found NaN or None in the following player stats:
# Player 206604 - Column: average_position_x - Value: None
# Player 206604 - Column: average_position_y - Value: None

# %%
for player in player_data:
    if player.get('player_id') == 206604:
        print(player)
        break
# Out:
# {'player_id': 206604, 'name': 'Imanol Corral Matellán', 'minutes': 48.7, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 0.0, 'pass_accuracy': 0.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 0.0, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 0, 'average_position_x': None, 'average_position_y': None}

# %%
unknown_positions = sum(1 for player in player_data if player.get('most_played_position') == 'Unknown')
print(f"Number of players with 'Unknown' position: {unknown_positions}")
# Out:
# Number of players with 'Unknown' position: 32

# %%
for player in player_data:
    if player.get('most_played_position') == 'Unknown':
        print(player)
# Out:
# {'player_id': 25057, 'name': 'Alejandro Barrera García', 'minutes': 316.17, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 9.962994591517221, 'pass_accuracy': 68.57142857142857, 'progressive_passes_per_90': 3.131226871619698, 'progressive_pass_accuracy': 63.63636363636363, 'long_passes_per_90': 0.5693139766581269, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 13.094221463136918, 'shots_per_90': 0.569313976658127, 'shots_on_target_per_90': 0.2846569883290635, 'shot_accuracy': 0.5, 'goals_per_90': 0.0, 'xg_per_90': 0.03252313948192428, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.569313976658127, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.28465698832906344, 'successful_dribbles_per_90': 0.28465698832906344, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 1.1386279533162538, 'fouls_won_per_90': 0.0, 'pressures_per_90': 8.25505266154284, 'blocks_per_90': 0.28465698832906344, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.28465698832906344, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.8539709649871904, 'fouls_made_per_90': 0.28465698832906344, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 2.2772559066325075, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 36.15143751779106, 'average_position_x': 72.54173228346451, 'average_position_y': 42.52598425196851}
# {'player_id': 6807, 'name': 'Roberto Suárez Pier', 'minutes': 151.73, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 24.912673828511174, 'pass_accuracy': 83.33333333333334, 'progressive_passes_per_90': 10.083701311540237, 'progressive_pass_accuracy': 76.47058823529412, 'long_passes_per_90': 5.338430106109537, 'long_pass_accuracy': 66.66666666666666, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 18.387925921043962, 'shots_per_90': 0.5931589006788375, 'shots_on_target_per_90': 0.5931589006788375, 'shot_accuracy': 1.0, 'goals_per_90': 0.0, 'xg_per_90': 0.20434824754498124, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.5931589006788375, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 1.186317801357675, 'fouls_won_per_90': 0.0, 'pressures_per_90': 4.152112304751862, 'blocks_per_90': 0.0, 'interceptions_per_90': 1.186317801357675, 'dribbled_past_per_90': 0.5931589006788375, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.5931589006788375, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.5931589006788375, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 63.46800237263561, 'average_position_x': 47.92803738317758, 'average_position_y': 17.84766355140186}
# {'player_id': 31469, 'name': 'Andrés Pascual Santoja', 'minutes': 106.55, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 5.068043172219616, 'pass_accuracy': 83.33333333333334, 'progressive_passes_per_90': 0.8446738620366027, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 12.670107930549038, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.6893477240732053, 'successful_dribbles_per_90': 0.8446738620366027, 'dribble_success_rate': 50.0, 'progressive_runs_per_90': 0.8446738620366027, 'fouls_won_per_90': 1.6893477240732053, 'pressures_per_90': 5.068043172219616, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.8446738620366027, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.534021586109808, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 3.3786954481464107, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 37.16564992961052, 'average_position_x': 72.69772727272726, 'average_position_y': 56.059090909090905}
# {'player_id': 6676, 'name': 'Igor Zubeldia Elorza', 'minutes': 61.07, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 7.368593417389881, 'pass_accuracy': 80.0, 'progressive_passes_per_90': 1.473718683477976, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 7.368593417389881, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 1.473718683477976, 'fouls_won_per_90': 0.0, 'pressures_per_90': 5.894874733911904, 'blocks_per_90': 1.473718683477976, 'interceptions_per_90': 1.473718683477976, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.473718683477976, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 30.948092353037495, 'average_position_x': 67.89999999999998, 'average_position_y': 27.952380952380945}
# {'player_id': 4558, 'name': 'Pape Cheikh Diop Gueye', 'minutes': 309.55, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 6.977871103214343, 'pass_accuracy': 91.66666666666666, 'progressive_passes_per_90': 0.8722338879017929, 'progressive_pass_accuracy': 66.66666666666666, 'long_passes_per_90': 0.29074462930059763, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 8.140849620416732, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.5814892586011953, 'successful_dribbles_per_90': 0.5814892586011953, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.29074462930059763, 'fouls_won_per_90': 1.1629785172023905, 'pressures_per_90': 2.907446293005976, 'blocks_per_90': 0.29074462930059763, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.453723146502988, 'fouls_made_per_90': 0.5814892586011953, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.7444677758035858, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 28.492973671458568, 'average_position_x': 55.522448979591864, 'average_position_y': 26.935714285714283}
# {'player_id': 197562, 'name': 'Iñigo Barrenetxea García', 'minutes': 110.87, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 5.682330657526832, 'pass_accuracy': 85.71428571428571, 'progressive_passes_per_90': 3.247046090015333, 'progressive_pass_accuracy': 75.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.8117615225038333, 'assists_per_90': 0.0, 'passes_received_per_90': 5.682330657526832, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.8117615225038333, 'fouls_won_per_90': 0.0, 'pressures_per_90': 2.4352845675115, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.8117615225038333, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.6235230450076665, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 18.670515017588166, 'average_position_x': 58.79565217391305, 'average_position_y': 50.29565217391304}
# {'player_id': 25984, 'name': 'Ángel Domingo López Ruano', 'minutes': 192.37, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 13.099755679159951, 'pass_accuracy': 89.28571428571429, 'progressive_passes_per_90': 0.9356968342257107, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 0.9356968342257107, 'long_pass_accuracy': 100.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 10.760513593595673, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.46784841711285535, 'fouls_won_per_90': 0.0, 'pressures_per_90': 4.210635754015699, 'blocks_per_90': 0.9356968342257107, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 1.4035452513385662, 'ball_recoveries_per_90': 0.9356968342257107, 'fouls_made_per_90': 0.9356968342257107, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 36.49217653480272, 'average_position_x': 52.083333333333336, 'average_position_y': 41.735897435897435}
# {'player_id': 197595, 'name': 'Sergio Mendigutxia Iglesias', 'minutes': 80.93, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 8.896577289015198, 'pass_accuracy': 62.5, 'progressive_passes_per_90': 1.1120721611268998, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 21.129371061411096, 'shots_per_90': 1.1120721611268998, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.050043754355615956, 'first_time_shots_per_90': 0.0, 'headers_per_90': 1.1120721611268998, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.1120721611268998, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 1.1120721611268998, 'fouls_won_per_90': 2.2241443222537995, 'pressures_per_90': 4.448288644507599, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 1.1120721611268998, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.1120721611268998, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 43.37081428394909, 'average_position_x': 76.50512820512823, 'average_position_y': 51.274358974358975}
# {'player_id': 31467, 'name': 'Eneko Capilla González', 'minutes': 57.18, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 7.869884575026234, 'pass_accuracy': 60.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 11.017838405036727, 'shots_per_90': 1.5739769150052465, 'shots_on_target_per_90': 1.5739769150052465, 'shot_accuracy': 1.0, 'goals_per_90': 0.0, 'xg_per_90': 0.06285515634837356, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.5739769150052467, 'successful_dribbles_per_90': 1.5739769150052467, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 1.5739769150052467, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.5739769150052467, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 34.62749213011543, 'average_position_x': 63.59545454545455, 'average_position_y': 24.87272727272727}
# {'player_id': 206604, 'name': 'Imanol Corral Matellán', 'minutes': 48.7, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 0.0, 'pass_accuracy': 0.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 0.0, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 0, 'average_position_x': None, 'average_position_y': None}
# {'player_id': 20063, 'name': 'Javier Ontiveros Parra', 'minutes': 261.9, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 14.776632302405499, 'pass_accuracy': 76.74418604651163, 'progressive_passes_per_90': 3.0927835051546393, 'progressive_pass_accuracy': 44.44444444444444, 'long_passes_per_90': 1.3745704467353954, 'long_pass_accuracy': 50.0, 'crosses_per_90': 0.6872852233676977, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.6872852233676977, 'assists_per_90': 0.0, 'passes_received_per_90': 13.745704467353953, 'shots_per_90': 0.3436426116838488, 'shots_on_target_per_90': 0.3436426116838488, 'shot_accuracy': 1.0, 'goals_per_90': 0.0, 'xg_per_90': 0.006717344329896908, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.6872852233676977, 'successful_dribbles_per_90': 0.6872852233676977, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.34364261168384885, 'pressures_per_90': 5.84192439862543, 'blocks_per_90': 0.34364261168384885, 'interceptions_per_90': 0.34364261168384885, 'dribbled_past_per_90': 0.6872852233676977, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 3.0927835051546393, 'fouls_made_per_90': 1.718213058419244, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.718213058419244, 'duels_won_per_90': 0.34364261168384885, 'duel_success_rate': 20.0, 'touches_per_90': 52.92096219931272, 'average_position_x': 72.36493506493505, 'average_position_y': 17.158441558441545}
# {'player_id': 197493, 'name': 'Mikel Arruabarrena Aranbide', 'minutes': 367.85, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 8.318608128313171, 'pass_accuracy': 94.11764705882352, 'progressive_passes_per_90': 0.7339948348511621, 'progressive_pass_accuracy': 66.66666666666666, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 9.786597798015494, 'shots_per_90': 0.24466494495038735, 'shots_on_target_per_90': 0.24466494495038735, 'shot_accuracy': 1.0, 'goals_per_90': 0.24466494495038735, 'xg_per_90': 0.22233804539893978, 'first_time_shots_per_90': 0.24466494495038735, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.48932988990077475, 'pressures_per_90': 5.1379638439581345, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.24466494495038738, 'ball_recoveries_per_90': 0.24466494495038738, 'fouls_made_per_90': 0.24466494495038738, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.7339948348511621, 'duels_won_per_90': 0.48932988990077475, 'duel_success_rate': 66.66666666666666, 'touches_per_90': 26.91314394454261, 'average_position_x': 63.3636363636364, 'average_position_y': 32.98181818181817}
# {'player_id': 6840, 'name': 'Marcos Llorente Moreno', 'minutes': 127.53, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 13.408609738884968, 'pass_accuracy': 100.0, 'progressive_passes_per_90': 1.4114326040931544, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.7057163020465772, 'assists_per_90': 0.0, 'passes_received_per_90': 12.70289343683839, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 3.528581510232886, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.7057163020465772, 'dribbled_past_per_90': 0.7057163020465772, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 38.81439661256175, 'average_position_x': 60.53818181818183, 'average_position_y': 46.769090909090906}
# {'player_id': 27401, 'name': 'Bernard Mensah', 'minutes': 471.07, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 8.02428513808988, 'pass_accuracy': 90.47619047619048, 'progressive_passes_per_90': 2.1015984885473498, 'progressive_pass_accuracy': 90.9090909090909, 'long_passes_per_90': 0.5731632241492772, 'long_pass_accuracy': 66.66666666666666, 'crosses_per_90': 0.19105440804975907, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 9.552720402487953, 'shots_per_90': 0.38210881609951813, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.003473677309104804, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.1463264482985545, 'successful_dribbles_per_90': 0.7642176321990363, 'dribble_success_rate': 66.66666666666666, 'progressive_runs_per_90': 1.3373808563483134, 'fouls_won_per_90': 0.38210881609951813, 'pressures_per_90': 4.01214256904494, 'blocks_per_90': 0.19105440804975907, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.5731632241492772, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.5731632241492772, 'fouls_made_per_90': 1.1463264482985545, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.5731632241492772, 'duels_won_per_90': 0.19105440804975907, 'duel_success_rate': 33.33333333333333, 'touches_per_90': 33.05241259260832, 'average_position_x': 66.4173410404624, 'average_position_y': 39.79595375722541}
# {'player_id': 10852, 'name': 'Miguel Filipe Nunes Cardoso', 'minutes': 202.82, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 7.099891529434967, 'pass_accuracy': 75.0, 'progressive_passes_per_90': 2.2187161029484272, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 0.44374322058968546, 'long_pass_accuracy': 100.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.44374322058968546, 'passes_received_per_90': 11.093580514742136, 'shots_per_90': 1.3312296617690564, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.04136903781678336, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.7749728823587418, 'successful_dribbles_per_90': 0.44374322058968546, 'dribble_success_rate': 25.0, 'progressive_runs_per_90': 0.8874864411793709, 'fouls_won_per_90': 0.0, 'pressures_per_90': 5.324918647076226, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.44374322058968546, 'dribbled_past_per_90': 0.44374322058968546, 'clearances_per_90': 0.44374322058968546, 'ball_recoveries_per_90': 0.8874864411793709, 'fouls_made_per_90': 0.44374322058968546, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.8874864411793709, 'duels_won_per_90': 0.44374322058968546, 'duel_success_rate': 50.0, 'touches_per_90': 33.7244847648161, 'average_position_x': 81.5828947368421, 'average_position_y': 35.95526315789474}
# {'player_id': 43354, 'name': 'Chengdong Zhang', 'minutes': 60.25, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 4.481327800829876, 'pass_accuracy': 66.66666666666666, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 1.4937759336099585, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 4.481327800829876, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 5.975103734439834, 'blocks_per_90': 1.4937759336099585, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 1.4937759336099585, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 1.4937759336099585, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.4937759336099585, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 16.431535269709546, 'average_position_x': 56.87272727272727, 'average_position_y': 15.390909090909092}
# {'player_id': 24249, 'name': 'Juan Muñiz Gallego', 'minutes': 269.3, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 9.357593761604159, 'pass_accuracy': 67.85714285714286, 'progressive_passes_per_90': 2.6735982176011883, 'progressive_pass_accuracy': 62.5, 'long_passes_per_90': 2.6735982176011883, 'long_pass_accuracy': 25.0, 'crosses_per_90': 0.33419977720014854, 'cross_accuracy': 0.0, 'key_passes_per_90': 1.3367991088005942, 'assists_per_90': 0.0, 'passes_received_per_90': 12.031191979205346, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.6683995544002971, 'successful_dribbles_per_90': 0.6683995544002971, 'dribble_success_rate': 100.0, 'progressive_runs_per_90': 1.6709988860007425, 'fouls_won_per_90': 1.6709988860007425, 'pressures_per_90': 8.354994430003712, 'blocks_per_90': 0.6683995544002971, 'interceptions_per_90': 0.33419977720014854, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.33419977720014854, 'ball_recoveries_per_90': 1.0025993316004456, 'fouls_made_per_90': 1.3367991088005942, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.33419977720014854, 'duels_per_90': 2.005198663200891, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 39.76977348681768, 'average_position_x': 67.9655462184874, 'average_position_y': 32.336974789915956}
# {'player_id': 49433, 'name': 'Hachim Mastour', 'minutes': 58.65, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 3.069053708439898, 'pass_accuracy': 50.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 4.603580562659847, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 3.069053708439898, 'blocks_per_90': 1.534526854219949, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 1.534526854219949, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.534526854219949, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 12.276214833759592, 'average_position_x': 70.3, 'average_position_y': 24.7}
# {'player_id': 26775, 'name': 'Thievy Guivane Bifouma Koulossa', 'minutes': 554.22, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 11.36732705423839, 'pass_accuracy': 74.28571428571429, 'progressive_passes_per_90': 1.7862942513803182, 'progressive_pass_accuracy': 54.54545454545454, 'long_passes_per_90': 0.4871711594673595, 'long_pass_accuracy': 33.33333333333333, 'crosses_per_90': 0.16239038648911983, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.32478077297823965, 'assists_per_90': 0.0, 'passes_received_per_90': 17.538161740824943, 'shots_per_90': 0.32478077297823965, 'shots_on_target_per_90': 0.16239038648911983, 'shot_accuracy': 0.5, 'goals_per_90': 0.0, 'xg_per_90': 0.015726155082819094, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 2.111075024358558, 'successful_dribbles_per_90': 0.974342318934719, 'dribble_success_rate': 46.15384615384615, 'progressive_runs_per_90': 1.4615134784020785, 'fouls_won_per_90': 0.8119519324455992, 'pressures_per_90': 4.059759662227996, 'blocks_per_90': 0.6495615459564793, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.4871711594673595, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.6239038648911983, 'fouls_made_per_90': 0.8119519324455992, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 2.111075024358558, 'duels_won_per_90': 0.32478077297823965, 'duel_success_rate': 15.384615384615385, 'touches_per_90': 50.17862942513803, 'average_position_x': 80.74045307443367, 'average_position_y': 39.363106796116504}
# {'player_id': 166764, 'name': 'Ander Gayoso Reina', 'minutes': 56.15, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 9.617097061442566, 'pass_accuracy': 66.66666666666666, 'progressive_passes_per_90': 4.808548530721283, 'progressive_pass_accuracy': 33.33333333333333, 'long_passes_per_90': 3.2056990204808553, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 6.411398040961711, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 1.6028495102404277, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 1.6028495102404277, 'ball_recoveries_per_90': 1.6028495102404277, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 27.248441674087267, 'average_position_x': 65.81176470588235, 'average_position_y': 6.329411764705883}
# {'player_id': 8866, 'name': 'Carlos Fernández Luna', 'minutes': 76.48, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 10.591004184100418, 'pass_accuracy': 88.88888888888889, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 1.1767782426778242, 'assists_per_90': 0.0, 'passes_received_per_90': 10.591004184100418, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 2.3535564853556483, 'fouls_won_per_90': 1.1767782426778242, 'pressures_per_90': 3.5303347280334725, 'blocks_per_90': 0.0, 'interceptions_per_90': 1.1767782426778242, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.1767782426778242, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 1.1767782426778242, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 34.1265690376569, 'average_position_x': 88.54482758620692, 'average_position_y': 51.87241379310344}
# {'player_id': 34728, 'name': 'Diego Alende López', 'minutes': 92.3, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 5.850487540628386, 'pass_accuracy': 100.0, 'progressive_passes_per_90': 0.9750812567713976, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 4.8754062838569885, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 4.8754062838569885, 'blocks_per_90': 2.925243770314193, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 3.9003250270855903, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.9750812567713976, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 22.426868905742147, 'average_position_x': 32.10869565217392, 'average_position_y': 46.12173913043478}
# {'player_id': 11212, 'name': 'Fábio Ricardo Gomes Fonseca', 'minutes': 191.73, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 25.817555938037867, 'pass_accuracy': 81.81818181818183, 'progressive_passes_per_90': 4.224690971678924, 'progressive_pass_accuracy': 66.66666666666666, 'long_passes_per_90': 1.4082303238929745, 'long_pass_accuracy': 33.33333333333333, 'crosses_per_90': 0.9388202159286497, 'cross_accuracy': 50.0, 'key_passes_per_90': 0.46941010796432486, 'assists_per_90': 0.0, 'passes_received_per_90': 30.511657017681117, 'shots_per_90': 0.9388202159286497, 'shots_on_target_per_90': 0.46941010796432486, 'shot_accuracy': 0.5, 'goals_per_90': 0.0, 'xg_per_90': 0.022038413550305117, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.8776404318572995, 'successful_dribbles_per_90': 0.46941010796432486, 'dribble_success_rate': 25.0, 'progressive_runs_per_90': 1.4082303238929745, 'fouls_won_per_90': 0.46941010796432486, 'pressures_per_90': 3.285870755750274, 'blocks_per_90': 0.9388202159286497, 'interceptions_per_90': 0.46941010796432486, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.46941010796432486, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 86.37145986543578, 'average_position_x': 73.39347826086956, 'average_position_y': 59.13423913043475}
# {'player_id': 23849, 'name': 'Francisco José Villalba Rodrigo', 'minutes': 55.25, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 6.515837104072398, 'pass_accuracy': 75.0, 'progressive_passes_per_90': 3.257918552036199, 'progressive_pass_accuracy': 50.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 6.515837104072398, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 1.6289592760180995, 'fouls_won_per_90': 0.0, 'pressures_per_90': 1.6289592760180995, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.6289592760180995, 'fouls_made_per_90': 3.257918552036199, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 1.6289592760180995, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 21.176470588235293, 'average_position_x': 72.86923076923077, 'average_position_y': 58.723076923076924}
# {'player_id': 27052, 'name': 'Lévy Clément Madinda', 'minutes': 51.42, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 3.5005834305717616, 'pass_accuracy': 100.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 3.5005834305717616, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 1.7502917152858808, 'blocks_per_90': 0.0, 'interceptions_per_90': 1.7502917152858808, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 12.252042007001167, 'average_position_x': 73.02857142857142, 'average_position_y': 63.57142857142857}
# {'player_id': 6834, 'name': 'Gerard Gumbau Garriga', 'minutes': 192.5, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 9.35064935064935, 'pass_accuracy': 85.0, 'progressive_passes_per_90': 1.87012987012987, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 0.4675324675324675, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 9.35064935064935, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 8.883116883116884, 'blocks_per_90': 1.4025974025974026, 'interceptions_per_90': 0.4675324675324675, 'dribbled_past_per_90': 1.4025974025974026, 'clearances_per_90': 0.935064935064935, 'ball_recoveries_per_90': 0.4675324675324675, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.4675324675324675, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 30.38961038961039, 'average_position_x': 53.12153846153847, 'average_position_y': 40.91538461538462}
# {'player_id': 27318, 'name': 'Douglas Pereira dos Santos', 'minutes': 61.93, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 4.359761020507024, 'pass_accuracy': 66.66666666666666, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 2.9065073470046827, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 1.4532536735023414, 'pressures_per_90': 5.813014694009365, 'blocks_per_90': 0.0, 'interceptions_per_90': 1.4532536735023414, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 2.9065073470046827, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 15.985790408525755, 'average_position_x': 37.25454545454546, 'average_position_y': 64.10909090909091}
# {'player_id': 11146, 'name': 'Luis Carlos Fariña Olivera', 'minutes': 208.12, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 8.216413607534115, 'pass_accuracy': 89.47368421052632, 'progressive_passes_per_90': 0.8648856428983278, 'progressive_pass_accuracy': 50.0, 'long_passes_per_90': 0.4324428214491639, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 11.675956179127427, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.2973284643474918, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.4324428214491639, 'pressures_per_90': 5.621756678839131, 'blocks_per_90': 0.0, 'interceptions_per_90': 1.2973284643474918, 'dribbled_past_per_90': 0.8648856428983278, 'clearances_per_90': 0.4324428214491639, 'ball_recoveries_per_90': 2.5946569286949837, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.4324428214491639, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 39.78473957332308, 'average_position_x': 77.629347826087, 'average_position_y': 35.53152173913045}
# {'player_id': 79615, 'name': 'Néstor Díaz García', 'minutes': 64.12, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 2.80723643169058, 'pass_accuracy': 100.0, 'progressive_passes_per_90': 1.40361821584529, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 2.80723643169058, 'long_pass_accuracy': 100.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 1.40361821584529, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'shots_faced_per_90': 2.80723643169058, 'saves_per_90': 0.0, 'goals_conceded_per_90': 0.0, 'smothers_per_90': 0.0, 'collections_per_90': 0.0, 'punches_per_90': 1.40361821584529, 'sweeper_claims_per_90': 0.0, 'sweeper_clears_per_90': 0.0, 'save_percentage': 0.0, 'smother_success_rate': 0, 'collection_success_rate': 0, 'punch_success_rate': 100.0, 'sweeper_success_rate': 0, 'touches_per_90': 9.82532751091703, 'average_position_x': 7.299999999999999, 'average_position_y': 37.91428571428572}
# {'player_id': 27970, 'name': 'Ian González Nieto', 'minutes': 66.15, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 14.965986394557822, 'pass_accuracy': 81.81818181818183, 'progressive_passes_per_90': 1.3605442176870746, 'progressive_pass_accuracy': 100.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 17.68707482993197, 'shots_per_90': 1.3605442176870748, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0.0, 'goals_per_90': 0.0, 'xg_per_90': 0.35725689795918364, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 2.721088435374149, 'fouls_won_per_90': 0.0, 'pressures_per_90': 0.0, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 0.0, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 50.34013605442176, 'average_position_x': 77.53513513513514, 'average_position_y': 28.591891891891887}
# {'player_id': 21229, 'name': 'Sergi Samper Montaña', 'minutes': 78.72, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 29.72560975609756, 'pass_accuracy': 84.61538461538461, 'progressive_passes_per_90': 8.003048780487804, 'progressive_pass_accuracy': 71.42857142857143, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 22.865853658536583, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 0.0, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 2.2865853658536586, 'fouls_won_per_90': 0.0, 'pressures_per_90': 12.576219512195122, 'blocks_per_90': 0.0, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 2.2865853658536586, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 2.2865853658536586, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 2.2865853658536586, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 81.17378048780488, 'average_position_x': 50.509859154929586, 'average_position_y': 39.55915492957747}
# {'player_id': 27481, 'name': 'Carlos Carbonell Gil', 'minutes': 53.95, 'most_played_position': 'Unknown', 'position': 'other', 'passes_per_90': 3.336422613531047, 'pass_accuracy': 50.0, 'progressive_passes_per_90': 0.0, 'progressive_pass_accuracy': 0.0, 'long_passes_per_90': 0.0, 'long_pass_accuracy': 0.0, 'crosses_per_90': 0.0, 'cross_accuracy': 0.0, 'key_passes_per_90': 0.0, 'assists_per_90': 0.0, 'passes_received_per_90': 1.6682113067655235, 'shots_per_90': 0.0, 'shots_on_target_per_90': 0.0, 'shot_accuracy': 0, 'goals_per_90': 0.0, 'xg_per_90': 0.0, 'first_time_shots_per_90': 0.0, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.0, 'dribbles_per_90': 1.6682113067655235, 'successful_dribbles_per_90': 0.0, 'dribble_success_rate': 0.0, 'progressive_runs_per_90': 0.0, 'fouls_won_per_90': 0.0, 'pressures_per_90': 5.004633920296571, 'blocks_per_90': 1.6682113067655235, 'interceptions_per_90': 0.0, 'dribbled_past_per_90': 0.0, 'clearances_per_90': 0.0, 'ball_recoveries_per_90': 1.6682113067655235, 'fouls_made_per_90': 0.0, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.0, 'duels_per_90': 0.0, 'duels_won_per_90': 0.0, 'duel_success_rate': 0.0, 'touches_per_90': 11.677479147358666, 'average_position_x': 48.67142857142857, 'average_position_y': 48.81428571428571}

# %%
import pandas as pd

df_players = pd.DataFrame(player_data)
print(df_players.head())  # To see the first few rows
# Out:
#    player_id                          name  minutes      most_played_position  \
# 0      24149   José Antonio García Rabasco  3369.15  Right Defensive Midfield
# 1      26023  Juan Francisco García García  2249.52          Left Center Back
# 2       6742        Sergio Gontán Gallardo  3311.02                Right Wing
# 3       6566          Borja González Tomás  3721.57            Center Forward
# 4       5678  Jefferson Andrés Lerma Solís  4122.73     Right Center Midfield
#
#       position  passes_per_90  pass_accuracy  progressive_passes_per_90  \
# 0   midfielder      36.383064      77.019090                  11.913984
# 1  center back      30.606529      64.705882                  15.363277
# 2       winger      25.007400      64.891304                   6.469306
# 3      striker      15.646622      69.397218                   2.684351
# 4   midfielder      26.436366      73.988439                   7.531417
#
#    progressive_pass_accuracy  long_passes_per_90  ...  smothers_per_90  \
# 0                  60.089686            7.319354  ...              NaN
# 1                  50.781250           10.002134  ...              NaN
# 2                  50.420168            3.071561  ...              NaN
# 3                  49.549550            0.580400  ...              NaN
# 4                  52.753623            3.689303  ...              NaN
#
#    collections_per_90  punches_per_90  sweeper_claims_per_90  \
# 0                 NaN             NaN                    NaN
# 1                 NaN             NaN                    NaN
# 2                 NaN             NaN                    NaN
# 3                 NaN             NaN                    NaN
# 4                 NaN             NaN                    NaN
#
#    sweeper_clears_per_90  save_percentage  smother_success_rate  \
# 0                    NaN              NaN                   NaN
# 1                    NaN              NaN                   NaN
# 2                    NaN              NaN                   NaN
# 3                    NaN              NaN                   NaN
# 4                    NaN              NaN                   NaN
#
#    collection_success_rate  punch_success_rate  sweeper_success_rate
# 0                      NaN                 NaN                   NaN
# 1                      NaN                 NaN                   NaN
# 2                      NaN                 NaN                   NaN
# 3                      NaN                 NaN                   NaN
# 4                      NaN                 NaN                   NaN
#
# [5 rows x 57 columns]

# %%
cols_to_fill = [
    'shots_faced_per_90',
    'saves_per_90',
    'goals_conceded_per_90',
    'smothers_per_90',
    'collections_per_90',
    'punches_per_90',
    'sweeper_claims_per_90',
    'sweeper_clears_per_90',
    'save_percentage',
    'smother_success_rate',
    'collection_success_rate',
    'punch_success_rate',
    'sweeper_success_rate'  # fixed missing quote here
]

df_players[cols_to_fill] = df_players[cols_to_fill].fillna(0.0)

# %%
print(df_players.columns)
print(df_players['name'].head(20))  # or try another likely column name, e.g. 'player_name'
keylor_row = df_players[df_players['name'].str.contains('José Antonio García Rabasco', case=False, na=False)]
print(keylor_row.to_dict(orient='records'))
# Out:
# Index(['player_id', 'name', 'minutes', 'most_played_position', 'position',
#        'passes_per_90', 'pass_accuracy', 'progressive_passes_per_90',
#        'progressive_pass_accuracy', 'long_passes_per_90', 'long_pass_accuracy',
#        'crosses_per_90', 'cross_accuracy', 'key_passes_per_90',
#        'assists_per_90', 'passes_received_per_90', 'shots_per_90',
#        'shots_on_target_per_90', 'shot_accuracy', 'goals_per_90', 'xg_per_90',
#        'first_time_shots_per_90', 'headers_per_90', 'shots_outside_box_per_90',
#        'dribbles_per_90', 'successful_dribbles_per_90', 'dribble_success_rate',
#        'progressive_runs_per_90', 'fouls_won_per_90', 'pressures_per_90',
#        'blocks_per_90', 'interceptions_per_90', 'dribbled_past_per_90',
#        'clearances_per_90', 'ball_recoveries_per_90', 'fouls_made_per_90',
#        'yellow_cards_per_90', 'red_cards_per_90', 'duels_per_90',
#        'duels_won_per_90', 'duel_success_rate', 'touches_per_90',
#        'average_position_x', 'average_position_y', 'shots_faced_per_90',
#        'saves_per_90', 'goals_conceded_per_90', 'smothers_per_90',
#        'collections_per_90', 'punches_per_90', 'sweeper_claims_per_90',
#        'sweeper_clears_per_90', 'save_percentage', 'smother_success_rate',
#        'collection_success_rate', 'punch_success_rate',
#        'sweeper_success_rate'],
#       dtype='object')
# 0            José Antonio García Rabasco
# 1           Juan Francisco García García
# 2                 Sergio Gontán Gallardo
# 3                   Borja González Tomás
# 4           Jefferson Andrés Lerma Solís
# 5                           Takashi Inui
# 6            Rubén Iván Martínez Andrade
# 7                 Ángel Trujillo Canorea
# 8                         Zouhair Feddal
# 9              José Luis Morales Nogales
# 10                 Antonio García Aranda
# 11    José María Martín-Bejarano Serrano
# 12                          Nabil Ghilas
# 13              Víctor Casadesús Castaño
# 14                  Asier Riesgo Unamuno
# 15                  Ander Capa Rodríguez
# 16               Mauro Javier Dos Santos
# 17                     Aleksandar Pantić
# 18                      David Juncà Reñé
# 19                     Gonzalo Escalante
# Name: name, dtype: object
# [{'player_id': 24149, 'name': 'José Antonio García Rabasco', 'minutes': 3369.15, 'most_played_position': 'Right Defensive Midfield', 'position': 'midfielder', 'passes_per_90': 36.3830639775611, 'pass_accuracy': 77.01908957415566, 'progressive_passes_per_90': 11.913984239348203, 'progressive_pass_accuracy': 60.0896860986547, 'long_passes_per_90': 7.319353546146654, 'long_pass_accuracy': 43.79562043795621, 'crosses_per_90': 0.9883798584212634, 'cross_accuracy': 24.324324324324326, 'key_passes_per_90': 1.095231735007346, 'assists_per_90': 0.0801389074395619, 'passes_received_per_90': 27.674636035795377, 'shots_per_90': 0.6678242286630159, 'shots_on_target_per_90': 0.18699078402564442, 'shot_accuracy': 0.28, 'goals_per_90': 0.053425938293041264, 'xg_per_90': 0.05210306754908508, 'first_time_shots_per_90': 0.21370375317216506, 'headers_per_90': 0.0, 'shots_outside_box_per_90': 0.026712969146520632, 'dribbles_per_90': 0.5075464137838921, 'successful_dribbles_per_90': 0.34726859890476824, 'dribble_success_rate': 68.42105263157895, 'progressive_runs_per_90': 0.9616668892747429, 'fouls_won_per_90': 0.8548150126886603, 'pressures_per_90': 11.994123146787764, 'blocks_per_90': 0.8815279818351809, 'interceptions_per_90': 0.9082409509817015, 'dribbled_past_per_90': 0.7212501669560571, 'clearances_per_90': 0.8281020435421397, 'ball_recoveries_per_90': 3.3391211433150794, 'fouls_made_per_90': 1.1486576733003873, 'yellow_cards_per_90': 0.0, 'red_cards_per_90': 0.24041672231868572, 'duels_per_90': 1.816481901963403, 'duels_won_per_90': 0.34726859890476824, 'duel_success_rate': 19.11764705882353, 'touches_per_90': 99.74622679310805, 'average_position_x': 58.189582217461066, 'average_position_y': 44.31456882699508, 'shots_faced_per_90': 0.0, 'saves_per_90': 0.0, 'goals_conceded_per_90': 0.0, 'smothers_per_90': 0.0, 'collections_per_90': 0.0, 'punches_per_90': 0.0, 'sweeper_claims_per_90': 0.0, 'sweeper_clears_per_90': 0.0, 'save_percentage': 0.0, 'smother_success_rate': 0.0, 'collection_success_rate': 0.0, 'punch_success_rate': 0.0, 'sweeper_success_rate': 0.0}]

# %%
for col in df_players.columns:
    nan_count = df_players[col].isna().sum()
    if nan_count > 0:
        print(f"Column '{col}' has {nan_count} NaN(s).")
        players_with_nan = df_players[df_players[col].isna()]
        print("Players with NaN in this column:")
        for idx, row in players_with_nan.iterrows():
            pid = row.get('player_id', 'Unknown')
            name = row.get('name', 'Unknown')
            print(f" - Player ID: {pid}, Name: {name}")
        print()
# Out:
# Column 'average_position_x' has 1 NaN(s).
# Players with NaN in this column:
#  - Player ID: 206604, Name: Imanol Corral Matellán
#
# Column 'average_position_y' has 1 NaN(s).
# Players with NaN in this column:
#  - Player ID: 206604, Name: Imanol Corral Matellán

# %%
# Drop all rows with any NaNs
df_players_clean = df_players.dropna()

print(f"Removed {len(df_players) - len(df_players_clean)} players with NaN values.")
# Out:
# Removed 1 players with NaN values.

# %%
df_players_clean.to_csv('cleaned_player_data.csv', index=False)
